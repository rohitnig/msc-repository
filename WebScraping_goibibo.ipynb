# %%
"""
Web Scraping - Beautiful Soup
"""

# importing required libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd

# target URL to scrap
url = "https://www.goibibo.com/hotels/hotels-in-shimla-ct/"

# headers
headers = {
    'User-Agent': "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36"
    }

# send request to download the data
response = requests.request("GET", url, headers=headers)

# parse the downloaded data
data = BeautifulSoup(response.text, 'html.parser')
print(data)
# Out:
# <!DOCTYPE html>
# <html><head><title>Hotels in Shimla - Book 789 Shimla Hotels with 𝘂𝗽𝘁𝗼 𝟱𝟬% off @ ₹251</title><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/><meta content="Best Shimla Hotels with upto 50% off from Goibibo. Check 51650 reviews and 38180 photos for 789  Shimla Hotels. Use coupon code GETSETGO and grab best deals starting from  @ ₹251 on Shimla online hotel booking. ✔ Lowest Price Guarantee ✔ Fastest Booking ✔ Instant Refund" name="description"/><meta content="width=device-width,initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/><meta content="hotels in Shimla, best hotels in Shimla, Shimla hotels, Shimla hotel booking, Shimla hotel price, Shimla hotel deals, book Shimla hotels, goibibo Shimla hotels" name="keywords"/><link href="//www.goibibo.com/images/favicon.ico" rel="shortcut icon" type="image/ico"/><meta content="Hotels in Shimla -  Book 789  Shimla Hotels with 𝘂𝗽𝘁𝗼 𝟱𝟬% off  @ ₹251" property="og:title"/><meta content="Best Shimla Hotels with upto 50% off from Goibibo. Check 51650 reviews and 38180 photos for 789  Shimla Hotels. Use coupon code GETSETGO and grab best deals starting from  @ ₹251 on Shimla online hotel booking. ✔ Lowest Price Guarantee ✔ Fastest Booking ✔ Instant Refund" property="og:description"/><meta content="https://cdn1.goibibo.com/himachal-pradesh-shimla-147617005104o.jpg" property="og:image"/><meta content="https://www.goibibo.com/hotels/hotels-in-shimla-ct/" property="og:url"/><link href="https://www.goibibo.com/hotels/hotels-in-shimla-ct/" rel="canonical"/><link href="https://www.goibibo.com/hotels/hotels-in-shimla-ct/?pg=2" rel="next"/><link href='android-app://com.goibibo/goibibo/www.goibibo.com/app/hotels/hotels-in-shimla-ct/?params={"go_data": {"n": "shimla", "oid": "1449073512565742573", "t": "area", "cid": "1449073512565742573"}, "tag_id": 202}' rel="alternate"/><link href="https://fonts.googleapis.com/css?family=Quicksand&amp;display=swap" rel="stylesheet"/></head><body class="width100 fl"><noscript><meta content="0;url='https://www.goibibo.com/hotels/hotels-in-shimla-ct/?PageSpeed=noscript'" http-equiv="refresh"/><style><!--table,div,span,font,p{display:none} --></style><div style="display:block">Please click <a href="https://www.goibibo.com/hotels/hotels-in-shimla-ct/?PageSpeed=noscript">here</a> if you are not redirected within a few seconds.</div></noscript><div class="bgdiv" id="new-hotel-loading-div" style="position: fixed; font-family: 'Quicksand', sans-serif !important; display:none"><div id="background-loader-text" onclick="event.stopPropagation()" style="border-radius: 30px; margin: 150px auto; background-color: white; width: 643px; height: 336px;"><div style="width: 100%; height: 213px;"><script pagespeed_no_defer="">//<![CDATA[
# (function(){var g=encodeURIComponent,h=window,k=document,l="width",m="documentElement",n="height",p="length",q=this,r=function(b,d){var a=b.split("."),c=q;a[0]in c||!c.execScript||c.execScript("var "+a[0]);for(var e;a[p]&&(e=a.shift());)a[p]||void 0===d?c[e]?c=c[e]:c=c[e]={}:c[e]=d};var t=function(b){var d=b[p];if(0<d){for(var a=Array(d),c=0;c<d;c++)a[c]=b[c];return a}return[]};var u=function(b){var d=h;if(d.addEventListener)d.addEventListener("load",b,!1);else if(d.attachEvent)d.attachEvent("onload",b);else{var a=d.onload;d.onload=function(){b.call(this);a&&a.call(this)}}};var v,w=function(b,d,a,c,e){this.f=b;this.h=d;this.i=a;this.c=e;this.e={height:h.innerHeight||k[m].clientHeight||k.body.clientHeight,width:h.innerWidth||k[m].clientWidth||k.body.clientWidth};this.g=c;this.b={};this.a=[];this.d={}},x=function(b,d){var a,c,e=d.getAttribute("pagespeed_url_hash");if(a=e)if(a=!(e in b.d))if(0>=d.offsetWidth&&0>=d.offsetHeight)a=!1;else{c=d.getBoundingClientRect();var f=k.body;a=c.top+("pageYOffset"in h?h.pageYOffset:(k[m]||f.parentNode||f).scrollTop);c=c.left+("pageXOffset"in
# h?h.pageXOffset:(k[m]||f.parentNode||f).scrollLeft);f=a.toString()+","+c;b.b.hasOwnProperty(f)?a=!1:(b.b[f]=!0,a=a<=b.e[n]&&c<=b.e[l])}a&&(b.a.push(e),b.d[e]=!0)};w.prototype.checkImageForCriticality=function(b){b.getBoundingClientRect&&x(this,b)};r("pagespeed.CriticalImages.checkImageForCriticality",function(b){v.checkImageForCriticality(b)});r("pagespeed.CriticalImages.checkCriticalImages",function(){y(v)});
# var y=function(b){b.b={};for(var d=["IMG","INPUT"],a=[],c=0;c<d[p];++c)a=a.concat(t(k.getElementsByTagName(d[c])));if(0!=a[p]&&a[0].getBoundingClientRect){for(c=0;d=a[c];++c)x(b,d);a="oh="+b.i;b.c&&(a+="&n="+b.c);if(d=0!=b.a[p])for(a+="&ci="+g(b.a[0]),c=1;c<b.a[p];++c){var e=","+g(b.a[c]);131072>=a[p]+e[p]&&(a+=e)}b.g&&(e="&rd="+g(JSON.stringify(z())),131072>=a[p]+e[p]&&(a+=e),d=!0);A=a;if(d){c=b.f;b=b.h;var f;if(h.XMLHttpRequest)f=new XMLHttpRequest;else if(h.ActiveXObject)try{f=new ActiveXObject("Msxml2.XMLHTTP")}catch(s){try{f=
# new ActiveXObject("Microsoft.XMLHTTP")}catch(B){}}f&&(f.open("POST",c+(-1==c.indexOf("?")?"?":"&")+"url="+g(b)),f.setRequestHeader("Content-Type","application/x-www-form-urlencoded"),f.send(a))}}},z=function(){var b={},d=k.getElementsByTagName("IMG");if(0==d[p])return{};var a=d[0];if(!("naturalWidth"in a&&"naturalHeight"in a))return{};for(var c=0;a=d[c];++c){var e=a.getAttribute("pagespeed_url_hash");e&&(!(e in b)&&0<a[l]&&0<a[n]&&0<a.naturalWidth&&0<a.naturalHeight||e in b&&a[l]>=b[a.src].k&&a[n]>=
# b[a.src].j)&&(b[e]={rw:a[l],rh:a[n],ow:a.naturalWidth,oh:a.naturalHeight})}return b},A="";r("pagespeed.CriticalImages.getBeaconData",function(){return A});r("pagespeed.CriticalImages.Run",function(b,d,a,c,e,f){var s=new w(b,d,a,e,f);v=s;c&&u(function(){h.setTimeout(function(){y(s)},0)})});})();
#
# pagespeed.CriticalImages.Run('/mod_pagespeed_beacon','https://www.goibibo.com/hotels/hotels-in-shimla-ct/','9h69CgP56i',true,false,'sBNnqsN5-Eo');
# //]]></script><img onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="2129554552" src="https://gos3.ibcdn.com/screen-loader-1568375554.png" style="width: auto; height: 175px; margin: 25px auto;"/></div><p style="width: 393px; margin: 0px auto; font-size: 22px; font-weight: bold; color: #2276e3;">LOADING THE BEST PRICES FOR YOU</p><div style="font-weight: normal; color: #898b91;"><p>We get you the best prices, everytime. Serving over 600k</p><p>customers worldwide everyday</p></div></div></div><div itemscope="" itemtype="http://schema.org/WebPage"><div id="app-install-widget"></div><script src="//goibibo.ibcdn.com/hotelsnew/static/js/lib/jquery.2.1.3.min.1483561221.js"></script><script src="//goibibo.ibcdn.com/styleguide/js/respond.min.1483563658.js"></script><script src="//goibibo.ibcdn.com/js/v2/headerV2.1568333090.js"></script><script src="//goibibo.ibcdn.com/js/v2/header_common.1568333090.js"></script><div class="headerBox col-md-12 col-sm-12 col-xs-12"><div class="hdrLeft"><a class="hdrLogo" href="/"><img onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="753931433" src="//goibibo.ibcdn.com/styleguide/images/goLogo.png"/></a><ul class="mainLinks"><li class="active"><a href="/flights/"><i class="icon-flights db blue ico24 lh1-2 padT5 padB5"></i> <span class="iconText ">Flights</span></a></li><li class=""><a href="/hotels/"><i class="icon-hotels db blue ico28 lh1-2 padT2 padB3"></i> <span class="iconText">Hotels</span></a></li><li class=""><a href="/gostays/"><i class="icon-gostays icon-gostays-cstm db blue padT5 padB5"></i> <span class="iconText">Hotels</span></a></li><li class=""><a href="/bus/"><i class="icon-bus db blue ico24 lh1-2 padT5 padB5"></i> <span class="iconText ">Bus</span></a></li><li class="posRel"><a href="/trains/"><img alt="irctc train logo" class="marginT5 marginB5" height="25px" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="3286845901" src="/styleguide/images/train_logo.png" width="24px"/><span class="iconText ">IRCTC Trains</span></a></li><li class="posRel"><a href="/cars/"><i class="icon-airport-transfer db blue ico24 lh1-2 padT5 padB5"></i><span class="iconText ">Cabs</span></a></li><li class="hdrMoreLink"><div class="padB10 lh1-2 iconText fmtTooltip">more +<div class="tip tip_top white moreSubLinks"><a href="/international-flights/"><i class="icon-flights padR10 blue ico20 fl"></i> <span class="fl padT3">International Flights</span></a><a href="/mobile/"><i class="icon-mobiles padR10 blue ico20 fl"></i> <span class="fl padT3">Mobile Apps</span></a> <a href="/destinations/"><i class="icon-destination padR10 blue ico20 fl"></i> <span class="fl padT3">Destinations</span></a> <a href="/ask/"><i class="icon-ask padR10 blue ico20 fl"></i> <span class="fl padT3">Ask</span></a> <a href="/routeplanner/"><i class="icon-route-planner padR10 blue ico20 fl"></i> <span class="fl padT3">Route Planner</span></a> <a href="/offers/"><i class="icon-offer-badge padR10 blue ico20 fl"></i> <span class="fl padT3">Offers &amp; Promotions</span></a> <a href="/info/reviews-and-rating/"><i class="icon-photo-review padR10 blue ico22 fl"></i> <span class="fl padT3">Reviews &amp; Ratings</span></a> <a href="/trains/check-train-running-status/"><i class="icon-train-front-view padR10 blue ico22 fl"></i> <span class="fl padT3">Train Runing Status</span></a> <a href="/trains/check-pnr-status/"><i class="icon-train-front-view padR10 blue ico22 fl"></i> <span class="fl padT3">Check PNR Status</span></a></div></div></li></ul></div><div class="hdrRight"><div class="width100 fl txtRight padB5 padR5"><a class="hdrCusSupport vMid padR15" href="/support/"><small class="fl ico13 lh1-2">24x7 goCare Support</small></a> <span class="vMid dib txtRight hdrUserName" id="hdr_user_signin"><span class="ico13 blue db"><a href="javascript:void(0)" onclick="window.location.href = '/accounts/login/?next=' + location.href;  ">Sign In</a> / <a href= ...
#     $(window).on('load',function(){
#
#         if(widget && widget.autosuggestSetter)
#         {
#             widget.autosuggestSetter({"title": "Shimla", "country": "IN", "entityType": "city", "cityName": "Shimla", "cityId": "1449073512565742573", "entityId": "1449073512565742573"});
#         }
#
#
#
#
#     });
#
# </script><div class="searchWrapOuterBox bgBlue row"><div class="searchInnerBox"><a class="dn ipaddn mobdb button orange large fl width100 marginB10 goCamp" href="javascript:void(0)" id="searchHotelButton" style="display:none !important;">Search<span class="goKarde"></span></a><form class="mobSearchToggle1" id="gi_search_hp" method="post" name="gi_search" onsubmit="return false;"><div class="col-md-12 col-sm-12 col-xs-12 pad0"><div class="col-lg-5 col-md-4 col-sm-12 col-xs-12 autoSuggestBox"><input autocomplete="off" class="form-control txtInput" id="gosuggest_inputL" placeholder="Enter City name, Area name or Hotel name" type="text"/><div class="col-md-12 col-sm-12 col-xs-12 autoWrap marginTM10"></div></div><div class="col-lg-3 col-md-3 col-sm-5 col-xs-12"><div class="fl width100 calenderOuterBox"><div class="col-md-6 col-xs-6 calenderInnerBox" id="ciHolder"><a class="width100 fl" data-date="" href="javascript:void(0)" id="start-date_hp"><i class="icon-calendar1 black ico26 fl padR5"></i> <span class="fl font13Dr padT5" id="ci_srp_day">Checkin</span></a><div class="jrdp_calendar_pos" id="start-calen_hp"></div></div><div class="col-md-6 col-xs-6 calenderInnerBox last" id="coHolder"><a class="width100 fl" data-date="" href="javascript:void(0)" id="end-date_hp"><i class="icon-calendar1 black ico26 fl padR5"></i> <span class="fl font13Dr padT5" id="co_srp_day">Checkout</span></a><div class="jrdp_calendar_pos" id="end-calen_hp"></div></div></div></div><div class="col-lg-2 col-md-3 col-sm-4 col-xs-12"><div class="paxWrapper"><a class="paxBox" href="javascript:void(0);" id="pax_link_hp"><i class="icon-user greyLt ico18 fl marginT2 padR5"></i> <span class="ico13 black padT5 fl" id="home_textHook">1 Guests / 1 Rooms</span> <i class="icon-arrow-down txtgrey ico18 padT5 fr"></i></a><div class="width100 fl paxWrapCont borderAll dn" id="paxcontainer_home"><div id="summaryContainer"></div><div id="editBox"></div><div class="width100 fl borderBtm marginB10 bg-greyLtest1" id="addButton"></div></div></div></div><div class="col-lg-2 col-md-2 col-sm-3 col-xs-12 marginB10 goCamp"><button class="button orange large ipadButtonSpace width100" id="hm_srch" type="submit">Search<span class="goKarde"></span></button></div></div></form></div></div><div class="dn" id="template-placeholder"></div><script id="go_suggestions" type="text/template">
# 		<ul class="autoSuggestBoxList flt dn">
# 			<% _.each(list, function(item,count) { %>
# 				<li <% if(item.left.cityHead){ %> class="cityhead" <%}%> <% if(item.left.indent){ %>class="indent" <%}%> data-index="<%= count %>">
# 					<% if(item.left.cityHead){ %>
# 						<% if(item.meta.pageType == 'offers'){%>
# 							<div class="fl padR2 hidden-sm hidden-xs padT5">
# 						<i class="fl icon-city ico11"></i>
# 						<% } else { %>
# 							<div class="fl padR2 hidden-sm hidden-xs padR2 padT5">
# 							<i class="fl icon-city ico14"></i>
# 						<% } %>
# 						</div> <%}%>
# 						<% if(item.meta.context=='flights'){%>
# 							<% if (item.left.cityHead == false){ %>
# 								<% if(item.meta.pageType == 'offers'){%>
# 									<div class="fl hidden-sm  padT5 hidden-xs">
# 								<i class="fl icon-flights ico12"></i>
# 								<% } else { %>
# 									<div class="fl padT5 hidden-sm padR10 hidden-xs">
#  									<i class="fl icon-flights ico14"></i>
# 								<% } %>
#
# 							</div><%}%>
# 							<% if(item.meta.suggestType == 'multi'){%> <div class="dib marginL10 col-md-10 col-sm-12 col-xs-12 pad0 textOverflow"><% } %>
# 							<% if(item.meta.pageType == 'offers'){%> <div class="dib marginL10 col-md-10 col-sm-12 col-xs-12 pad0 textOverflow"> <% } else { %><div class="dib col-md-11 col-sm-12 col-xs-12 pad0 textOverflow"><% } %>
# 								<div class="mainTxt clearfix">
# 									<span> <%= item.left.mainTxt %> </span> <span class="txtTransUpper ico14 greyLt">(<%= item.right.span %>)</span>
# 								</div>
# 								<% if(item.meta.suggestType == 'multi'){%>
# 									<div class="fl auto-ctryMult-ellip auto-ctryAir-ellip padT2">
# 								<% } else { %>
#  									<div class="fl auto-ctryAir-ellip mobEllipsis padT2">
# 								<% } %>
# 										<span class="clearfix">
# 											<small class="font12Lt"> <%= item.left.subTxtSpan %></small>
# 										</span>
#
# 									</div>
# 								<span class="fr">
# 									<% if(item.meta.pageType == 'offers'){%>
# 										<small class="font12Lt vMid padR5 dib"><%= item.left.subTextCName %></small>
# 									<% } else { %>
# 										<small class="font12Lt vMid padR5 dib"><%= item.left.subTxtSmall %></small>
# 									<% } %>
# 									<span class="flag-sprt vMid dib <%= item.left.subTextCName.toLowerCase() %>"></span>
# 								</span>
# 								<span class="clearfix">&nbsp;</span>
#
# 								<% if(item.left.dis && item.left.cityNameDis) {%>
# 										<span class="clearfix">
# 											<small class="font12Lt"> <span class="fb">(<%= Math.floor(item.left.dis) %></span> KMs from <span class="fb"><%= item.left.cityNameDis %></span>)</small>
# 										</span>
# 									<% } %>
# 							</div>
# 						<% } else { %>
# 							<div class="dib col-md-8 col-sm-8 pad0 <%if(item.meta.context){ %> col-xs-8 <% }else{ %>col-xs-12<% } %> <%if(item.meta.context=='flights'){ %> textOverflow <% } %>">
# 								<div class="mainTxt">
# 									<span><%= item.left.mainTxt %></span><% if(item.left.subTxtSpan){ %>
# 										<span class=""> &ndash; <%= item.left.subTxtSpan %></span>
# 										<% }else if(item.left.subTxtSmall){ %>
# 											<small class="font11Lt"><%= item.left.subTxtSmall %></small>
# 										<% } %>
# 								</div>
# 							</div>
# 						<% } %>
# 						<% if(item.meta.context!='flights'){%>
# 							<div class="col-md-4 col-sm-4 pad0 <%if(item.meta.context){ %> col-xs-4 <% }else{ %>col-xs-12<% } %>">
# 								<div class="fr width100">
# 									<% if(item.right.rating){%>
# 										<div class="fl">
# 											<div class="autoGoRating fl">
# 												<i class="icon-reverse-go ico15 orange fl"></i>
# 												<small class="fl padL5 padT2"><b><%= item.right.rating%></b>
# 													<span class="font11Lt">/5</span>
# 												</small>
# 											</div>
# 											<% if(item.right.reviewCount){ %>
# 												<small class="autoReviewers  padT2 fl width100">
# 													<span><%=item.right.reviewCount%></span> <span>Reviews</span>
# 												</small>
# 											<% } %>
# 										</div>
# 									<% } %>
#
# 									<% if(item.right.span){%>
# 									<% } else if(item.right.group){%>
# 										<% if(item.right.group.span){%>
# 											<span class="statusTag auto txtLeft"><%=item.right.group.span%></span>
# 										<% } %>
# 										<i class="ht_bgAutoSuggest ht_<%= item.right.group.type %> fr"></i>
# 										<small class="margin5 dib pad3 fr"><%= item.right.group.type %></small>
# 									<% } %>
# 								</div>
# 							</div>
# 						<% } %>
# 					</li>
# 				<% }); %>
# 			</ul>
# 		</script><script id="go_suggestions_error" type="text/template">
# 			<ul class="autoSuggestBoxList dn">
# 				<li> No matching result found.</li>
# 			</ul>
# 		</script><script id="pax_select" type="text/template">
#     <div class="widgetUserBlock fl <%=val.containerClass%>">
#         <label class="ico13 db padB5"><span><%=val.label%></span><small class="font10Lt db padT3"> <%=val.subLabel%></small></label>
#         <div class="customSelect">
#             <select <%if(val.react){ %> class="hasChild" id="<%=val.id%>" <% } %> name="<%=val.label.replace(' ','')%>">
#             <% for(var i=val.min;i<=val.max;i++){ %>
#             <option value="<%=i%>" <%if(val.value==i){ %>selected<% } %>><%=i%></option>
#             <% } %>
#             </select>
#         </div>
#     </div>
# </script><script id="pax_li" type="text/template">
#     <li class="roomRow">
#         <% if(config.boxHeading.visible){ %>
#         <h4 class="padTB5"><%=config.boxHeading.label%>
#             <% if(config.boxHeading.useIndex){ %>
#             <%=++config.boxHeading.index%>
#             <% } %>
#         </h4>
#         <%}%>
#         <% _.each(entity, function(person,key){ %>
#         <% if(person.visible){ %>
#         <%=renderSelect({val:person})%>
#         <%if(person.childConfig){ %>
#         <%for(var z=1;z<=person.value;z++){ %>
#         <%=renderSelect({val:person.childConfig[z-1]})%>
#         <%};%>
#         <%}%>
#         <%}%>
#         <% }); %>
#     </li>
# </script><script id="pax_template" type="text/template">
#     <div class="paxMobile dn paxContainer">
#         <a class="icon-cancel-circle fr marginT10 marginR10 fr greyDr mobdn" id="pax_close" href="javascript:void(0);"></a>
#         <ul>
#             <% _.each(config.entities, function(entity,idx){ %>
#             <%=renderLi({config:config,entity:entity,renderSelect:renderSelect})%>
#             <% }); %>
#
#             <% if(config.actionLinks.visible){ %>
#             <li class="fl txtCenter">
#                 <a class="fl ico16 pad15" href="javascript:void(0)" id="add">Add <%=config.actionLinks.textToAppend%></a>
#                 <a class="fl ico16 pad15 dn" href="javascript:void(0)" id="remove">Remove <%=config.actionLinks.textToAppend%></a>
#             </li>
#             <% }%>
#         </ul>
#     </div>
# </script><script id="summaryTemplate" type="text/template">
#
# 	<%for(var i=0; i<roomObject.roomconfig.length; i++){%>
#
# 		<div class="width100 fl posRel borderBtm summary" data-serial="<%=i+1%>">
#
# 			<div class="rowIcons nClick">
# 				<a class="icon-edit fl greyLt ico16 pad5 nClick" href="javascript:void(0);"></a>
# 				<%if(roomObject.roomconfig.length != 1){%>
# 					<a class="icon-close1 fl pad5 red nClick" href="javascript:void(0);" data-close="true"></a>
# 				<% } %>
# 			</div>
# 			<div class="userselected fl width100 nClick">
# 				<span class="fl ico14 pad10 grey lh1-2 bg-greyLtest1 fb nClick">Room <%=i+1%></span>
# 				<span class="fl pad10 tipLeft nClick"><%=roomObject.roomconfig[i].adult%> <%=roomObject.roomconfig[i].adultTag%> / <%=roomObject.roomconfig[i].children%> <%=roomObject.roomconfig[i].childTag%></span>
# 			</div>
#
# 		</div>
#
# 	<% } %>
#
# </script><script id="editTemplate" type="text/template">
#
# 		<div class="width100 fl posRel borderBtm">
# 			<div class="rowIcons">
# 				<a class="icon-close1 fl pad5 red nClick" href="javascript:void(0);" id="editClose"></a>
# 			</div>
# 			<div class="useredit fl width100 pad10" id="edtHook" data-mode= "<%=mode%>" data-serial = "<%=rmnumber + 1%>">
# 				<h4 class="padTB5 ico14 grey lh1-2">Room <%=rmnumber + 1%></h4>
# 				<div class="widgetUserBlock fl " ele="adult">
# 			        <label class="ico13 db padB5"><span>Adult</span><small class="font10Lt db padT3"> (12+ yrs)</small></label>
# 			        <div class="customSelect">
# 			            <select name="Adult">
# 			            <%for(var x=1; x<5; x++ ){%>
# 			            	<option value="<%=x%>"
# 			            		<% if(x == adult) { %>
# 			            			selected="selected"
# 					            <% } %>
# 					         ><%=x%></option>
# 					     <% } %>
# 			            </select>
# 			        </div>
# 			    </div>
# 				<div class="widgetUserBlock fl " ele="children">
# 			        <label class="ico13 db padB5"><span>Children</span><small class="font10Lt db padT3"> (2-12 yrs)</small></label>
# 			        <div class="customSelect">
# 			            <select class="hasChild" id="children" name="children">
# 			            	<%for(var x=0; x<3; x++ ){%>
# 				            	<option value="<%=x%>"
# 				            		<% if(x == children) { %>
# 				            			selected="selected"
# 						            <% } %>
# 						         ><%=x%></option>
# 						     <% } %>
# 			            </select>
# 			        </div>
# 			    </div>
# 			    <div class="widgetUserBlock fl children <% if(!age1){ %> dn <% } %>" id="childBox1" ele="age1">
# 					<label class="ico13 db padB5"><span>Child 1</span><small class="font10Lt db padT3"> Select age</small></label>
# 			        <div class="customSelect">
# 			            <select name="Child1">
#
# 			            	<%for(var x=1; x<13; x++ ){%>
# 				            	<option value="<%=x%>"
# 				            		<% if(x == age1) { %>
# 				            			selected="selected"
# 						            <% } %>
# 						         ><%=x%></option>
# 						     <% } %>
#
# 			            </select>
# 			        </div>
# 			    </div>
# 			    <div class="widgetUserBlock fl children <% if(!age2){ %> dn <% } %>" id="childBox2" ele="age2">
# 					<label class="ico13 db padB5"><span>Child 2</span><small class="font10Lt db padT3"> Select age</small></label>
# 			        <div class="customSelect">
# 			            <select name="Child2">
#
# 				            <%for(var x=1; x<13; x++ ){%>
# 				            	<option value="<%=x%>"
# 				            		<% if(x == age2) { %>
# 				            			selected="selected"
# 						            <% } %>
# 						         ><%=x%></option>
# 						     <% } %>
#
# 			            </select>
# 			        </div>
# 			    </div>
# 		    </div>
# 	    </div>
#
# </script><script id="addTemplate" type="text/template">
#
# 	<%if(roomObject.roomconfig.length < 6){%>
# 		<a class="button outlineBlue fl margin5 txtTransUpper nClick" id="addRoom">+ Add Room</a>
# 	<% } else {%>
# 		<div class="width100 fl pad10 txtCenter borderBtm">
# 			<span class="width100 fl grey ico12 lh1-2">Need more rooms? Contact our travel expert on</span>
# 			<span class="width100 dib padT2 ico13">
# 				<span class="dib blue">1800 267 9999</span>
# 				<span class="dib grey padL4 padR4">or</span>
# 				<span class="dib blue">
# 					<a href="mailto:holidays@goibibo.com">holidays@goibibo.com</a>
# 				</span>
# 			</span>
# 		</div>
# 	<% } %>
# 	<button class="button blue fr margin5 xsmall nClick" id="editSubmit">Done</button>
#
# </script><script>
# 		proto = window.location.protocol;
# 	</script><script src="//goibibo.ibcdn.com/hotelsnew/static/js/widget_hotels-lib-min.1483561221.js" type="text/javascript"></script></div> <div class="clear"></div><div class="width100 fl greyBg"><div class="seoPageHtl marginAuto"><div class="breadcrumb marginTB5 lh1-5 col-md-9 col-sm-9 col-xs-12 padL15" style="margin-bottom: -5px;"><div class="fl" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><a href="/" itemprop="url" title="Home"><span itemprop="title">Goibibo</span></a>→ </div><div class="fl" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><a href="/hotels/" itemprop="url" title="Hotel Booking"><span itemprop="title">Hotel Booking</span></a>→ </div><div class="fl" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><a href="/hotels/india/" itemprop="url" title="Hotels in India"><span itemprop="title">India</span></a> → </div><div class="fl"><span>Shimla</span></div></div></div></div><div class="clear"></div><div class="width100 fl greyBg"><div class="seoPageHtl marginAuto"><div class="col-md-12 col-sm-12 col-xs-12 padLR10"><div class="width100 fl"><a class="posRel button showFiltr orange xsmall fr ipaddb mobdn dn" onclick="">Hide Filter</a><section class="col-md-9 col-sm-12 col-xs-12 fr wid80 pad0" style="width: 75% !important;"><div id="price-loader"><div class="price-loader-text">Fetching best deals for you<div class="typing_loader"></div></div></div><div style="clear: both;"></div><div class="col-md-12 col-sm-12 col-xs-12 marginB10 marginT10 dn" id="search-head1"><div class="fl font15">Current Search Filters</div><div id="current-search-btns"></div></div><div class="dn" id="add-more-loc-head"><div class="txt-cap fl marginL20" id="add-more-loc"><a class="filter-btn txt-cap" onclick="HotelCityApp.searchEvents.focusLocationFilter()" style="background-color: #f26722;" title="Add More Locations">+ Add More</a></div></div><div class="dn fl marginL5 width100 marginT5" id="sort-div"><div class="sort-tab sort-tab-active" id="popularity" onclick="HotelCityApp.searchEvents.processSort('popularity')" title="Sort by popularity">Popularity</div><div class="sort-tab" id="price-low" onclick="HotelCityApp.searchEvents.processSort('price-low')" title="Sort by price low to high">Price Low To High</div><div class="sort-tab" id="price-high" onclick="HotelCityApp.searchEvents.processSort('price-high')" title="Sort by price high to low">Price High To Low</div><div class="col-md-3 col-sm-3 col-xs-12 "><select class=" listdropdown locDropDown dn" id="sort-type" onchange="HotelCityApp.searchEvents.multiLocationSort()"></select></div></div><div style="clear:both;"></div><div class="width100 fl padB5" id="outerSrpLocContainer" style="margin-top:10px;padding-left:5px; padding-right:5px;"><div class="searchBlk posRel" id="srpLocContainer" style="background: rgb(255, 255, 255); border-width: 0px 1px 1px; border-top-style: initial; border-right-style: solid; border-bottom-style: solid; border-left-style: solid; border-top-color: initial; border-right-color: rgb(230, 230, 230); border-bottom-color: rgb(230, 230, 230); border-left-color: rgb(230, 230, 230); border-image: initial;"><span class="fl ico16 black padT4 marginTB5" style="width: 260px;"><i class="icon-area ico18 fl marginR5 borderBtm redDr padR4"></i>Find By Location or Address</span><div class="fl posRel" style="width:500px;"><div class="fl padL20 autoSuggestBox" style="width:100%;"><div class="fl marginTB5 posRel" id="location-search-div" style="width:100%;"></div></div></div><span class="offerTag"><span class="dib">New</span></span></div></div><div style="clear:both;"></div><div style="clear:both;"></div><div class="width100 fl pad5 padding-top-0" id="main-page-div" style="padding-top: 0px;margin-top:-18px;"><div style="width: 100%; float: left; margin-top: 10px; margin-bottom: 10px;"><div class="col-md-12 col-sm-12 col-xs-12 marginT10" id="all-hotels-container"><div class="col-md-9 col-sm-12 col-xs-12"><i class="fl icon-hotels blue ico28"></i><h1 cla ...
# <div id="htl-<%= hotel_data.id %>" class="width100 fl htlListSeo hotel-tile-srp-container hotel-tile-srp-container-template"  onclick="window.open('<%= hotel_data.url %>'); event.stopPropagation();">
#     <div class="hotel-tile-srp-container-img-container">
#         <% if (hotel_data.bkfstOverlay && hotel_data.bkfstOverlay === 1) {%>
#             <div class="htl-tile-free-bkfst-overlay" style="display: block;">
#                 <div class="text-label">Free breakfast</div>
#                 <div class="label-decor"></div>
#             </div>
#         <% } %>
#         <div class="hotel-tile-srp-container-title-image">
#             <img class="lazy" src="<%= hotel_data.img %>" ori="<%= hotel_data.img %>" id="htl-tile-main-image-<%= hotel_data.id %>">
#         </div>
#         <% if (hotel_data.img_gallery.length > 1) {%>
#             <ul class="hotel-tile-srp-container-image-gallery">
#                 <% for (var idx in hotel_data.img_gallery) {%>
#                     <li>
#                         <% if ((hotel_data.img_gallery.length-idx) === 1) {%>
#                             <div style="cursor:pointer !important;">
#                                 VIEW ALL
#                             </div>
#                         <% } %>
#                         <img src="<%=hotel_data.img_gallery[idx].th%>" fsi="<%=hotel_data.img_gallery[idx].fs%>" class="lazy htl-tile-gallery-image" htl="<%= hotel_data.id %>" onmouseenter="onImageHover(this, 'in')" onmouseleave="onImageHover(this, 'out')">
#                     </li>
#                 <% } %>
#             </ul>
#         <% } %>
#     </div>
#     <div class="hotel-tile-srp-container-content-container">
# 		<ul class="hotel-content-container-top-hinged-list">
# 			<li>
# 				<div style="display: inline-block; float:left;">
#                     <% for (var i=0; i<hotel_data.star_rating; i++) {%>
# 					    <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i>
#                     <% } %>
# 					<span style="padding: 2px; border: 1px solid #e5edf6; border-radius: 2px; margin-left: 5px; color: #4f525a">HOTEL</span>
# 				</div>
#                 <div>
#                  <% if  (hotel_data.ugc_src == "ta" && hotel_data.ta_rating != "") { %>
#                          <div style="background-color: green; height: 20px; -webkit-border-radius:5px; float:right; margin-left:8px;">
#                              <span >
#                              <img src="https://gos3.ibcdn.com/trip_adviser-1557838494.png" alt="Trip Advisor Logo" style="max-width: 25.5px; max-height: 12px; margin: 5px 0px 5px 5px;">
#                              <span class="ico16" style="color:#ffffff;  margin: 4px 7px 3px 5px; font-size:12px; float:right;">
#                                  <strong> <%= hotel_data.ta_rating %> </strong> /5 </span>
#                              </span>
#                          </div>
#                     <% } %>
#                 </div>
# 				<div style="float: right; margin-top:3px;">
#                     <% if (hotel_data.review_count) {%>
#                         <span><%= hotel_data.review_count %> reviews</span>
#                     <% } %>
#                     <% if (hotel_data.ugc_src === "gir" && hotel_block_config.go_rating === true && hotel_data.go_rating != "" && hotel_data.go_rating > 0) {%>
#                         <span style="padding: 4px; background-color: <% if (hotel_data.go_rating >= 4.0){ %>#7ccf50<% } else if (hotel_data.go_rating >= 3.0 ){ %>#afd600<% } else { %>#fdaf15<% } %>; color: white; border-radius: 2px; margin-left: 5px;"><%= hotel_data.go_rating %>/5</span>
#                     <% } %>
#                     <% if (!(hotel_data.review_count || (hotel_data.ugc_src === "gir" && hotel_block_config.go_rating === true && hotel_data.go_rating != "" && hotel_data.go_rating > 0) || (hotel_data.ugc_src === "ta" && hotel_block_config.ta_rating === true && hotel_data.ta_rating != "" && hotel_data.ta_rating > 0))) {%>
#                     <span>New Listing</span>
#                     <span style="padding: 4px 6px;background-color: #1aabb8;color: white;border-radius: 2px;">NEW</span>
#                     <% } %>
#                 </div>
# 			</li>
# 			<li>
#                 <a href="<%= hotel_data.url %>" target="_blank" onclick="event.stopPropagation();"><p style="font-size: 18px; font-weight: bolder; color: #141823;font-family: 'Quicksand', sans-serif;  margin-top:17px;"><%= hotel_data.name %></p></a>
#             </li>
# 			<% if (hotel_data.location) {%>
#             <li style="color: #2276e3;">
#                 <p><%= hotel_data.location %></p>
#             </li>
#             <% } %>
# 		</ul>
# 		<ul class="hotel-content-container-bottom-hinged-list">
# 			<li>
# 				<i class="icon-ranking" style="font-size: 15px; margin-right: 3px; color: #fdba00"></i>
#                 <% if (hotel_data.topTag && hotel_data.topTag != '') {%>
#                     <span class="htl-tile-top-tag-text" style="color: #2276e3; cursor: pointer"><%= hotel_data.topTag %></span>
#                 <% } else if (hotel_data.reco_percent && hotel_data.reco_percent != '0') {%>
#                     <span class="htl-tile-top-tag-text" style="color: #2276e3; cursor: pointer"><%= hotel_data.reco_percent %>% Guests recommend this hotel</span>
#                 <% } else { %>
#                     <span class="htl-tile-top-tag-text" style="color: #2276e3; cursor: pointer"></span>
#                 <% } %>
# 			</li>
#             <% if (hotel_data.locPin && hotel_data.locPin != "") {%>
#                 <li class="hotel-content-container-li-loc-usp" style="display: block;">
#                     <i class="icon-persuation-generic" style="font-size: 15px; margin-right: 3px;"></i>
#                     <span class="htl-tile-loc-pin-text"><%= hotel_data.locPin %></span>
#                 </li>
#             <% } %>
#             <% if (hotel_data.htl_amen_list) {%>
#                 <li style="" class="htl-tile-amenities-list">
#                     <% if (hotel_data.htl_amen_list.room_service === true) {%>
#                         <div style="">
#                             <i class="icon-service2" style=""></i>
#                             <span>Room Service</span>
#                         </div>
#                     <% } %>
#                     <% if (hotel_data.htl_amen_list.internet === true) {%>
#                         <div style="">
#                             <i class="icon-wifi-free" style=""></i>
#                             <span>Free Internet</span>
#                         </div>
#                     <% } %>
#                     <% if (hotel_data.htl_amen_list.restaurant === true) {%>
#                         <div style="">
#                             <i class="icon-restaurant2" style=""></i>
#                             <span>Restaurant/Coffee Shop</span>
#                         </div>
#                     <% } %>
#                     <% if (hotel_data.htl_amen_list.swimming_pool === true) {%>
#                         <div style="">
#                             <i class="icon-swimming2" style=""></i>
#                             <span>Swimming Pool</span>
#                         </div>
#                     <% } %>
#                 <% if (hotel_data.htl_rem_amen_cnt > 0) {%>
#                     <span style="color: #2276e3; cursor: pointer">+ <%= hotel_data.htl_rem_amen_cnt %> More</span>
#                 <% } %>
#                 </li>
#             <% } %>
#
# 			<% if (hotel_data.couple_friendly && hotel_data.couple_friendly === 1) {%>
#                 <li style="color: #ff3a5c;">
#                     <i class="icon-couple-man-woman" style="font-size: 15px; margin-right: 3px;"></i>
#                     <span>Couple Friendly</span>
#                 </li>
#             <% } %>
#             <% if (hotel_data.stlDeal && hotel_data.stlDeal != "") {%>
# 			<li style="color: #861388;">
# 				<span>
# 					<i class="icon-steal-deal" style="font-size: 15px; margin-right: 3px;"></i>
# 					<!--<i class="icon-path" style="font-size: 15px; margin-right: 3px;"></i>-->
# 				</span>
# 				<span style="padding: 3px 8px; border-radius: 10px; background-color: #f2e7f3;">Steal Deal</span>
#                 <span style="margin-left: 5px; color: black;" class="htl-tile-steal-deal-text"><%= hotel_data.stlDeal %></span>
# 			</li>
#             <% } %>
# 			<!--<li style="border-radius: 4px; background-color: #eef4fd; margin-top: 4px;">
# 				 <span style="background-image: linear-gradient(285deg, #cf125d, #ff3478); color: white; padding: 2px 8px; border-radius: 2px; margin-right: 5px;">
#                     GIFT CARD
#                 </span>
#                 <span>1500 TAJ Experiences card for use at any Taj</span>
#                 <span style="display: inline-block; margin-left: 5px; color: #2276e3;">+More</span>
# 			</li>
# 			<li style="border-radius: 4px;background-color: #eef4fd;">
# 				<span style="background-image: linear-gradient(107deg, #1149f3, #00c3ff); color: white; padding: 2px 8px; border-radius: 2px; margin-right: 5px;">SPL DEAL</span>
#                 <span>Free 30min SPA session</span>
#                 <span style="display: inline-block; margin-left: 5px; color: #2276e3;">+More</span>
# 			</li>-->
# 		</ul>
# 	</div>
# 		<div style="width: 200px; margin: 12px 10px 0px 6px; display: inline-block; border-left: 1px solid #e5edf6; height: 256px; position: absolute; right: 0px; font-size: 12px; color: #4f525a;">
#             <% if (hotel_data.bannerText && hotel_data.bannerText != "") {%>
#                 <div style="font-size: 12px; font-weight: bold; position: absolute; top: -24px; right: 10px;">
#                     <div style="display: inline-block; width: 0px; height: 0px; border-right: 5px solid #898b91; border-left: 5px solid transparent; border-top: 5px solid transparent; border-bottom: 5px solid #898b91; margin: -9px 0px 0px 0px;"></div>
#                     <div class="htl-tile-banner-text-div" style="margin: 0px -4px; display: inline-block; padding: 1px 10px; background-image: linear-gradient(284deg, #adaeb2, #34393a); color: white; width: max-content; border-bottom-right-radius: 2px; border-bottom-left-radius: 2px; height: 17px;">
#                         <%= hotel_data.bannerText %>
#                     </div>
#                     <div style="display: inline-block; width: 0px; height: 0px; border-right: 5px solid transparent; border-left: 5px solid #898b91; border-top: 5px solid transparent; border-bottom: 5px solid #898b91; margin: -9px 0px 0px 0px;"></div>
#                 </div>
#             <% } %>
#             <% if (hotel_data.fcpText && hotel_data.fcpText != "") {%>
#                 <div style="background-color: aliceblue; width: 182px; text-align: center; border-radius: 10px; margin: 5px auto;">
#                     <span style="color: #2bac36;" class="htl-tile-fcp-text"><%= hotel_data.fcpText %></span>
#                 </div>
#             <% } %>
# 			<div style="text-align: right; position: absolute; top: 75px; right: 0px;">
#                 <ul>
#                     <li style="height: 27px; display: none" class="htl-tile-prc-loader">
#                         <div class="typing_loader" style="float: unset;"></div>
#                     </li>
#                     <% if (hotel_data.so) { %>
#                     <li style="font-size: 18px;color: black;font-weight: bold;" class="htl-tile-sold-out-label">SOLD OUT</li>
#                     <% } else { %>
#                         <% if (hotel_data.oprc) { %>
#                             <li style="text-decoration: line-through;" class="htl-tile-non-discount-prc">
#                                 <i class="icon-rupee rupee-icon" style="font-size: 12px;"></i><%= hotel_data.oprc %>
#                             </li>
#                         <% } %>
#                         <% if (hotel_block_config.price == true && hotel_data.booking_price != "" && hotel_data.booking_price > 0) {%>
#                         <li style="font-size: 22px; color: black; font-weight: bold;" class="htl-tile-discount-prc">
#                             <i class="icon-rupee rupee-icon" style="font-size: 16px;"></i><%= hotel_data.booking_price %>
#                         </li>
#                         <li>per room/night</li>
#                         <% } %>
#                     <% } %>
#                     <% if (hotel_data.offersCount && hotel_data.offersCount > 0) {%>
#                         <li style="background-color: #fef8e5; color: #8e5a14;">
#                             <i class="icon-gocash-plus" style="font-size: 15px; color: #fdba00;"></i>
#                             <span style="margin: 5px;" class="htl-tile-offers-count">+<%= hotel_data.offersCount %> offers</span>
#                         </li>
#                     <% } %>
#                 </ul>
#             </div>
# 			<div style="text-align: right; position: absolute; bottom: 0px; right: 0px;">
# 			<p>
#                 <button onclick="window.open('<%= hotel_data.url %>'); event.stopPropagation();" style="padding: 0px 15px; height: 35px; font-size: 16px; font-weight: bold; background-color: #ff6d38; color: white; border: none; border-radius: 4px;">BOOK NOW</button>
#             </p>
# 			<p style="color: #ff3a5c; margin: 5px 0px;" class="htl-tile-last-opt"><%= hotel_data.lastTag %></p>
# 		</div>
# 	</div>
# </div>
# </script><script type="text/javascript">
#     pageType = "main_city";
#     lat = 31.1048145;
#     lon = 77.1734033;
#     city_name = "Shimla";
#     city_id = "1449073512565742573";
#     currentHost = "voyager.goibibo.com";
#     allHotelsData = {};
#     allHermesData = {};
#     priortizedHotelIds = ["1953288179585905793", "8833337098196373625", "8269876364174459846", "3572747602679325734", "8689972586923762049", "6672745452248732216", "6025344523708922203", "7393074725561129529", "3839912992465323263", "3972438790911577064", "4098314048100585768", "2233447007757316171", "5035039896502133936", "5937000712051274523", "2866704395127249073", "5884068027977565082", "1840384582126692352", "323485704258300318", "1393359224681702820", "7764296370836633209", "3369629136120637174", "7020693384946872874", "3816266321977187845", "6990212052173557682", "7638770112293463188", "128385603999652492", "1416809721456220441", "2162192616761384325", "7325499651138989507", "3335398829407382929", "6219607130473533931", "2739295705892554451", "8474581889215348193", "5231879829398869129", "7353626981578665283", "8970639597040984344", "3882623631711451075", "4132340955783784970", "3896020271608532948", "4270473854139036574", "5780866766883362606", "2599470256323068721", "6320051737019986277", "5490941750412315350", "5296367711267092596", "2805366558683576001", "4430673730811884875", "2264529271423614038", "736425363845889208", "4603401151261891684", "7814236958554289102", "8351599671021854493", "4508640287885363792", "3399253684009777930", "3027796615243425553", "2724952418138578682", "2107192302665896428", "1449963254462068403", "5226089337385666229", "894231724514839263", "584566816388311754", "6582857422120530423", "7481785841346701430", "2311532179286816502", "9132401001922838353", "7084782206685124872", "6133961403167948671", "3122448041086811088", "8926765172084866206", "3443781901865797711", "3754327080378501221", "2928012005302227019", "6338974406996106684", "2229265802353322488", "4263883128813072657", "4917911572303765618", "3861576060139081035", "4899085585014300339", "8871636629353578439", "912580186579670511", "8964443484484594838", "2664474765517349026", "909705468737555211", "2610176761536433856", "3464718552129675150", "7899035935330867108", "919875262476689975", "171304619761356672", "2722835239411954969", "7905287361581001648", "3687170931724471022", "2300615405345761887", "3451763848511086302", "4354553821466644453", "5513812841692411131", "4517767613702610692", "3469858137133532554", "2152028404001390089", "2812730581603329307", "9186820163445991802", "4300718848124328777", "5860465706634300818", "1700844874317530146", "3819013212308245534", "4303914596620081984", "7131765730681137", "953909913787486485", "6997953323380690605", "7734814358727015024", "1978269669167048330", "4205623634279217572", "7847646803364735412", "3739938819293799336", "1367466367395691201", "994303966553207628", "7798423028228869013", "6956831556773249795", "4637820275887385447", "8468634016855667632", "6992592702406338805", "1770849336303147771", "5331096070916179602", "6467213783512500824", "6655724272836236676", "1566559072649220797", "7459202266562597344", "6045723022250842323", "3436642880906825535", "5364825111301595548", "881400959191619265", "1769649039584828409", "530223076072755170", "8685198985434721970", "5773497737550006529", "6633597274498559323", "5362282077951121683", "6676802961546271766", "2668930289000053794", "8875423732210384017", "5243132854159319848", "8798437038915809316", "6682502713314075020", "8005471583658990261", "9169859037899788510", "4440839263471650198", "828693841156692241", "8769076834385575803", "7029152240984219419", "7330523828712648537", "3834715834113494333", "4046044598960677877", "926642424978302912", "4374345064866095428", "5254749793973848546", "7723386232244357332", "4713243126660706589", "486279457395787859", "552382346639660862", "7944004809002395615", "5914857255039358309", "6950680197781245899", "1085766080464256343", "5689221843742874524", "6523455857485537428", "441747302991298674", "4851345145442551410", "9069816741563323817", "4805667441470141203", "5552266556689170547", "9087118454481438872", "1545193929232907419", "2572441171192798856", "6961675676232961072", "703198957683152 ...
#     priortizedHotelIdsSlice = ["1953288179585905793", "8833337098196373625", "8269876364174459846", "3572747602679325734", "8689972586923762049", "6672745452248732216", "6025344523708922203", "7393074725561129529", "3839912992465323263", "3972438790911577064", "7543907359980632827", "5602436240729783016", "2370305609510851950", "2865955665055037007", "3451763848511086302", "2599470256323068721", "5226089337385666229", "1416809721456220441", "6219607130473533931"];
#
#     recentlyReviewedHotelIds = ["5226089337385666229", "1416809721456220441", "6219607130473533931"];
#     recentlyBookedHotelIds = ["2865955665055037007", "3451763848511086302", "2599470256323068721"];
#     allHotelIds = priortizedHotelIds.concat(recentlyReviewedHotelIds)
#     allHotelIds = allHotelIds.concat(recentlyBookedHotelIds)
#     hotelAmenitiesNames = {"Free Internet": 112, "Outdoor Activities": 108, "CCTV surveillance": 119, "Dining": 120, "Internet": 105, "Conference Room": 125, "Travel Assistance": 109, "Power backup": 123, "Swimming Pool": 101, "Banquet hall": 124, "Clean Room": 115, "Indoor Entertainment": 111, "Front desk": 107, "Clean linen": 118, "Laundry Service": 110, "Business Services": 104, "Health-Spa": 106, "Parking Facility": 103, "Airport Transfer (on Demand)": 121, "Room Service": 113, "Restaurant/Coffee Shop": 102, "Pets allowed": 122, "Smoking Rooms Available": 116, "Spa": 114, "Clean Washroom": 117};
#     ugcAmenitiesMapping = {"vfm_rating": {"name": "Value for Money", "icon": "mnyIconMob"}, "fd_rating": {"name": "Food & Drinks", "icon": "fdIconMob"}, "loc_rating": {"name": "Location", "icon": "loctnIconMob"}, "sq_rating": {"name": "Service & Quality", "icon": "qltyIconMob"}, "cleanliness_rating": {"name": "Cleanliness", "icon": "clnIconMob"}, "amenities_rating": {"name": "Amenities", "icon": "amntyIconMob"}};
#     location_area_name = "";
#     hotel_city_name = "shimla";
#     chain_code = "";
#
#     star_rating = "";
#
#     property_type = "Hotels";
#     recommendedHotelIds = []
#     showLocationBox = true
#
#     location_id = ""
#     currentPage = 1;
#     loadLock = false;
#     locations = [];
#     landmarks = [];
#     contextTotalPages = 0;
#     distanceMapData = {};
#     collecName = "";
#     collecId = "";
#     segmentsRedirectSlugMap = {"763": {"url": "https://www.goibibo.com/hotels/hotels-for-couples-in-shimla-cl/", "collec_name": "dh_cf", "collec_id": "763"}, "766": {"url": "https://www.goibibo.com/hotels/business-hotels-in-shimla-cl/", "collec_name": "dh_business_friendly", "collec_id": "766"}, "5421": {"url": "https://www.goibibo.com/hotels/resorts-in-shimla-cl/", "collec_name": "resorts_landmark_location", "collec_id": "5421"}, "749": {"url": "https://www.goibibo.com/hotels/gostays-in-shimla-cl/", "collec_name": "dh_gostays", "collec_id": "749"}};
#
#     for (var id in segmentsRedirectSlugMap) {
#         url = segmentsRedirectSlugMap[id]["url"]
#         if (url == "https://www.goibibo.com/hotels/hotels-in-shimla-ct/") {
#             collecName = segmentsRedirectSlugMap[id]['collec_name'];
#             collecId = segmentsRedirectSlugMap[id]['collec_id'];
# ...
#
#
#         chains = [{"url": "/hotels/hotels-in-shimla/oyo-rooms-oyorms-chain/", "count": 193, "img": "https://gos3.ibcdn.com/OYO_Rooms-1424340877.jpg", "n": "OYO Rooms"}, {"url": "/hotels/hotels-in-shimla/hptdc-hptdc-chain/", "count": 4, "img": "", "n": "HPTDC"}, {"url": "/hotels/hotels-in-shimla/leisure-hotels-leisurehtl-chain/", "count": 3, "img": "https://gos3.ibcdn.com/LeisureHotels-1423739810.jpg", "n": "Leisure Hotels"}, {"url": "/hotels/hotels-in-shimla/club-mahindra-group-clubmhndrg-chain/", "count": 3, "img": "https://gos3.ibcdn.com/Club_Mahindra_Group-1424342342.png", "n": "Club Mahindra Group"}];
#
#
#     var enhancedEcommerceEvent = {};
#     var pos = 1;
#
#         var event_info = {}
#
#     var category = "hotels-domestic";
#     var end_page = 10;
#     var start_page = 1;
#     var subCategory = "domestic";
#
#     var hotelSoContext = {"hid": null};
#     var recommendedHotels = [];
#     enhancedEcommerceEvent['event'] = "enhanced-ecommerce-srp";
#     enhancedEcommerceEvent['path'] = window.location.href;
#     enhancedEcommerceEvent['client'] = "client";
#     enhancedEcommerceEvent['ecommerce'] = {"impressions":[]};
#     var roomString = "1-2_0";
#
#
#             enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Marigold Sarovar Portico","id":"5226089337385666229","brand":"","category":category,"price":4999,"variant":4,"position":pos,"list":ecommerceListType });
#             pos++;
#
#             enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Amritara The Zion Hotel","id":"1416809721456220441","brand":"","category":category,"price":4200,"variant":4,"position":pos,"list":ecommerceListType });
#             pos++;
#
#             enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Galleu Hill Resort","id":"6219607130473533931","brand":"","category":category,"price":2960,"variant":3,"position":pos,"list":ecommerceListType });
#             pos++;
#
#
#
#
#
#             enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Koti Resorts","id":"2865955665055037007","brand":"","category":category,"price":5500,"variant":4,"position":pos,"list":ecommerceListType });
#             pos++;
#
#             enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Hotel Chaman Palace","id":"3451763848511086302","brand":"","category":category,"price":1500,"variant":3,"position":pos,"list":ecommerceListType });
#             pos++;
#
#             enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Hotel Sidharath","id":"2599470256323068721","brand":"","category":category,"price":2800,"variant":3,"position":pos,"list":ecommerceListType });
#             pos++;
#
#
#
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Snow Valley Resorts","id":"1953288179585905793","brand":"","category":category,"price":3000,"variant":4,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Marina- Shimla First Designer Boutique Hotel","id":"8833337098196373625","brand":"","category":category,"price":7020,"variant":5,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Hotel Dalziel","id":"8269876364174459846","brand":"","category":category,"price":1470,"variant":3,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Hotel Combermere","id":"3572747602679325734","brand":"","category":category,"price":6150,"variant":4,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Hotel Shingar","id":"8689972586923762049","brand":"","category":category,"price":2850,"variant":3,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Shimla Havens Resort","id":"6672745452248732216","brand":"","category":category,"price":3025,"variant":4,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Rocky Knob ","id":"6025344523708922203","brand":"","category":category,"price":2700,"variant":3,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Hotel Baljees Regency","id":"7393074725561129529","brand":"","category":category,"price":2310,"variant":3,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Summit Thistle Villa Resort &amp; Spa","id":"3839912992465323263","brand":"","category":category,"price":1650,"variant":4,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Hotel Surya","id":"3972438790911577064","brand":"","category":category,"price":2376,"variant":3,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#
#
#
#     // get list of locations and landmark ids
#
#     locationIdsList = [];
#     landmarkIdsList = [];
#
#     for (var i = 0; i < locations.length; i++) {
#         locationIdsList.push(locations[i]['id'])
#     }
#     for (var i = 0; i < landmarks.length; i++) {
#         landmarkIdsList.push(landmarks[i]['id'])
#     }
# </script><script src="//voyager.goibibo.com/static/cache/js/7cf80432c671.js" type="text/javascript"></script><style type="text/css">.fotDPLink a { color: #b3b3b3; font-size: 12px; line-height: 1; float: left; margin-right: 5px; padding-bottom: 5px; } .greyLter { color: #b3b3b3; } .website-badge-Bottom{display:none!important;}</style><div class="footerBox mobdn posRel" style="z-index: 1;"><div class="website-badge-Bottom"></div><div class="marginAuto"><div class="col-md-12 col-sm-12 padB20"><ul class=" col-md-2 col-sm-3 footerLinks"><li class="txtTransUpper font12 greyDr fb padB10">our products</li><li><a href="/flight-schedule/">Flight Schedule</a></li><li><a href="/flights/city-to-city-airlines/">City Airline Routes</a></li><li><a href="/international-flights/">International Flights</a></li><li><a href="/hotels-international/">International Hotels</a></li><li><a href="/bus/">Bus Booking</a></li><li><a href="/airlines/">Domestic Airlines</a></li><li><a href="/hotels/hotels-in-india/">Hotels in India</a></li><li><a href="/hotels/">Hotel Booking</a></li><li><a href="/flights/cheap-flights/">Cheap Flights</a></li><li class="txtTransUpper font12 greyDr fb padB10 marginT15">Company</li><li><a href="/aboutus/">About Us</a></li><li><a href="/faqs/">FAQs</a></li><li><a href="/terms-and-conditions/">Terms &amp; Conditions</a></li><li><a href="/common/privacy/">Privacy</a></li><li><a href="/contactus/">Contact Us</a></li><li><a href="http://www.ibibo.com/">ibibo Group</a></li></ul><ul class="col-md-2 col-sm-3 footerLinks"><li class="txtTransUpper font12 greyDr fb padB10">Trending Hotel Cities</li><li><a href="//www.goibibo.com/hotels/hotels-in-goa-ct/">Hotels in Goa</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-delhi-ct/">Hotels in Delhi</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-mumbai-ct/">Hotels in Mumbai</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-bangalore-ct/">Hotels in Bangalore</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-hyderabad-ct/">Hotels in Hyderabad</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-chennai-ct/">Hotels in Chennai</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-jaipur-ct/">Hotels in Jaipur</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-pondicherry-ct/">Hotels in Pondicherry</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-agra-ct/">Hotels in Agra</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-puri-ct/">Hotels in Puri</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-indore-ct/">Hotels in Indore</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-lonavala-ct/">Hotels in Lonavala</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-mysore-ct/">Hotels in Mysore</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-ajmer-ct/">Hotels in Ajmer</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-bhubaneswar-ct/">Hotels in Bhubaneswar</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-ghaziabad-ct/">Hotels in Ghaziabad</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-jaisalmer-ct/">Hotels in Jaisalmer</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-darjeeling-ct/">Hotels in Darjeeling</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-shirdi-ct/">Hotels in Shirdi</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-ernakulam-ct/">Hotels in Ernakulam</a></li></ul><ul class="col-md-2 col-sm-3 footerLinks"><li class="txtTransUpper font12 greyDr fb padB10">Trending International Hotel Cities</li><li><a href="//www.goibibo.com/hotels/intl-hotels-in-dubai-ct/">Hotels in Dubai</a></li><li><a href="//www.goibibo.com/hotels/intl-hotels-in-bangkok-ct/">Hotels in Bangkok</a></li><li><a href="//www.goibibo.com/hotels/intl-hotels-in-phuket-ct/">Hotels in Phuket</a></li><li><a href="//www.goibibo.com/hotels/intl-hotels-in-pattaya-ct/">Hotels in Pattaya</a></li><li><a href="//www.goibibo.com/hotels/intl-hotels-in-singapore-ct/">Hotels in Singapore</a></li><li><a href="//www.goibibo.com/hotels/intl-ho ...
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer', 'GTM-NNFJ8WW' );</script><script type="text/javascript">
#     var _gaq = _gaq || {};
#     var dataLayer = dataLayer || {};
#     var gaDevice = "desktop";
#
# </script><script type="text/javascript">
#     function pushEventToGA(category,action,label){
#         if(_gaq && _gaq.push)
#         {
#             var eventData = (label && label!=null) ? ['_trackEvent', category, action, label] : ['_trackEvent', category, action];
#             _gaq.push(eventData);
#         }
#
#     }
# </script><script type="text/javascript">
#     function createCookie(name,value,time) {
#         if (time) {
#             var date = new Date();
#             date.setTime(date.getTime()+(time*1000));
#             var expires = "; expires="+date.toGMTString();
#         }
#         else var expires = "";
#         document.cookie = name+"="+value+expires+"; path=/";
#     }
#
#     function readCookie(name) {
#         var nameEQ = name + "=";
#         var ca = document.cookie.split(';');
#         for(var i=0;i < ca.length;i++) {
#             var c = ca[i];
#             while (c.charAt(0)==' ') c = c.substring(1,c.length);
#             if (c.indexOf(nameEQ) == 0) return c.substring(nameEQ.length,c.length);
#         }
#         return null;
#     }
#
#     function eraseCookie(name) {
#         createCookie(name,"",-1);
#     }
#
#
#     function setAppInstallWidget(){
#         $("#app-install-widget").html('<div class="mobileApp" style="background-color:#f7f7f7;padding:10px 5px;"><div class="fl crossTop" style="width:5%;margin-right:1%;"><a href="javascript:void(0);" onclick="$(\'#app-install-widget\').slideUp();"><img src="//goibibo.ibcdn.com/images/mobile/apparrow.png" style="width:14px;"></a></div><div class="fl" style="width:94%;margin-top:-5px;"><a href="https://go.onelink.me/2118851199?pid=SEO&c=SEO_Banners" id="appFlyer"><div class="fl" style="margin-right:12px; color:#737373;font-size:14px;line-height:22px;"><div style="font-size:22px; color:#000;"><div class="fl"><img src="//goibibo.ibcdn.com/images/mobile/go_icon.png"></div><div class="fl" style="margin-top:5px;margin-left:5px;">Goibibo <img src="//goibibo.ibcdn.com/images/mobile/android_stars.png"></div></div><div style="clear:both;"></div><p>For more discounts and better experience download goibibo app.<span style="border-radius:3px;float:none;background-color:#2e69b3;color:#fff;padding:5px 10px;margin-left:10px;">Install</span></p></div><div class="clearAll"></div></a></div><div class="clearAll"></div></div>');
#     }
#
#     $(window).load(function(){
#         var seobanner = true;
#         location.search.substr(1).split("&").forEach(function (item) {
#             tmp = item.split("=");
#             if (tmp[0] === "flavour" && (tmp[1] === "android" || tmp[1] === "ios") )
#                 seobanner = false;
#                 });
#
#
#         if($(window).width()<600 && !readCookie("app_install_widget_seo") && seobanner){
#
#             createCookie("app_install_widget_seo",1,15*60);
#
#         }
#     })
#
#     function pushDataLayerEvent(eventData){
#         if(dataLayer && dataLayer.push)
#         {
#             dataLayer.push(eventData);
#         }
#
#     }
#
#
# </script><input name="pgt" type="hidden" value="01-11-2019 04:41:53"/><a class="btn-scroll-top dn" id="scroll-top-btn"></a><div id="login-div" style="display: none;"><div class="popOverlay popShow"></div><div class="popModal zoom small popShow" id="authOverlay"><div class="popContent"><a class="fr icon-close font12Lt popClose" href="javascript:void(0)" onclick="$('#login-div').hide()"></a><div class="popBody"><iframe height="480px" id="authiframe" src="" width="100%"></iframe></div></div></div></div><div class="padT10 width10 dn" id="missing-review"><span>Be the first Reviewer</span> <br/> <a class=" blue font13" id="write-review">Write Reviews</a> <a class="blue fr font13" id="ask-questions">Ask Questions</a></div></body></html>

# %%
# !pip3 install requests
# Out:
# Collecting requests
#   Downloading https://files.pythonhosted.org/packages/51/bd/23c926cd341ea6b7dd0b2a00aba99ae0f828be89d72b2190f27c11d4b7fb/requests-2.22.0-py2.py3-none-any.whl (57kB)
#     100% |████████████████████████████████| 61kB 344kB/s ta 0:00:01
# Collecting chardet<3.1.0,>=3.0.2 (from requests)
#   Downloading https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl (133kB)
#     100% |████████████████████████████████| 143kB 284kB/s ta 0:00:01
# Collecting certifi>=2017.4.17 (from requests)
#   Downloading https://files.pythonhosted.org/packages/18/b0/8146a4f8dd402f60744fa380bc73ca47303cccf8b9190fd16a827281eac2/certifi-2019.9.11-py2.py3-none-any.whl (154kB)
#     100% |████████████████████████████████| 163kB 383kB/s ta 0:00:01
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from requests) (1.25.5)
# Collecting idna<2.9,>=2.5 (from requests)
#   Downloading https://files.pythonhosted.org/packages/14/2c/cd551d81dbe15200be1cf41cd03869a46fe7226e7450af7a6545bfc474c9/idna-2.8-py2.py3-none-any.whl (58kB)
#     100% |████████████████████████████████| 61kB 584kB/s ta 0:00:011
# Installing collected packages: chardet, certifi, idna, requests
# Successfully installed certifi-2019.9.11 chardet-3.0.4 idna-2.8 requests-2.22.0
# You are using pip version 18.1, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
"""
Web Scraping - Beautiful Soup
"""

# importing required libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd

# target URL to scrap
url = "https://www.goibibo.com/hotels/hotels-in-shimla-ct/"

# headers
headers = {
    'User-Agent': "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36"
    }

# send request to download the data
response = requests.request("GET", url, headers=headers)

# parse the downloaded data
data = BeautifulSoup(response.text, 'html.parser')
print(data)
# Out:
# <!DOCTYPE html>
# <html><head><title>Hotels in Shimla - Book 790 Shimla Hotels with 𝘂𝗽𝘁𝗼 𝟱𝟬% off @ ₹196</title><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/><meta content="Best Shimla Hotels with upto 50% off from Goibibo. Check 52690 reviews and 38801 photos for 790  Shimla Hotels. Use coupon code GETSETGO and grab best deals starting from  @ ₹196 on Shimla online hotel booking. ✔ Lowest Price Guarantee ✔ Fastest Booking ✔ Instant Refund" name="description"/><meta content="width=device-width,initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/><meta content="hotels in Shimla, best hotels in Shimla, Shimla hotels, Shimla hotel booking, Shimla hotel price, Shimla hotel deals, book Shimla hotels, goibibo Shimla hotels" name="keywords"/><link href="//www.goibibo.com/images/favicon.ico" rel="shortcut icon" type="image/ico"/><meta content="Hotels in Shimla -  Book 790  Shimla Hotels with 𝘂𝗽𝘁𝗼 𝟱𝟬% off  @ ₹196" property="og:title"/><meta content="Best Shimla Hotels with upto 50% off from Goibibo. Check 52690 reviews and 38801 photos for 790  Shimla Hotels. Use coupon code GETSETGO and grab best deals starting from  @ ₹196 on Shimla online hotel booking. ✔ Lowest Price Guarantee ✔ Fastest Booking ✔ Instant Refund" property="og:description"/><meta content="https://cdn1.goibibo.com/himachal-pradesh-shimla-147617005104o.jpg" property="og:image"/><meta content="https://www.goibibo.com/hotels/hotels-in-shimla-ct/" property="og:url"/><link href="https://www.goibibo.com/hotels/hotels-in-shimla-ct/" rel="canonical"/><link href="https://www.goibibo.com/hotels/hotels-in-shimla-ct/?pg=2" rel="next"/><link href='android-app://com.goibibo/goibibo/www.goibibo.com/app/hotels/hotels-in-shimla-ct/?params={"go_data": {"n": "shimla", "oid": "1449073512565742573", "t": "area", "cid": "1449073512565742573"}, "tag_id": 202}' rel="alternate"/><link href="https://fonts.googleapis.com/css?family=Quicksand&amp;display=swap" rel="stylesheet"/></head><body class="width100 fl"><noscript><meta content="0;url='https://www.goibibo.com/hotels/hotels-in-shimla-ct/?PageSpeed=noscript'" http-equiv="refresh"/><style><!--table,div,span,font,p{display:none} --></style><div style="display:block">Please click <a href="https://www.goibibo.com/hotels/hotels-in-shimla-ct/?PageSpeed=noscript">here</a> if you are not redirected within a few seconds.</div></noscript><div class="bgdiv" id="new-hotel-loading-div" style="position: fixed; font-family: 'Quicksand', sans-serif !important; display:none"><div id="background-loader-text" onclick="event.stopPropagation()" style="border-radius: 30px; margin: 150px auto; background-color: white; width: 643px; height: 336px;"><div style="width: 100%; height: 213px;"><script pagespeed_no_defer="">//<![CDATA[
# (function(){var g=encodeURIComponent,h=window,k=document,l="width",m="documentElement",n="height",p="length",q=this,r=function(b,d){var a=b.split("."),c=q;a[0]in c||!c.execScript||c.execScript("var "+a[0]);for(var e;a[p]&&(e=a.shift());)a[p]||void 0===d?c[e]?c=c[e]:c=c[e]={}:c[e]=d};var t=function(b){var d=b[p];if(0<d){for(var a=Array(d),c=0;c<d;c++)a[c]=b[c];return a}return[]};var u=function(b){var d=h;if(d.addEventListener)d.addEventListener("load",b,!1);else if(d.attachEvent)d.attachEvent("onload",b);else{var a=d.onload;d.onload=function(){b.call(this);a&&a.call(this)}}};var v,w=function(b,d,a,c,e){this.f=b;this.h=d;this.i=a;this.c=e;this.e={height:h.innerHeight||k[m].clientHeight||k.body.clientHeight,width:h.innerWidth||k[m].clientWidth||k.body.clientWidth};this.g=c;this.b={};this.a=[];this.d={}},x=function(b,d){var a,c,e=d.getAttribute("pagespeed_url_hash");if(a=e)if(a=!(e in b.d))if(0>=d.offsetWidth&&0>=d.offsetHeight)a=!1;else{c=d.getBoundingClientRect();var f=k.body;a=c.top+("pageYOffset"in h?h.pageYOffset:(k[m]||f.parentNode||f).scrollTop);c=c.left+("pageXOffset"in
# h?h.pageXOffset:(k[m]||f.parentNode||f).scrollLeft);f=a.toString()+","+c;b.b.hasOwnProperty(f)?a=!1:(b.b[f]=!0,a=a<=b.e[n]&&c<=b.e[l])}a&&(b.a.push(e),b.d[e]=!0)};w.prototype.checkImageForCriticality=function(b){b.getBoundingClientRect&&x(this,b)};r("pagespeed.CriticalImages.checkImageForCriticality",function(b){v.checkImageForCriticality(b)});r("pagespeed.CriticalImages.checkCriticalImages",function(){y(v)});
# var y=function(b){b.b={};for(var d=["IMG","INPUT"],a=[],c=0;c<d[p];++c)a=a.concat(t(k.getElementsByTagName(d[c])));if(0!=a[p]&&a[0].getBoundingClientRect){for(c=0;d=a[c];++c)x(b,d);a="oh="+b.i;b.c&&(a+="&n="+b.c);if(d=0!=b.a[p])for(a+="&ci="+g(b.a[0]),c=1;c<b.a[p];++c){var e=","+g(b.a[c]);131072>=a[p]+e[p]&&(a+=e)}b.g&&(e="&rd="+g(JSON.stringify(z())),131072>=a[p]+e[p]&&(a+=e),d=!0);A=a;if(d){c=b.f;b=b.h;var f;if(h.XMLHttpRequest)f=new XMLHttpRequest;else if(h.ActiveXObject)try{f=new ActiveXObject("Msxml2.XMLHTTP")}catch(s){try{f=
# new ActiveXObject("Microsoft.XMLHTTP")}catch(B){}}f&&(f.open("POST",c+(-1==c.indexOf("?")?"?":"&")+"url="+g(b)),f.setRequestHeader("Content-Type","application/x-www-form-urlencoded"),f.send(a))}}},z=function(){var b={},d=k.getElementsByTagName("IMG");if(0==d[p])return{};var a=d[0];if(!("naturalWidth"in a&&"naturalHeight"in a))return{};for(var c=0;a=d[c];++c){var e=a.getAttribute("pagespeed_url_hash");e&&(!(e in b)&&0<a[l]&&0<a[n]&&0<a.naturalWidth&&0<a.naturalHeight||e in b&&a[l]>=b[a.src].k&&a[n]>=
# b[a.src].j)&&(b[e]={rw:a[l],rh:a[n],ow:a.naturalWidth,oh:a.naturalHeight})}return b},A="";r("pagespeed.CriticalImages.getBeaconData",function(){return A});r("pagespeed.CriticalImages.Run",function(b,d,a,c,e,f){var s=new w(b,d,a,e,f);v=s;c&&u(function(){h.setTimeout(function(){y(s)},0)})});})();
#
# pagespeed.CriticalImages.Run('/mod_pagespeed_beacon','https://www.goibibo.com/hotels/hotels-in-shimla-ct/','9h69CgP56i',true,false,'zLfc1SnmMTk');
# //]]></script><img onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="2129554552" src="https://gos3.ibcdn.com/screen-loader-1568375554.png" style="width: auto; height: 175px; margin: 25px auto;"/></div><p style="width: 393px; margin: 0px auto; font-size: 22px; font-weight: bold; color: #2276e3;">LOADING THE BEST PRICES FOR YOU</p><div style="font-weight: normal; color: #898b91;"><p>We get you the best prices, everytime. Serving over 600k</p><p>customers worldwide everyday</p></div></div></div><div itemscope="" itemtype="http://schema.org/WebPage"><div id="app-install-widget"></div><script src="//goibibo.ibcdn.com/hotelsnew/static/js/lib/jquery.2.1.3.min.1483561221.js"></script><script src="//goibibo.ibcdn.com/styleguide/js/respond.min.1483563658.js"></script><script src="//goibibo.ibcdn.com/js/v2/headerV2.1568333090.js"></script><script src="//goibibo.ibcdn.com/js/v2/header_common.1568333090.js"></script><div class="headerBox col-md-12 col-sm-12 col-xs-12"><div class="hdrLeft"><a class="hdrLogo" href="/"><img onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="753931433" src="//goibibo.ibcdn.com/styleguide/images/goLogo.png"/></a><ul class="mainLinks"><li class="active"><a href="/flights/"><i class="icon-flights db blue ico24 lh1-2 padT5 padB5"></i> <span class="iconText">Flights</span></a></li><li class=""><a href="/hotels/"><i class="icon-hotels db blue ico28 lh1-2 padT2 padB3"></i> <span class="iconText">Hotels</span></a></li><li class=""><a href="/gostays/"><i class="icon-gostays icon-gostays-cstm db blue padT5 padB5"></i> <span class="iconText">Hotels</span></a></li><li class=""><a href="/bus/"><i class="icon-bus db blue ico24 lh1-2 padT5 padB5"></i> <span class="iconText">Bus</span></a></li><li class="posRel"><a href="/trains/"><img alt="irctc train logo" class="marginT5 marginB5" height="25px" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="3286845901" src="/styleguide/images/train_logo.png" width="24px"/><span class="iconText">IRCTC Trains</span></a></li><li class="posRel"><a href="/cars/"><i class="icon-airport-transfer db blue ico24 lh1-2 padT5 padB5"></i><span class="iconText">Cabs</span></a></li><li class="hdrMoreLink"><div class="padB10 lh1-2 iconText fmtTooltip">more +<div class="tip tip_top white moreSubLinks"><a href="/international-flights/"><i class="icon-flights padR10 blue ico20 fl"></i> <span class="fl padT3">International Flights</span></a><a href="/mobile/"><i class="icon-mobiles padR10 blue ico20 fl"></i> <span class="fl padT3">Mobile Apps</span></a> <a href="/destinations/"><i class="icon-destination padR10 blue ico20 fl"></i> <span class="fl padT3">Destinations</span></a> <a href="/ask/"><i class="icon-ask padR10 blue ico20 fl"></i> <span class="fl padT3">Ask</span></a> <a href="/routeplanner/"><i class="icon-route-planner padR10 blue ico20 fl"></i> <span class="fl padT3">Route Planner</span></a> <a href="/offers/"><i class="icon-offer-badge padR10 blue ico20 fl"></i> <span class="fl padT3">Offers &amp; Promotions</span></a> <a href="/info/reviews-and-rating/"><i class="icon-photo-review padR10 blue ico22 fl"></i> <span class="fl padT3">Reviews &amp; Ratings</span></a> <a href="/trains/check-train-running-status/"><i class="icon-train-front-view padR10 blue ico22 fl"></i> <span class="fl padT3">Train Runing Status</span></a> <a href="/trains/check-pnr-status/"><i class="icon-train-front-view padR10 blue ico22 fl"></i> <span class="fl padT3">Check PNR Status</span></a></div></div></li></ul></div><div class="hdrRight"><div class="width100 fl txtRight padB5 padR5"><a class="hdrCusSupport vMid padR15" href="/support/"><small class="fl ico13 lh1-2">24x7 goCare Support</small></a> <span class="vMid dib txtRight hdrUserName" id="hdr_user_signin"><span class="ico13 blue db"><a href="javascript:void(0)" onclick="window.location.href = '/accounts/login/?next=' + location.href;  ">Sign In</a> / <a href="jav ...
#     $(window).on('load',function(){
#
#         if(widget && widget.autosuggestSetter)
#         {
#             widget.autosuggestSetter({"title": "Shimla", "country": "IN", "entityType": "city", "cityName": "Shimla", "cityId": "1449073512565742573", "entityId": "1449073512565742573"});
#         }
#
#
#
#
#     });
#
# </script><div class="searchWrapOuterBox bgBlue row"><div class="searchInnerBox"><a class="dn ipaddn mobdb button orange large fl width100 marginB10 goCamp" href="javascript:void(0)" id="searchHotelButton" style="display:none !important;">Search<span class="goKarde"></span></a><form class="mobSearchToggle1" id="gi_search_hp" method="post" name="gi_search" onsubmit="return false;"><div class="col-md-12 col-sm-12 col-xs-12 pad0"><div class="col-lg-5 col-md-4 col-sm-12 col-xs-12 autoSuggestBox"><input autocomplete="off" class="form-control txtInput" id="gosuggest_inputL" placeholder="Enter City name, Area name or Hotel name" type="text"/><div class="col-md-12 col-sm-12 col-xs-12 autoWrap marginTM10"></div></div><div class="col-lg-3 col-md-3 col-sm-5 col-xs-12"><div class="fl width100 calenderOuterBox"><div class="col-md-6 col-xs-6 calenderInnerBox" id="ciHolder"><a class="width100 fl" data-date="" href="javascript:void(0)" id="start-date_hp"><i class="icon-calendar1 black ico26 fl padR5"></i> <span class="fl font13Dr padT5" id="ci_srp_day">Checkin</span></a><div class="jrdp_calendar_pos" id="start-calen_hp"></div></div><div class="col-md-6 col-xs-6 calenderInnerBox last" id="coHolder"><a class="width100 fl" data-date="" href="javascript:void(0)" id="end-date_hp"><i class="icon-calendar1 black ico26 fl padR5"></i> <span class="fl font13Dr padT5" id="co_srp_day">Checkout</span></a><div class="jrdp_calendar_pos" id="end-calen_hp"></div></div></div></div><div class="col-lg-2 col-md-3 col-sm-4 col-xs-12"><div class="paxWrapper"><a class="paxBox" href="javascript:void(0);" id="pax_link_hp"><i class="icon-user greyLt ico18 fl marginT2 padR5"></i> <span class="ico13 black padT5 fl" id="home_textHook">1 Guests / 1 Rooms</span> <i class="icon-arrow-down txtgrey ico18 padT5 fr"></i></a><div class="width100 fl paxWrapCont borderAll dn" id="paxcontainer_home"><div id="summaryContainer"></div><div id="editBox"></div><div class="width100 fl borderBtm marginB10 bg-greyLtest1" id="addButton"></div></div></div></div><div class="col-lg-2 col-md-2 col-sm-3 col-xs-12 marginB10 goCamp"><button class="button orange large ipadButtonSpace width100" id="hm_srch" type="submit">Search<span class="goKarde"></span></button></div></div></form></div></div><div class="dn" id="template-placeholder"></div><script id="go_suggestions" type="text/template">
# 		<ul class="autoSuggestBoxList flt dn">
# 			<% _.each(list, function(item,count) { %>
# 				<li <% if(item.left.cityHead){ %> class="cityhead" <%}%> <% if(item.left.indent){ %>class="indent" <%}%> data-index="<%= count %>">
# 					<% if(item.left.cityHead){ %>
# 						<% if(item.meta.pageType == 'offers'){%>
# 							<div class="fl padR2 hidden-sm hidden-xs padT5">
# 						<i class="fl icon-city ico11"></i>
# 						<% } else { %>
# 							<div class="fl padR2 hidden-sm hidden-xs padR2 padT5">
# 							<i class="fl icon-city ico14"></i>
# 						<% } %>
# 						</div> <%}%>
# 						<% if(item.meta.context=='flights'){%>
# 							<% if (item.left.cityHead == false){ %>
# 								<% if(item.meta.pageType == 'offers'){%>
# 									<div class="fl hidden-sm  padT5 hidden-xs">
# 								<i class="fl icon-flights ico12"></i>
# 								<% } else { %>
# 									<div class="fl padT5 hidden-sm padR10 hidden-xs">
#  									<i class="fl icon-flights ico14"></i>
# 								<% } %>
#
# 							</div><%}%>
# 							<% if(item.meta.suggestType == 'multi'){%> <div class="dib marginL10 col-md-10 col-sm-12 col-xs-12 pad0 textOverflow"><% } %>
# 							<% if(item.meta.pageType == 'offers'){%> <div class="dib marginL10 col-md-10 col-sm-12 col-xs-12 pad0 textOverflow"> <% } else { %><div class="dib col-md-11 col-sm-12 col-xs-12 pad0 textOverflow"><% } %>
# 								<div class="mainTxt clearfix">
# 									<span> <%= item.left.mainTxt %> </span> <span class="txtTransUpper ico14 greyLt">(<%= item.right.span %>)</span>
# 								</div>
# 								<% if(item.meta.suggestType == 'multi'){%>
# 									<div class="fl auto-ctryMult-ellip auto-ctryAir-ellip padT2">
# 								<% } else { %>
#  									<div class="fl auto-ctryAir-ellip mobEllipsis padT2">
# 								<% } %>
# 										<span class="clearfix">
# 											<small class="font12Lt"> <%= item.left.subTxtSpan %></small>
# 										</span>
#
# 									</div>
# 								<span class="fr">
# 									<% if(item.meta.pageType == 'offers'){%>
# 										<small class="font12Lt vMid padR5 dib"><%= item.left.subTextCName %></small>
# 									<% } else { %>
# 										<small class="font12Lt vMid padR5 dib"><%= item.left.subTxtSmall %></small>
# 									<% } %>
# 									<span class="flag-sprt vMid dib <%= item.left.subTextCName.toLowerCase() %>"></span>
# 								</span>
# 								<span class="clearfix">&nbsp;</span>
#
# 								<% if(item.left.dis && item.left.cityNameDis) {%>
# 										<span class="clearfix">
# 											<small class="font12Lt"> <span class="fb">(<%= Math.floor(item.left.dis) %></span> KMs from <span class="fb"><%= item.left.cityNameDis %></span>)</small>
# 										</span>
# 									<% } %>
# 							</div>
# 						<% } else { %>
# 							<div class="dib col-md-8 col-sm-8 pad0 <%if(item.meta.context){ %> col-xs-8 <% }else{ %>col-xs-12<% } %> <%if(item.meta.context=='flights'){ %> textOverflow <% } %>">
# 								<div class="mainTxt">
# 									<span><%= item.left.mainTxt %></span><% if(item.left.subTxtSpan){ %>
# 										<span class=""> &ndash; <%= item.left.subTxtSpan %></span>
# 										<% }else if(item.left.subTxtSmall){ %>
# 											<small class="font11Lt"><%= item.left.subTxtSmall %></small>
# 										<% } %>
# 								</div>
# 							</div>
# 						<% } %>
# 						<% if(item.meta.context!='flights'){%>
# 							<div class="col-md-4 col-sm-4 pad0 <%if(item.meta.context){ %> col-xs-4 <% }else{ %>col-xs-12<% } %>">
# 								<div class="fr width100">
# 									<% if(item.right.rating){%>
# 										<div class="fl">
# 											<div class="autoGoRating fl">
# 												<i class="icon-reverse-go ico15 orange fl"></i>
# 												<small class="fl padL5 padT2"><b><%= item.right.rating%></b>
# 													<span class="font11Lt">/5</span>
# 												</small>
# 											</div>
# 											<% if(item.right.reviewCount){ %>
# 												<small class="autoReviewers  padT2 fl width100">
# 													<span><%=item.right.reviewCount%></span> <span>Reviews</span>
# 												</small>
# 											<% } %>
# 										</div>
# 									<% } %>
#
# 									<% if(item.right.span){%>
# 									<% } else if(item.right.group){%>
# 										<% if(item.right.group.span){%>
# 											<span class="statusTag auto txtLeft"><%=item.right.group.span%></span>
# 										<% } %>
# 										<i class="ht_bgAutoSuggest ht_<%= item.right.group.type %> fr"></i>
# 										<small class="margin5 dib pad3 fr"><%= item.right.group.type %></small>
# 									<% } %>
# 								</div>
# 							</div>
# 						<% } %>
# 					</li>
# 				<% }); %>
# 			</ul>
# 		</script><script id="go_suggestions_error" type="text/template">
# 			<ul class="autoSuggestBoxList dn">
# 				<li> No matching result found.</li>
# 			</ul>
# 		</script><script id="pax_select" type="text/template">
#     <div class="widgetUserBlock fl <%=val.containerClass%>">
#         <label class="ico13 db padB5"><span><%=val.label%></span><small class="font10Lt db padT3"> <%=val.subLabel%></small></label>
#         <div class="customSelect">
#             <select <%if(val.react){ %> class="hasChild" id="<%=val.id%>" <% } %> name="<%=val.label.replace(' ','')%>">
#             <% for(var i=val.min;i<=val.max;i++){ %>
#             <option value="<%=i%>" <%if(val.value==i){ %>selected<% } %>><%=i%></option>
#             <% } %>
#             </select>
#         </div>
#     </div>
# </script><script id="pax_li" type="text/template">
#     <li class="roomRow">
#         <% if(config.boxHeading.visible){ %>
#         <h4 class="padTB5"><%=config.boxHeading.label%>
#             <% if(config.boxHeading.useIndex){ %>
#             <%=++config.boxHeading.index%>
#             <% } %>
#         </h4>
#         <%}%>
#         <% _.each(entity, function(person,key){ %>
#         <% if(person.visible){ %>
#         <%=renderSelect({val:person})%>
#         <%if(person.childConfig){ %>
#         <%for(var z=1;z<=person.value;z++){ %>
#         <%=renderSelect({val:person.childConfig[z-1]})%>
#         <%};%>
#         <%}%>
#         <%}%>
#         <% }); %>
#     </li>
# </script><script id="pax_template" type="text/template">
#     <div class="paxMobile dn paxContainer">
#         <a class="icon-cancel-circle fr marginT10 marginR10 fr greyDr mobdn" id="pax_close" href="javascript:void(0);"></a>
#         <ul>
#             <% _.each(config.entities, function(entity,idx){ %>
#             <%=renderLi({config:config,entity:entity,renderSelect:renderSelect})%>
#             <% }); %>
#
#             <% if(config.actionLinks.visible){ %>
#             <li class="fl txtCenter">
#                 <a class="fl ico16 pad15" href="javascript:void(0)" id="add">Add <%=config.actionLinks.textToAppend%></a>
#                 <a class="fl ico16 pad15 dn" href="javascript:void(0)" id="remove">Remove <%=config.actionLinks.textToAppend%></a>
#             </li>
#             <% }%>
#         </ul>
#     </div>
# </script><script id="summaryTemplate" type="text/template">
#
# 	<%for(var i=0; i<roomObject.roomconfig.length; i++){%>
#
# 		<div class="width100 fl posRel borderBtm summary" data-serial="<%=i+1%>">
#
# 			<div class="rowIcons nClick">
# 				<a class="icon-edit fl greyLt ico16 pad5 nClick" href="javascript:void(0);"></a>
# 				<%if(roomObject.roomconfig.length != 1){%>
# 					<a class="icon-close1 fl pad5 red nClick" href="javascript:void(0);" data-close="true"></a>
# 				<% } %>
# 			</div>
# 			<div class="userselected fl width100 nClick">
# 				<span class="fl ico14 pad10 grey lh1-2 bg-greyLtest1 fb nClick">Room <%=i+1%></span>
# 				<span class="fl pad10 tipLeft nClick"><%=roomObject.roomconfig[i].adult%> <%=roomObject.roomconfig[i].adultTag%> / <%=roomObject.roomconfig[i].children%> <%=roomObject.roomconfig[i].childTag%></span>
# 			</div>
#
# 		</div>
#
# 	<% } %>
#
# </script><script id="editTemplate" type="text/template">
#
# 		<div class="width100 fl posRel borderBtm">
# 			<div class="rowIcons">
# 				<a class="icon-close1 fl pad5 red nClick" href="javascript:void(0);" id="editClose"></a>
# 			</div>
# 			<div class="useredit fl width100 pad10" id="edtHook" data-mode= "<%=mode%>" data-serial = "<%=rmnumber + 1%>">
# 				<h4 class="padTB5 ico14 grey lh1-2">Room <%=rmnumber + 1%></h4>
# 				<div class="widgetUserBlock fl " ele="adult">
# 			        <label class="ico13 db padB5"><span>Adult</span><small class="font10Lt db padT3"> (12+ yrs)</small></label>
# 			        <div class="customSelect">
# 			            <select name="Adult">
# 			            <%for(var x=1; x<5; x++ ){%>
# 			            	<option value="<%=x%>"
# 			            		<% if(x == adult) { %>
# 			            			selected="selected"
# 					            <% } %>
# 					         ><%=x%></option>
# 					     <% } %>
# 			            </select>
# 			        </div>
# 			    </div>
# 				<div class="widgetUserBlock fl " ele="children">
# 			        <label class="ico13 db padB5"><span>Children</span><small class="font10Lt db padT3"> (2-12 yrs)</small></label>
# 			        <div class="customSelect">
# 			            <select class="hasChild" id="children" name="children">
# 			            	<%for(var x=0; x<3; x++ ){%>
# 				            	<option value="<%=x%>"
# 				            		<% if(x == children) { %>
# 				            			selected="selected"
# 						            <% } %>
# 						         ><%=x%></option>
# 						     <% } %>
# 			            </select>
# 			        </div>
# 			    </div>
# 			    <div class="widgetUserBlock fl children <% if(!age1){ %> dn <% } %>" id="childBox1" ele="age1">
# 					<label class="ico13 db padB5"><span>Child 1</span><small class="font10Lt db padT3"> Select age</small></label>
# 			        <div class="customSelect">
# 			            <select name="Child1">
#
# 			            	<%for(var x=1; x<13; x++ ){%>
# 				            	<option value="<%=x%>"
# 				            		<% if(x == age1) { %>
# 				            			selected="selected"
# 						            <% } %>
# 						         ><%=x%></option>
# 						     <% } %>
#
# 			            </select>
# 			        </div>
# 			    </div>
# 			    <div class="widgetUserBlock fl children <% if(!age2){ %> dn <% } %>" id="childBox2" ele="age2">
# 					<label class="ico13 db padB5"><span>Child 2</span><small class="font10Lt db padT3"> Select age</small></label>
# 			        <div class="customSelect">
# 			            <select name="Child2">
#
# 				            <%for(var x=1; x<13; x++ ){%>
# 				            	<option value="<%=x%>"
# 				            		<% if(x == age2) { %>
# 				            			selected="selected"
# 						            <% } %>
# 						         ><%=x%></option>
# 						     <% } %>
#
# 			            </select>
# 			        </div>
# 			    </div>
# 		    </div>
# 	    </div>
#
# </script><script id="addTemplate" type="text/template">
#
# 	<%if(roomObject.roomconfig.length < 6){%>
# 		<a class="button outlineBlue fl margin5 txtTransUpper nClick" id="addRoom">+ Add Room</a>
# 	<% } else {%>
# 		<div class="width100 fl pad10 txtCenter borderBtm">
# 			<span class="width100 fl grey ico12 lh1-2">Need more rooms? Contact our travel expert on</span>
# 			<span class="width100 dib padT2 ico13">
# 				<span class="dib blue">1800 267 9999</span>
# 				<span class="dib grey padL4 padR4">or</span>
# 				<span class="dib blue">
# 					<a href="mailto:holidays@goibibo.com">holidays@goibibo.com</a>
# 				</span>
# 			</span>
# 		</div>
# 	<% } %>
# 	<button class="button blue fr margin5 xsmall nClick" id="editSubmit">Done</button>
#
# </script><script>
# 		proto = window.location.protocol;
# 	</script><script src="//goibibo.ibcdn.com/hotelsnew/static/js/widget_hotels-lib-min.1483561221.js" type="text/javascript"></script></div> <div class="clear"></div><div class="width100 fl greyBg"><div class="seoPageHtl marginAuto"><div class="breadcrumb marginTB5 lh1-5 col-md-9 col-sm-9 col-xs-12 padL15" style="margin-bottom: -5px;"><div class="fl" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><a href="/" itemprop="url" title="Home"><span itemprop="title">Goibibo</span></a>→ </div><div class="fl" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><a href="/hotels/" itemprop="url" title="Hotel Booking"><span itemprop="title">Hotel Booking</span></a>→ </div><div class="fl" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><a href="/hotels/india/" itemprop="url" title="Hotels in India"><span itemprop="title">India</span></a> → </div><div class="fl"><span>Shimla</span></div></div></div></div><div class="clear"></div><div class="width100 fl greyBg"><div class="seoPageHtl marginAuto"><div class="col-md-12 col-sm-12 col-xs-12 padLR10"><div class="width100 fl"><a class="posRel button showFiltr orange xsmall fr ipaddb mobdn dn" onclick="">Hide Filter</a><section class="col-md-9 col-sm-12 col-xs-12 fr wid80 pad0" style="width: 75% !important;"><div id="price-loader"><div class="price-loader-text">Fetching best deals for you<div class="typing_loader"></div></div></div><div style="clear: both;"></div><div class="col-md-12 col-sm-12 col-xs-12 marginB10 marginT10 dn" id="search-head1"><div class="fl font15">Current Search Filters</div><div id="current-search-btns"></div></div><div class="dn" id="add-more-loc-head"><div class="txt-cap fl marginL20" id="add-more-loc"><a class="filter-btn txt-cap" onclick="HotelCityApp.searchEvents.focusLocationFilter()" style="background-color: #f26722;" title="Add More Locations">+ Add More</a></div></div><div class="dn fl marginL5 width100 marginT5" id="sort-div"><div class="sort-tab sort-tab-active" id="popularity" onclick="HotelCityApp.searchEvents.processSort('popularity')" title="Sort by popularity">Popularity</div><div class="sort-tab" id="price-low" onclick="HotelCityApp.searchEvents.processSort('price-low')" title="Sort by price low to high">Price Low To High</div><div class="sort-tab" id="price-high" onclick="HotelCityApp.searchEvents.processSort('price-high')" title="Sort by price high to low">Price High To Low</div><div class="col-md-3 col-sm-3 col-xs-12"><select class="listdropdown locDropDown dn" id="sort-type" onchange="HotelCityApp.searchEvents.multiLocationSort()"></select></div></div><div style="clear:both;"></div><div class="width100 fl padB5" id="outerSrpLocContainer" style="margin-top:10px;padding-left:5px; padding-right:5px;"><div class="searchBlk posRel" id="srpLocContainer" style="background: rgb(255, 255, 255); border-width: 0px 1px 1px; border-top-style: initial; border-right-style: solid; border-bottom-style: solid; border-left-style: solid; border-top-color: initial; border-right-color: rgb(230, 230, 230); border-bottom-color: rgb(230, 230, 230); border-left-color: rgb(230, 230, 230); border-image: initial;"><span class="fl ico16 black padT4 marginTB5" style="width: 260px;"><i class="icon-area ico18 fl marginR5 borderBtm redDr padR4"></i>Find By Location or Address</span><div class="fl posRel" style="width:500px;"><div class="fl padL20 autoSuggestBox" style="width:100%;"><div class="fl marginTB5 posRel" id="location-search-div" style="width:100%;"></div></div></div><span class="offerTag"><span class="dib">New</span></span></div></div><div style="clear:both;"></div><div style="clear:both;"></div><div class="width100 fl pad5 padding-top-0" id="main-page-div" style="padding-top: 0px;margin-top:-18px;"><div style="width: 100%; float: left; margin-top: 10px; margin-bottom: 10px;"><div class="col-md-12 col-sm-12 col-xs-12 marginT10" id="all-hotels-container"><div class="col-md-9 col-sm-12 col-xs-12"><i class="fl icon-hotels blue ico28"></i><h1 class ...
# <div id="htl-<%= hotel_data.id %>" class="width100 fl htlListSeo hotel-tile-srp-container hotel-tile-srp-container-template"  onclick="window.open('<%= hotel_data.url %>'); event.stopPropagation();">
#     <div class="hotel-tile-srp-container-img-container">
#         <% if (hotel_data.bkfstOverlay && hotel_data.bkfstOverlay === 1) {%>
#             <div class="htl-tile-free-bkfst-overlay" style="display: block;">
#                 <div class="text-label">Free breakfast</div>
#                 <div class="label-decor"></div>
#             </div>
#         <% } %>
#         <div class="hotel-tile-srp-container-title-image">
#             <img class="lazy" src="<%= hotel_data.img %>" ori="<%= hotel_data.img %>" id="htl-tile-main-image-<%= hotel_data.id %>">
#         </div>
#         <% if (hotel_data.img_gallery.length > 1) {%>
#             <ul class="hotel-tile-srp-container-image-gallery">
#                 <% for (var idx in hotel_data.img_gallery) {%>
#                     <li>
#                         <% if ((hotel_data.img_gallery.length-idx) === 1) {%>
#                             <div style="cursor:pointer !important;">
#                                 VIEW ALL
#                             </div>
#                         <% } %>
#                         <img src="<%=hotel_data.img_gallery[idx].th%>" fsi="<%=hotel_data.img_gallery[idx].fs%>" class="lazy htl-tile-gallery-image" htl="<%= hotel_data.id %>" onmouseenter="onImageHover(this, 'in')" onmouseleave="onImageHover(this, 'out')">
#                     </li>
#                 <% } %>
#             </ul>
#         <% } %>
#     </div>
#     <div class="hotel-tile-srp-container-content-container">
# 		<ul class="hotel-content-container-top-hinged-list">
# 			<li>
# 				<div style="display: inline-block; float:left;">
#                     <% for (var i=0; i<hotel_data.star_rating; i++) {%>
# 					    <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i>
#                     <% } %>
# 					<span style="padding: 2px; border: 1px solid #e5edf6; border-radius: 2px; margin-left: 5px; color: #4f525a">HOTEL</span>
# 				</div>
#                 <div>
#                  <% if  (hotel_data.ugc_src == "ta" && hotel_data.ta_rating != "") { %>
#                          <div style="background-color: green; height: 20px; -webkit-border-radius:5px; float:right; margin-left:8px;">
#                              <span >
#                              <img src="https://gos3.ibcdn.com/trip_adviser-1557838494.png" alt="Trip Advisor Logo" style="max-width: 25.5px; max-height: 12px; margin: 5px 0px 5px 5px;">
#                              <span class="ico16" style="color:#ffffff;  margin: 4px 7px 3px 5px; font-size:12px; float:right;">
#                                  <strong> <%= hotel_data.ta_rating %> </strong> /5 </span>
#                              </span>
#                          </div>
#                     <% } %>
#                 </div>
# 				<div style="float: right; margin-top:3px;">
#                     <% if (hotel_data.review_count) {%>
#                         <span><%= hotel_data.review_count %> reviews</span>
#                     <% } %>
#                     <% if (hotel_data.ugc_src === "gir" && hotel_block_config.go_rating === true && hotel_data.go_rating != "" && hotel_data.go_rating > 0) {%>
#                         <span style="padding: 4px; background-color: <% if (hotel_data.go_rating >= 4.0){ %>#7ccf50<% } else if (hotel_data.go_rating >= 3.0 ){ %>#afd600<% } else { %>#fdaf15<% } %>; color: white; border-radius: 2px; margin-left: 5px;"><%= hotel_data.go_rating %>/5</span>
#                     <% } %>
#                     <% if (!(hotel_data.review_count || (hotel_data.ugc_src === "gir" && hotel_block_config.go_rating === true && hotel_data.go_rating != "" && hotel_data.go_rating > 0) || (hotel_data.ugc_src === "ta" && hotel_block_config.ta_rating === true && hotel_data.ta_rating != "" && hotel_data.ta_rating > 0))) {%>
#                     <span>New Listing</span>
#                     <span style="padding: 4px 6px;background-color: #1aabb8;color: white;border-radius: 2px;">NEW</span>
#                     <% } %>
#                 </div>
# 			</li>
# 			<li>
#                 <a href="<%= hotel_data.url %>" target="_blank" onclick="event.stopPropagation();"><p style="font-size: 18px; font-weight: bolder; color: #141823;font-family: 'Quicksand', sans-serif;  margin-top:17px;"><%= hotel_data.name %></p></a>
#             </li>
# 			<% if (hotel_data.location) {%>
#             <li style="color: #2276e3;">
#                 <p><%= hotel_data.location %></p>
#             </li>
#             <% } %>
# 		</ul>
# 		<ul class="hotel-content-container-bottom-hinged-list">
# 			<li>
# 				<i class="icon-ranking" style="font-size: 15px; margin-right: 3px; color: #fdba00"></i>
#                 <% if (hotel_data.topTag && hotel_data.topTag != '') {%>
#                     <span class="htl-tile-top-tag-text" style="color: #2276e3; cursor: pointer"><%= hotel_data.topTag %></span>
#                 <% } else if (hotel_data.reco_percent && hotel_data.reco_percent != '0') {%>
#                     <span class="htl-tile-top-tag-text" style="color: #2276e3; cursor: pointer"><%= hotel_data.reco_percent %>% Guests recommend this hotel</span>
#                 <% } else { %>
#                     <span class="htl-tile-top-tag-text" style="color: #2276e3; cursor: pointer"></span>
#                 <% } %>
# 			</li>
#             <% if (hotel_data.locPin && hotel_data.locPin != "") {%>
#                 <li class="hotel-content-container-li-loc-usp" style="display: block;">
#                     <i class="icon-persuation-generic" style="font-size: 15px; margin-right: 3px;"></i>
#                     <span class="htl-tile-loc-pin-text"><%= hotel_data.locPin %></span>
#                 </li>
#             <% } %>
#             <% if (hotel_data.htl_amen_list) {%>
#                 <li style="" class="htl-tile-amenities-list">
#                     <% if (hotel_data.htl_amen_list.room_service === true) {%>
#                         <div style="">
#                             <i class="icon-service2" style=""></i>
#                             <span>Room Service</span>
#                         </div>
#                     <% } %>
#                     <% if (hotel_data.htl_amen_list.internet === true) {%>
#                         <div style="">
#                             <i class="icon-wifi-free" style=""></i>
#                             <span>Free Internet</span>
#                         </div>
#                     <% } %>
#                     <% if (hotel_data.htl_amen_list.restaurant === true) {%>
#                         <div style="">
#                             <i class="icon-restaurant2" style=""></i>
#                             <span>Restaurant/Coffee Shop</span>
#                         </div>
#                     <% } %>
#                     <% if (hotel_data.htl_amen_list.swimming_pool === true) {%>
#                         <div style="">
#                             <i class="icon-swimming2" style=""></i>
#                             <span>Swimming Pool</span>
#                         </div>
#                     <% } %>
#                 <% if (hotel_data.htl_rem_amen_cnt > 0) {%>
#                     <span style="color: #2276e3; cursor: pointer">+ <%= hotel_data.htl_rem_amen_cnt %> More</span>
#                 <% } %>
#                 </li>
#             <% } %>
#
# 			<% if (hotel_data.couple_friendly && hotel_data.couple_friendly === 1) {%>
#                 <li style="color: #ff3a5c;">
#                     <i class="icon-couple-man-woman" style="font-size: 15px; margin-right: 3px;"></i>
#                     <span>Couple Friendly</span>
#                 </li>
#             <% } %>
#             <% if (hotel_data.stlDeal && hotel_data.stlDeal != "") {%>
# 			<li style="color: #861388;">
# 				<span>
# 					<i class="icon-steal-deal" style="font-size: 15px; margin-right: 3px;"></i>
# 					<!--<i class="icon-path" style="font-size: 15px; margin-right: 3px;"></i>-->
# 				</span>
# 				<span style="padding: 3px 8px; border-radius: 10px; background-color: #f2e7f3;">Steal Deal</span>
#                 <span style="margin-left: 5px; color: black;" class="htl-tile-steal-deal-text"><%= hotel_data.stlDeal %></span>
# 			</li>
#             <% } %>
# 			<!--<li style="border-radius: 4px; background-color: #eef4fd; margin-top: 4px;">
# 				 <span style="background-image: linear-gradient(285deg, #cf125d, #ff3478); color: white; padding: 2px 8px; border-radius: 2px; margin-right: 5px;">
#                     GIFT CARD
#                 </span>
#                 <span>1500 TAJ Experiences card for use at any Taj</span>
#                 <span style="display: inline-block; margin-left: 5px; color: #2276e3;">+More</span>
# 			</li>
# 			<li style="border-radius: 4px;background-color: #eef4fd;">
# 				<span style="background-image: linear-gradient(107deg, #1149f3, #00c3ff); color: white; padding: 2px 8px; border-radius: 2px; margin-right: 5px;">SPL DEAL</span>
#                 <span>Free 30min SPA session</span>
#                 <span style="display: inline-block; margin-left: 5px; color: #2276e3;">+More</span>
# 			</li>-->
# 		</ul>
# 	</div>
# 		<div style="width: 200px; margin: 12px 10px 0px 6px; display: inline-block; border-left: 1px solid #e5edf6; height: 256px; position: absolute; right: 0px; font-size: 12px; color: #4f525a;">
#             <% if (hotel_data.bannerText && hotel_data.bannerText != "") {%>
#                 <div style="font-size: 12px; font-weight: bold; position: absolute; top: -24px; right: 10px;">
#                     <div style="display: inline-block; width: 0px; height: 0px; border-right: 5px solid #898b91; border-left: 5px solid transparent; border-top: 5px solid transparent; border-bottom: 5px solid #898b91; margin: -9px 0px 0px 0px;"></div>
#                     <div class="htl-tile-banner-text-div" style="margin: 0px -4px; display: inline-block; padding: 1px 10px; background-image: linear-gradient(284deg, #adaeb2, #34393a); color: white; width: max-content; border-bottom-right-radius: 2px; border-bottom-left-radius: 2px; height: 17px;">
#                         <%= hotel_data.bannerText %>
#                     </div>
#                     <div style="display: inline-block; width: 0px; height: 0px; border-right: 5px solid transparent; border-left: 5px solid #898b91; border-top: 5px solid transparent; border-bottom: 5px solid #898b91; margin: -9px 0px 0px 0px;"></div>
#                 </div>
#             <% } %>
#             <% if (hotel_data.fcpText && hotel_data.fcpText != "") {%>
#                 <div style="background-color: aliceblue; width: 182px; text-align: center; border-radius: 10px; margin: 5px auto;">
#                     <span style="color: #2bac36;" class="htl-tile-fcp-text"><%= hotel_data.fcpText %></span>
#                 </div>
#             <% } %>
# 			<div style="text-align: right; position: absolute; top: 75px; right: 0px;">
#                 <ul>
#                     <li style="height: 27px; display: none" class="htl-tile-prc-loader">
#                         <div class="typing_loader" style="float: unset;"></div>
#                     </li>
#                     <% if (hotel_data.so) { %>
#                     <li style="font-size: 18px;color: black;font-weight: bold;" class="htl-tile-sold-out-label">SOLD OUT</li>
#                     <% } else { %>
#                         <% if (hotel_data.oprc) { %>
#                             <li style="text-decoration: line-through;" class="htl-tile-non-discount-prc">
#                                 <i class="icon-rupee rupee-icon" style="font-size: 12px;"></i><%= hotel_data.oprc %>
#                             </li>
#                         <% } %>
#                         <% if (hotel_block_config.price == true && hotel_data.booking_price != "" && hotel_data.booking_price > 0) {%>
#                         <li style="font-size: 22px; color: black; font-weight: bold;" class="htl-tile-discount-prc">
#                             <i class="icon-rupee rupee-icon" style="font-size: 16px;"></i><%= hotel_data.booking_price %>
#                         </li>
#                         <li>per room/night</li>
#                         <% } %>
#                     <% } %>
#                     <% if (hotel_data.offersCount && hotel_data.offersCount > 0) {%>
#                         <li style="background-color: #fef8e5; color: #8e5a14;">
#                             <i class="icon-gocash-plus" style="font-size: 15px; color: #fdba00;"></i>
#                             <span style="margin: 5px;" class="htl-tile-offers-count">+<%= hotel_data.offersCount %> offers</span>
#                         </li>
#                     <% } %>
#                 </ul>
#             </div>
# 			<div style="text-align: right; position: absolute; bottom: 0px; right: 0px;">
# 			<p>
#                 <button onclick="window.open('<%= hotel_data.url %>'); event.stopPropagation();" style="padding: 0px 15px; height: 35px; font-size: 16px; font-weight: bold; background-color: #ff6d38; color: white; border: none; border-radius: 4px;">BOOK NOW</button>
#             </p>
# 			<p style="color: #ff3a5c; margin: 5px 0px;" class="htl-tile-last-opt"><%= hotel_data.lastTag %></p>
# 		</div>
# 	</div>
# </div>
# </script><script type="text/javascript">
#     pageType = "main_city";
#     lat = 31.1048145;
#     lon = 77.1734033;
#     city_name = "Shimla";
#     city_id = "1449073512565742573";
#     currentHost = "voyager.goibibo.com";
#     allHotelsData = {};
#     allHermesData = {};
#     priortizedHotelIds = ["8833337098196373625", "5035039896502133936", "8871636629353578439", "7459202266562597344", "6133961403167948671", "9191986948655858497", "6919002552374671737", "3834503590779290545", "3429746845687339858", "4803818830674501773", "6042678147555200728", "8814950729764566617", "2668930289000053794", "4132340955783784970", "7393074725561129529", "4603401151261891684", "6219607130473533931", "2310909284817368176", "7764296370836633209", "3451763848511086302", "7899035935330867108", "1085766080464256343", "7233073256399800597", "3027796615243425553", "334113831833825406", "7926285534851583337", "5644494538551280914", "1367466367395691201", "7830725769081543809", "9132401001922838353", "5552266556689170547", "7638770112293463188", "7896309543687198170", "4508640287885363792", "1949489690883681366", "2722835239411954969", "5890844042233498779", "5226089337385666229", "1700844874317530146", "919875262476689975", "4093584789369691896", "7973943634519748681", "3572747602679325734", "2739295705892554451", "4930060251182269812", "5231879829398869129", "5582707235298205128", "4341947675367428838", "3162417438540254080", "4366881424198211944", "9047047789922507199", "8847676300359984525", "8833940789536256162", "4797386695497356013", "2805366558683576001", "643910851770662122", "1840384582126692352", "6676802961546271766", "8256559789798336309", "7908309035161623236", "887913683841027079", "8525939572628378557", "3972438790911577064", "2918584767187870299", "6354599858499974952", "5296367711267092596", "7814236958554289102", "4356622928106972422", "6467213783512500824", "171304619761356672", "5364825111301595548", "7481785841346701430", "8210235490388535758", "4180652637903669013", "7867442280735533839", "2928012005302227019", "4024291697560108892", "7325499651138989507", "8634570325548773980", "6961675676232961072", "6833650235336324497", "1684310128965648781", "2152028404001390089", "7543907359980632827", "1923769941457192394", "5190297589595166178", "1272848330064890914", "5688410952616404300", "3840120836663711930", "3122448041086811088", "1839450225092003455", "5761525067723984112", "6672745452248732216", "3555257284160429171", "7535386019037895893", "4382675063350128999", "6868601222461797927", "6992592702406338805", "1373067411416306668", "7696013012067250540", "4865285288407569798", "2923180421546263602", "289297441951257782", "8487828901284192936", "6997953323380690605", "3062377524074980636", "5989231034384112109", "1753840413039671320", "1770849336303147771", "8798437038915809316", "584566816388311754", "3241060935116797850", "8154688523451183823", "7309046686498622248", "6682502713314075020", "2724952418138578682", "7491354277971285191", "5917072032362829316", "6655733281806765216", "3763280662125809904", "2502293248040232672", "5339455598025612593", "7481695928021801525", "4430673730811884875", "5860465706634300818", "1447855037354376569", "3443781901865797711", "6617236183435430076", "8964443484484594838", "2264529271423614038", "1416809721456220441", "1602794851833368474", "7071577211857429914", "3394214965776349887", "6849717144312925906", "3382270246003252888", "6025344523708922203", "4713243126660706589", "323485704258300318", "8685198985434721970", "292549637383670558", "4086518870721023087", "5755630105667356881", "1805720073013259735", "8477564650772533145", "6077198038391316207", "3063282073816526781", "926642424978302912", "4098314048100585768", "360487241192802909", "1632511420934038011", "1874875264102932793", "8038818731568437947", "4719927100919199252", "518705267460558983", "3403463968076540848", "3882623631711451075", "5186180118951080266", "2930265219565893244", "4343073517424016921", "4558330758147613894", "4899085585014300339", "6365647411079466321", "7144406779096906702", "7330523828712648537", "2706073311959172046", "2209003268233911490", "3754327080378501221", "7275331496949195588", "736425363845889208", "7493940230123243060", "632154612455959267", "2000804894644230056", "29420724 ...
#     priortizedHotelIdsSlice = ["8833337098196373625", "5035039896502133936", "8871636629353578439", "7459202266562597344", "6133961403167948671", "9191986948655858497", "6919002552374671737", "3834503590779290545", "3429746845687339858", "4803818830674501773", "953909913787486485", "3451763848511086302", "9047047789922507199", "2865955665055037007", "3451763848511086302", "2599470256323068721", "8351599671021854493", "3839912992465323263", "8269876364174459846"];
#
#     recentlyReviewedHotelIds = ["8351599671021854493", "3839912992465323263", "8269876364174459846"];
#     recentlyBookedHotelIds = ["2865955665055037007", "3451763848511086302", "2599470256323068721"];
#     allHotelIds = priortizedHotelIds.concat(recentlyReviewedHotelIds)
#     allHotelIds = allHotelIds.concat(recentlyBookedHotelIds)
#     hotelAmenitiesNames = {"Free Internet": 112, "Outdoor Activities": 108, "CCTV surveillance": 119, "Dining": 120, "Internet": 105, "Conference Room": 125, "Travel Assistance": 109, "Power backup": 123, "Swimming Pool": 101, "Banquet hall": 124, "Clean Room": 115, "Indoor Entertainment": 111, "Front desk": 107, "Clean linen": 118, "Laundry Service": 110, "Business Services": 104, "Health-Spa": 106, "Parking Facility": 103, "Airport Transfer (on Demand)": 121, "Room Service": 113, "Restaurant/Coffee Shop": 102, "Pets allowed": 122, "Smoking Rooms Available": 116, "Spa": 114, "Clean Washroom": 117};
#     ugcAmenitiesMapping = {"vfm_rating": {"name": "Value for Money", "icon": "mnyIconMob"}, "fd_rating": {"name": "Food & Drinks", "icon": "fdIconMob"}, "loc_rating": {"name": "Location", "icon": "loctnIconMob"}, "sq_rating": {"name": "Service & Quality", "icon": "qltyIconMob"}, "cleanliness_rating": {"name": "Cleanliness", "icon": "clnIconMob"}, "amenities_rating": {"name": "Amenities", "icon": "amntyIconMob"}};
#     location_area_name = "";
#     hotel_city_name = "shimla";
#     chain_code = "";
#
#     star_rating = "";
#
#     property_type = "Hotels";
#     recommendedHotelIds = []
#     showLocationBox = true
#
#     location_id = ""
#     currentPage = 1;
#     loadLock = false;
#     locations = [];
#     landmarks = [];
#     contextTotalPages = 0;
#     distanceMapData = {};
#     collecName = "";
#     collecId = "";
#     segmentsRedirectSlugMap = {"763": {"url": "https://www.goibibo.com/hotels/hotels-for-couples-in-shimla-cl/", "collec_name": "dh_cf", "collec_id": "763"}, "766": {"url": "https://www.goibibo.com/hotels/business-hotels-in-shimla-cl/", "collec_name": "dh_business_friendly", "collec_id": "766"}, "5421": {"url": "https://www.goibibo.com/hotels/resorts-in-shimla-cl/", "collec_name": "resorts_landmark_location", "collec_id": "5421"}, "749": {"url": "https://www.goibibo.com/hotels/gostays-in-shimla-cl/", "collec_name": "dh_gostays", "collec_id": "749"}};
#
#     for (var id in segmentsRedirectSlugMap) {
#         url = segmentsRedirectSlugMap[id]["url"]
#         if (url == "https://www.goibibo.com/hotels/hotels-in-shimla-ct/") {
#             collecName = segmentsRedirectSlugMap[id]['collec_name'];
#             collecId = segmentsRedirectSlugMap[id]['collec_id'];
# ...
#
#
#         chains = [{"url": "/hotels/hotels-in-shimla/oyo-rooms-oyorms-chain/", "count": 200, "img": "https://gos3.ibcdn.com/OYO_Rooms-1424340877.jpg", "n": "OYO Rooms"}, {"url": "/hotels/hotels-in-shimla/hptdc-hptdc-chain/", "count": 4, "img": "", "n": "HPTDC"}, {"url": "/hotels/hotels-in-shimla/leisure-hotels-leisurehtl-chain/", "count": 3, "img": "https://gos3.ibcdn.com/LeisureHotels-1423739810.jpg", "n": "Leisure Hotels"}, {"url": "/hotels/hotels-in-shimla/club-mahindra-group-clubmhndrg-chain/", "count": 3, "img": "https://gos3.ibcdn.com/Club_Mahindra_Group-1424342342.png", "n": "Club Mahindra Group"}];
#
#
#     var enhancedEcommerceEvent = {};
#     var pos = 1;
#
#         var event_info = {}
#
#     var category = "hotels-domestic";
#     var end_page = 10;
#     var start_page = 1;
#     var subCategory = "domestic";
#
#     var hotelSoContext = {"hid": null};
#     var recommendedHotels = [];
#     enhancedEcommerceEvent['event'] = "enhanced-ecommerce-srp";
#     enhancedEcommerceEvent['path'] = window.location.href;
#     enhancedEcommerceEvent['client'] = "client";
#     enhancedEcommerceEvent['ecommerce'] = {"impressions":[]};
#     var roomString = "1-2_0";
#
#
#             enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"landmark shimla - With Elevator Access To Mall Road","id":"8351599671021854493","brand":"","category":category,"price":2880,"variant":4,"position":pos,"list":ecommerceListType });
#             pos++;
#
#             enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Summit Thistle Villa Resort &amp; Spa","id":"3839912992465323263","brand":"","category":category,"price":1650,"variant":4,"position":pos,"list":ecommerceListType });
#             pos++;
#
#             enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Hotel Dalziel","id":"8269876364174459846","brand":"","category":category,"price":1365,"variant":3,"position":pos,"list":ecommerceListType });
#             pos++;
#
#
#
#
#
#             enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Koti Resorts","id":"2865955665055037007","brand":"","category":category,"price":5500,"variant":4,"position":pos,"list":ecommerceListType });
#             pos++;
#
#             enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Hotel Chaman Palace","id":"3451763848511086302","brand":"","category":category,"price":1500,"variant":3,"position":pos,"list":ecommerceListType });
#             pos++;
#
#             enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Hotel Sidharath","id":"2599470256323068721","brand":"","category":category,"price":2800,"variant":3,"position":pos,"list":ecommerceListType });
#             pos++;
#
#
#
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Marina- Shimla First Designer Boutique Hotel","id":"8833337098196373625","brand":"","category":category,"price":8100,"variant":5,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Ashiana Clarks INN Shimla","id":"5035039896502133936","brand":"","category":category,"price":2880,"variant":3,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Hotel Sangeet","id":"8871636629353578439","brand":"","category":category,"price":1950,"variant":3,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Hotel Holiday Home(Govt. Hotel)","id":"7459202266562597344","brand":"","category":category,"price":3550,"variant":3,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Hotel Sansar","id":"6133961403167948671","brand":"","category":category,"price":650,"variant":0,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"OYO 1706 Hotel The Alpine Heritage Residency","id":"9191986948655858497","brand":"","category":category,"price":1958,"variant":3,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Clarkes Hotel, A grand heritage hotel since 1898","id":"6919002552374671737","brand":"","category":category,"price":6750,"variant":5,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"OYO Home 13421 Cozy Hill View 2BHK","id":"3834503590779290545","brand":"","category":category,"price":1710,"variant":3,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Pine Cottage Estate by BOHO","id":"3429746845687339858","brand":"","category":category,"price":3000,"variant":0,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"OYO Home 10839 Cozy Studio","id":"4803818830674501773","brand":"","category":category,"price":977,"variant":3,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#
#
#
#     // get list of locations and landmark ids
#
#     locationIdsList = [];
#     landmarkIdsList = [];
#
#     for (var i = 0; i < locations.length; i++) {
#         locationIdsList.push(locations[i]['id'])
#     }
#     for (var i = 0; i < landmarks.length; i++) {
#         landmarkIdsList.push(landmarks[i]['id'])
#     }
# </script><script src="//voyager.goibibo.com/static/cache/js/7cf80432c671.js" type="text/javascript"></script><style type="text/css">.fotDPLink a { color: #b3b3b3; font-size: 12px; line-height: 1; float: left; margin-right: 5px; padding-bottom: 5px; } .greyLter { color: #b3b3b3; } .website-badge-Bottom{display:none!important;}</style><div class="footerBox mobdn posRel" style="z-index: 1;"><div class="website-badge-Bottom"></div><div class="marginAuto"><div class="col-md-12 col-sm-12 padB20"><ul class="col-md-2 col-sm-3 footerLinks"><li class="txtTransUpper font12 greyDr fb padB10">our products</li><li><a href="/flight-schedule/">Flight Schedule</a></li><li><a href="/flights/city-to-city-airlines/">City Airline Routes</a></li><li><a href="/international-flights/">International Flights</a></li><li><a href="/hotels-international/">International Hotels</a></li><li><a href="/bus/">Bus Booking</a></li><li><a href="/airlines/">Domestic Airlines</a></li><li><a href="/hotels/hotels-in-india/">Hotels in India</a></li><li><a href="/hotels/">Hotel Booking</a></li><li><a href="/flights/cheap-flights/">Cheap Flights</a></li><li class="txtTransUpper font12 greyDr fb padB10 marginT15">Company</li><li><a href="/aboutus/">About Us</a></li><li><a href="/faqs/">FAQs</a></li><li><a href="/terms-and-conditions/">Terms &amp; Conditions</a></li><li><a href="/common/privacy/">Privacy</a></li><li><a href="/contactus/">Contact Us</a></li><li><a href="http://www.ibibo.com/">ibibo Group</a></li></ul><ul class="col-md-2 col-sm-3 footerLinks"><li class="txtTransUpper font12 greyDr fb padB10">Trending Hotel Cities</li><li><a href="//www.goibibo.com/hotels/hotels-in-goa-ct/">Hotels in Goa</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-delhi-ct/">Hotels in Delhi</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-mumbai-ct/">Hotels in Mumbai</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-bangalore-ct/">Hotels in Bangalore</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-hyderabad-ct/">Hotels in Hyderabad</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-chennai-ct/">Hotels in Chennai</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-jaipur-ct/">Hotels in Jaipur</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-pondicherry-ct/">Hotels in Pondicherry</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-agra-ct/">Hotels in Agra</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-bhopal-ct/">Hotels in Bhopal</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-indore-ct/">Hotels in Indore</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-digha-ct/">Hotels in Digha</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-guwahati-ct/">Hotels in Guwahati</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-udaipur-ct/">Hotels in Udaipur</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-shimla-ct/">Hotels in Shimla</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-surat-ct/">Hotels in Surat</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-puri-ct/">Hotels in Puri</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-manali-ct/">Hotels in Manali</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-ahmedabad-ct/">Hotels in Ahmedabad</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-coimbatore-ct/">Hotels in Coimbatore</a></li></ul><ul class="col-md-2 col-sm-3 footerLinks"><li class="txtTransUpper font12 greyDr fb padB10">Trending International Hotel Cities</li><li><a href="//www.goibibo.com/hotels/intl-hotels-in-dubai-ct/">Hotels in Dubai</a></li><li><a href="//www.goibibo.com/hotels/intl-hotels-in-bangkok-ct/">Hotels in Bangkok</a></li><li><a href="//www.goibibo.com/hotels/intl-hotels-in-bali-ct/">Hotels in Bali</a></li><li><a href="//www.goibibo.com/hotels/intl-hotels-in-phuket-ct/">Hotels in Phuket</a></li><li><a href="//www.goibibo.com/hotels/intl-hotels-in-pattaya-ct/">Hotels in Pattaya</a></li><li><a href="//www.goibibo.com/hotels/intl-hotels-in-singapore-ct/">Hotels in  ...
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer', 'GTM-NNFJ8WW' );</script><script type="text/javascript">
#     var _gaq = _gaq || {};
#     var dataLayer = dataLayer || {};
#     var gaDevice = "desktop";
#
# </script><script type="text/javascript">
#     function pushEventToGA(category,action,label){
#         if(_gaq && _gaq.push)
#         {
#             var eventData = (label && label!=null) ? ['_trackEvent', category, action, label] : ['_trackEvent', category, action];
#             _gaq.push(eventData);
#         }
#
#     }
# </script><script type="text/javascript">
#     function createCookie(name,value,time) {
#         if (time) {
#             var date = new Date();
#             date.setTime(date.getTime()+(time*1000));
#             var expires = "; expires="+date.toGMTString();
#         }
#         else var expires = "";
#         document.cookie = name+"="+value+expires+"; path=/";
#     }
#
#     function readCookie(name) {
#         var nameEQ = name + "=";
#         var ca = document.cookie.split(';');
#         for(var i=0;i < ca.length;i++) {
#             var c = ca[i];
#             while (c.charAt(0)==' ') c = c.substring(1,c.length);
#             if (c.indexOf(nameEQ) == 0) return c.substring(nameEQ.length,c.length);
#         }
#         return null;
#     }
#
#     function eraseCookie(name) {
#         createCookie(name,"",-1);
#     }
#
#
#     function setAppInstallWidget(){
#         $("#app-install-widget").html('<div class="mobileApp" style="background-color:#f7f7f7;padding:10px 5px;"><div class="fl crossTop" style="width:5%;margin-right:1%;"><a href="javascript:void(0);" onclick="$(\'#app-install-widget\').slideUp();"><img src="//goibibo.ibcdn.com/images/mobile/apparrow.png" style="width:14px;"></a></div><div class="fl" style="width:94%;margin-top:-5px;"><a href="https://go.onelink.me/2118851199?pid=SEO&c=SEO_Banners" id="appFlyer"><div class="fl" style="margin-right:12px; color:#737373;font-size:14px;line-height:22px;"><div style="font-size:22px; color:#000;"><div class="fl"><img src="//goibibo.ibcdn.com/images/mobile/go_icon.png"></div><div class="fl" style="margin-top:5px;margin-left:5px;">Goibibo <img src="//goibibo.ibcdn.com/images/mobile/android_stars.png"></div></div><div style="clear:both;"></div><p>For more discounts and better experience download goibibo app.<span style="border-radius:3px;float:none;background-color:#2e69b3;color:#fff;padding:5px 10px;margin-left:10px;">Install</span></p></div><div class="clearAll"></div></a></div><div class="clearAll"></div></div>');
#     }
#
#     $(window).load(function(){
#         var seobanner = true;
#         location.search.substr(1).split("&").forEach(function (item) {
#             tmp = item.split("=");
#             if (tmp[0] === "flavour" && (tmp[1] === "android" || tmp[1] === "ios") )
#                 seobanner = false;
#                 });
#
#
#         if($(window).width()<600 && !readCookie("app_install_widget_seo") && seobanner){
#
#             createCookie("app_install_widget_seo",1,15*60);
#
#         }
#     })
#
#     function pushDataLayerEvent(eventData){
#         if(dataLayer && dataLayer.push)
#         {
#             dataLayer.push(eventData);
#         }
#
#     }
#
#
# </script><input name="pgt" type="hidden" value="25-10-2019 00:41:46"/><a class="btn-scroll-top dn" id="scroll-top-btn"></a><div id="login-div" style="display: none;"><div class="popOverlay popShow"></div><div class="popModal zoom small popShow" id="authOverlay"><div class="popContent"><a class="fr icon-close font12Lt popClose" href="javascript:void(0)" onclick="$('#login-div').hide()"></a><div class="popBody"><iframe height="480px" id="authiframe" src="" width="100%"></iframe></div></div></div></div><div class="padT10 width10 dn" id="missing-review"><span>Be the first Reviewer</span> <br/> <a class="blue font13" id="write-review">Write Reviews</a> <a class="blue fr font13" id="ask-questions">Ask Questions</a></div></body></html>

# %%
data
# Out:
# <!DOCTYPE html>
# <html><head><title>Hotels in Shimla - Book 790 Shimla Hotels with 𝘂𝗽𝘁𝗼 𝟱𝟬% off @ ₹196</title><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/><meta content="Best Shimla Hotels with upto 50% off from Goibibo. Check 52690 reviews and 38801 photos for 790  Shimla Hotels. Use coupon code GETSETGO and grab best deals starting from  @ ₹196 on Shimla online hotel booking. ✔ Lowest Price Guarantee ✔ Fastest Booking ✔ Instant Refund" name="description"/><meta content="width=device-width,initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/><meta content="hotels in Shimla, best hotels in Shimla, Shimla hotels, Shimla hotel booking, Shimla hotel price, Shimla hotel deals, book Shimla hotels, goibibo Shimla hotels" name="keywords"/><link href="//www.goibibo.com/images/favicon.ico" rel="shortcut icon" type="image/ico"/><meta content="Hotels in Shimla -  Book 790  Shimla Hotels with 𝘂𝗽𝘁𝗼 𝟱𝟬% off  @ ₹196" property="og:title"/><meta content="Best Shimla Hotels with upto 50% off from Goibibo. Check 52690 reviews and 38801 photos for 790  Shimla Hotels. Use coupon code GETSETGO and grab best deals starting from  @ ₹196 on Shimla online hotel booking. ✔ Lowest Price Guarantee ✔ Fastest Booking ✔ Instant Refund" property="og:description"/><meta content="https://cdn1.goibibo.com/himachal-pradesh-shimla-147617005104o.jpg" property="og:image"/><meta content="https://www.goibibo.com/hotels/hotels-in-shimla-ct/" property="og:url"/><link href="https://www.goibibo.com/hotels/hotels-in-shimla-ct/" rel="canonical"/><link href="https://www.goibibo.com/hotels/hotels-in-shimla-ct/?pg=2" rel="next"/><link href='android-app://com.goibibo/goibibo/www.goibibo.com/app/hotels/hotels-in-shimla-ct/?params={"go_data": {"n": "shimla", "oid": "1449073512565742573", "t": "area", "cid": "1449073512565742573"}, "tag_id": 202}' rel="alternate"/><link href="https://fonts.googleapis.com/css?family=Quicksand&amp;display=swap" rel="stylesheet"/></head><body class="width100 fl"><noscript><meta content="0;url='https://www.goibibo.com/hotels/hotels-in-shimla-ct/?PageSpeed=noscript'" http-equiv="refresh"/><style><!--table,div,span,font,p{display:none} --></style><div style="display:block">Please click <a href="https://www.goibibo.com/hotels/hotels-in-shimla-ct/?PageSpeed=noscript">here</a> if you are not redirected within a few seconds.</div></noscript><div class="bgdiv" id="new-hotel-loading-div" style="position: fixed; font-family: 'Quicksand', sans-serif !important; display:none"><div id="background-loader-text" onclick="event.stopPropagation()" style="border-radius: 30px; margin: 150px auto; background-color: white; width: 643px; height: 336px;"><div style="width: 100%; height: 213px;"><script pagespeed_no_defer="">//<![CDATA[
# (function(){var g=encodeURIComponent,h=window,k=document,l="width",m="documentElement",n="height",p="length",q=this,r=function(b,d){var a=b.split("."),c=q;a[0]in c||!c.execScript||c.execScript("var "+a[0]);for(var e;a[p]&&(e=a.shift());)a[p]||void 0===d?c[e]?c=c[e]:c=c[e]={}:c[e]=d};var t=function(b){var d=b[p];if(0<d){for(var a=Array(d),c=0;c<d;c++)a[c]=b[c];return a}return[]};var u=function(b){var d=h;if(d.addEventListener)d.addEventListener("load",b,!1);else if(d.attachEvent)d.attachEvent("onload",b);else{var a=d.onload;d.onload=function(){b.call(this);a&&a.call(this)}}};var v,w=function(b,d,a,c,e){this.f=b;this.h=d;this.i=a;this.c=e;this.e={height:h.innerHeight||k[m].clientHeight||k.body.clientHeight,width:h.innerWidth||k[m].clientWidth||k.body.clientWidth};this.g=c;this.b={};this.a=[];this.d={}},x=function(b,d){var a,c,e=d.getAttribute("pagespeed_url_hash");if(a=e)if(a=!(e in b.d))if(0>=d.offsetWidth&&0>=d.offsetHeight)a=!1;else{c=d.getBoundingClientRect();var f=k.body;a=c.top+("pageYOffset"in h?h.pageYOffset:(k[m]||f.parentNode||f).scrollTop);c=c.left+("pageXOffset"in
# h?h.pageXOffset:(k[m]||f.parentNode||f).scrollLeft);f=a.toString()+","+c;b.b.hasOwnProperty(f)?a=!1:(b.b[f]=!0,a=a<=b.e[n]&&c<=b.e[l])}a&&(b.a.push(e),b.d[e]=!0)};w.prototype.checkImageForCriticality=function(b){b.getBoundingClientRect&&x(this,b)};r("pagespeed.CriticalImages.checkImageForCriticality",function(b){v.checkImageForCriticality(b)});r("pagespeed.CriticalImages.checkCriticalImages",function(){y(v)});
# var y=function(b){b.b={};for(var d=["IMG","INPUT"],a=[],c=0;c<d[p];++c)a=a.concat(t(k.getElementsByTagName(d[c])));if(0!=a[p]&&a[0].getBoundingClientRect){for(c=0;d=a[c];++c)x(b,d);a="oh="+b.i;b.c&&(a+="&n="+b.c);if(d=0!=b.a[p])for(a+="&ci="+g(b.a[0]),c=1;c<b.a[p];++c){var e=","+g(b.a[c]);131072>=a[p]+e[p]&&(a+=e)}b.g&&(e="&rd="+g(JSON.stringify(z())),131072>=a[p]+e[p]&&(a+=e),d=!0);A=a;if(d){c=b.f;b=b.h;var f;if(h.XMLHttpRequest)f=new XMLHttpRequest;else if(h.ActiveXObject)try{f=new ActiveXObject("Msxml2.XMLHTTP")}catch(s){try{f=
# new ActiveXObject("Microsoft.XMLHTTP")}catch(B){}}f&&(f.open("POST",c+(-1==c.indexOf("?")?"?":"&")+"url="+g(b)),f.setRequestHeader("Content-Type","application/x-www-form-urlencoded"),f.send(a))}}},z=function(){var b={},d=k.getElementsByTagName("IMG");if(0==d[p])return{};var a=d[0];if(!("naturalWidth"in a&&"naturalHeight"in a))return{};for(var c=0;a=d[c];++c){var e=a.getAttribute("pagespeed_url_hash");e&&(!(e in b)&&0<a[l]&&0<a[n]&&0<a.naturalWidth&&0<a.naturalHeight||e in b&&a[l]>=b[a.src].k&&a[n]>=
# b[a.src].j)&&(b[e]={rw:a[l],rh:a[n],ow:a.naturalWidth,oh:a.naturalHeight})}return b},A="";r("pagespeed.CriticalImages.getBeaconData",function(){return A});r("pagespeed.CriticalImages.Run",function(b,d,a,c,e,f){var s=new w(b,d,a,e,f);v=s;c&&u(function(){h.setTimeout(function(){y(s)},0)})});})();
#
# pagespeed.CriticalImages.Run('/mod_pagespeed_beacon','https://www.goibibo.com/hotels/hotels-in-shimla-ct/','9h69CgP56i',true,false,'zLfc1SnmMTk');
# //]]></script><img onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="2129554552" src="https://gos3.ibcdn.com/screen-loader-1568375554.png" style="width: auto; height: 175px; margin: 25px auto;"/></div><p style="width: 393px; margin: 0px auto; font-size: 22px; font-weight: bold; color: #2276e3;">LOADING THE BEST PRICES FOR YOU</p><div style="font-weight: normal; color: #898b91;"><p>We get you the best prices, everytime. Serving over 600k</p><p>customers worldwide everyday</p></div></div></div><div itemscope="" itemtype="http://schema.org/WebPage"><div id="app-install-widget"></div><script src="//goibibo.ibcdn.com/hotelsnew/static/js/lib/jquery.2.1.3.min.1483561221.js"></script><script src="//goibibo.ibcdn.com/styleguide/js/respond.min.1483563658.js"></script><script src="//goibibo.ibcdn.com/js/v2/headerV2.1568333090.js"></script><script src="//goibibo.ibcdn.com/js/v2/header_common.1568333090.js"></script><div class="headerBox col-md-12 col-sm-12 col-xs-12"><div class="hdrLeft"><a class="hdrLogo" href="/"><img onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="753931433" src="//goibibo.ibcdn.com/styleguide/images/goLogo.png"/></a><ul class="mainLinks"><li class="active"><a href="/flights/"><i class="icon-flights db blue ico24 lh1-2 padT5 padB5"></i> <span class="iconText">Flights</span></a></li><li class=""><a href="/hotels/"><i class="icon-hotels db blue ico28 lh1-2 padT2 padB3"></i> <span class="iconText">Hotels</span></a></li><li class=""><a href="/gostays/"><i class="icon-gostays icon-gostays-cstm db blue padT5 padB5"></i> <span class="iconText">Hotels</span></a></li><li class=""><a href="/bus/"><i class="icon-bus db blue ico24 lh1-2 padT5 padB5"></i> <span class="iconText">Bus</span></a></li><li class="posRel"><a href="/trains/"><img alt="irctc train logo" class="marginT5 marginB5" height="25px" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="3286845901" src="/styleguide/images/train_logo.png" width="24px"/><span class="iconText">IRCTC Trains</span></a></li><li class="posRel"><a href="/cars/"><i class="icon-airport-transfer db blue ico24 lh1-2 padT5 padB5"></i><span class="iconText">Cabs</span></a></li><li class="hdrMoreLink"><div class="padB10 lh1-2 iconText fmtTooltip">more +<div class="tip tip_top white moreSubLinks"><a href="/international-flights/"><i class="icon-flights padR10 blue ico20 fl"></i> <span class="fl padT3">International Flights</span></a><a href="/mobile/"><i class="icon-mobiles padR10 blue ico20 fl"></i> <span class="fl padT3">Mobile Apps</span></a> <a href="/destinations/"><i class="icon-destination padR10 blue ico20 fl"></i> <span class="fl padT3">Destinations</span></a> <a href="/ask/"><i class="icon-ask padR10 blue ico20 fl"></i> <span class="fl padT3">Ask</span></a> <a href="/routeplanner/"><i class="icon-route-planner padR10 blue ico20 fl"></i> <span class="fl padT3">Route Planner</span></a> <a href="/offers/"><i class="icon-offer-badge padR10 blue ico20 fl"></i> <span class="fl padT3">Offers &amp; Promotions</span></a> <a href="/info/reviews-and-rating/"><i class="icon-photo-review padR10 blue ico22 fl"></i> <span class="fl padT3">Reviews &amp; Ratings</span></a> <a href="/trains/check-train-running-status/"><i class="icon-train-front-view padR10 blue ico22 fl"></i> <span class="fl padT3">Train Runing Status</span></a> <a href="/trains/check-pnr-status/"><i class="icon-train-front-view padR10 blue ico22 fl"></i> <span class="fl padT3">Check PNR Status</span></a></div></div></li></ul></div><div class="hdrRight"><div class="width100 fl txtRight padB5 padR5"><a class="hdrCusSupport vMid padR15" href="/support/"><small class="fl ico13 lh1-2">24x7 goCare Support</small></a> <span class="vMid dib txtRight hdrUserName" id="hdr_user_signin"><span class="ico13 blue db"><a href="javascript:void(0)" onclick="window.location.href = '/accounts/login/?next=' + location.href;  ">Sign In</a> / <a href="jav ...
#     $(window).on('load',function(){
#
#         if(widget && widget.autosuggestSetter)
#         {
#             widget.autosuggestSetter({"title": "Shimla", "country": "IN", "entityType": "city", "cityName": "Shimla", "cityId": "1449073512565742573", "entityId": "1449073512565742573"});
#         }
#
#
#
#
#     });
#
# </script><div class="searchWrapOuterBox bgBlue row"><div class="searchInnerBox"><a class="dn ipaddn mobdb button orange large fl width100 marginB10 goCamp" href="javascript:void(0)" id="searchHotelButton" style="display:none !important;">Search<span class="goKarde"></span></a><form class="mobSearchToggle1" id="gi_search_hp" method="post" name="gi_search" onsubmit="return false;"><div class="col-md-12 col-sm-12 col-xs-12 pad0"><div class="col-lg-5 col-md-4 col-sm-12 col-xs-12 autoSuggestBox"><input autocomplete="off" class="form-control txtInput" id="gosuggest_inputL" placeholder="Enter City name, Area name or Hotel name" type="text"/><div class="col-md-12 col-sm-12 col-xs-12 autoWrap marginTM10"></div></div><div class="col-lg-3 col-md-3 col-sm-5 col-xs-12"><div class="fl width100 calenderOuterBox"><div class="col-md-6 col-xs-6 calenderInnerBox" id="ciHolder"><a class="width100 fl" data-date="" href="javascript:void(0)" id="start-date_hp"><i class="icon-calendar1 black ico26 fl padR5"></i> <span class="fl font13Dr padT5" id="ci_srp_day">Checkin</span></a><div class="jrdp_calendar_pos" id="start-calen_hp"></div></div><div class="col-md-6 col-xs-6 calenderInnerBox last" id="coHolder"><a class="width100 fl" data-date="" href="javascript:void(0)" id="end-date_hp"><i class="icon-calendar1 black ico26 fl padR5"></i> <span class="fl font13Dr padT5" id="co_srp_day">Checkout</span></a><div class="jrdp_calendar_pos" id="end-calen_hp"></div></div></div></div><div class="col-lg-2 col-md-3 col-sm-4 col-xs-12"><div class="paxWrapper"><a class="paxBox" href="javascript:void(0);" id="pax_link_hp"><i class="icon-user greyLt ico18 fl marginT2 padR5"></i> <span class="ico13 black padT5 fl" id="home_textHook">1 Guests / 1 Rooms</span> <i class="icon-arrow-down txtgrey ico18 padT5 fr"></i></a><div class="width100 fl paxWrapCont borderAll dn" id="paxcontainer_home"><div id="summaryContainer"></div><div id="editBox"></div><div class="width100 fl borderBtm marginB10 bg-greyLtest1" id="addButton"></div></div></div></div><div class="col-lg-2 col-md-2 col-sm-3 col-xs-12 marginB10 goCamp"><button class="button orange large ipadButtonSpace width100" id="hm_srch" type="submit">Search<span class="goKarde"></span></button></div></div></form></div></div><div class="dn" id="template-placeholder"></div><script id="go_suggestions" type="text/template">
# 		<ul class="autoSuggestBoxList flt dn">
# 			<% _.each(list, function(item,count) { %>
# 				<li <% if(item.left.cityHead){ %> class="cityhead" <%}%> <% if(item.left.indent){ %>class="indent" <%}%> data-index="<%= count %>">
# 					<% if(item.left.cityHead){ %>
# 						<% if(item.meta.pageType == 'offers'){%>
# 							<div class="fl padR2 hidden-sm hidden-xs padT5">
# 						<i class="fl icon-city ico11"></i>
# 						<% } else { %>
# 							<div class="fl padR2 hidden-sm hidden-xs padR2 padT5">
# 							<i class="fl icon-city ico14"></i>
# 						<% } %>
# 						</div> <%}%>
# 						<% if(item.meta.context=='flights'){%>
# 							<% if (item.left.cityHead == false){ %>
# 								<% if(item.meta.pageType == 'offers'){%>
# 									<div class="fl hidden-sm  padT5 hidden-xs">
# 								<i class="fl icon-flights ico12"></i>
# 								<% } else { %>
# 									<div class="fl padT5 hidden-sm padR10 hidden-xs">
#  									<i class="fl icon-flights ico14"></i>
# 								<% } %>
#
# 							</div><%}%>
# 							<% if(item.meta.suggestType == 'multi'){%> <div class="dib marginL10 col-md-10 col-sm-12 col-xs-12 pad0 textOverflow"><% } %>
# 							<% if(item.meta.pageType == 'offers'){%> <div class="dib marginL10 col-md-10 col-sm-12 col-xs-12 pad0 textOverflow"> <% } else { %><div class="dib col-md-11 col-sm-12 col-xs-12 pad0 textOverflow"><% } %>
# 								<div class="mainTxt clearfix">
# 									<span> <%= item.left.mainTxt %> </span> <span class="txtTransUpper ico14 greyLt">(<%= item.right.span %>)</span>
# 								</div>
# 								<% if(item.meta.suggestType == 'multi'){%>
# 									<div class="fl auto-ctryMult-ellip auto-ctryAir-ellip padT2">
# 								<% } else { %>
#  									<div class="fl auto-ctryAir-ellip mobEllipsis padT2">
# 								<% } %>
# 										<span class="clearfix">
# 											<small class="font12Lt"> <%= item.left.subTxtSpan %></small>
# 										</span>
#
# 									</div>
# 								<span class="fr">
# 									<% if(item.meta.pageType == 'offers'){%>
# 										<small class="font12Lt vMid padR5 dib"><%= item.left.subTextCName %></small>
# 									<% } else { %>
# 										<small class="font12Lt vMid padR5 dib"><%= item.left.subTxtSmall %></small>
# 									<% } %>
# 									<span class="flag-sprt vMid dib <%= item.left.subTextCName.toLowerCase() %>"></span>
# 								</span>
# 								<span class="clearfix">&nbsp;</span>
#
# 								<% if(item.left.dis && item.left.cityNameDis) {%>
# 										<span class="clearfix">
# 											<small class="font12Lt"> <span class="fb">(<%= Math.floor(item.left.dis) %></span> KMs from <span class="fb"><%= item.left.cityNameDis %></span>)</small>
# 										</span>
# 									<% } %>
# 							</div>
# 						<% } else { %>
# 							<div class="dib col-md-8 col-sm-8 pad0 <%if(item.meta.context){ %> col-xs-8 <% }else{ %>col-xs-12<% } %> <%if(item.meta.context=='flights'){ %> textOverflow <% } %>">
# 								<div class="mainTxt">
# 									<span><%= item.left.mainTxt %></span><% if(item.left.subTxtSpan){ %>
# 										<span class=""> &ndash; <%= item.left.subTxtSpan %></span>
# 										<% }else if(item.left.subTxtSmall){ %>
# 											<small class="font11Lt"><%= item.left.subTxtSmall %></small>
# 										<% } %>
# 								</div>
# 							</div>
# 						<% } %>
# 						<% if(item.meta.context!='flights'){%>
# 							<div class="col-md-4 col-sm-4 pad0 <%if(item.meta.context){ %> col-xs-4 <% }else{ %>col-xs-12<% } %>">
# 								<div class="fr width100">
# 									<% if(item.right.rating){%>
# 										<div class="fl">
# 											<div class="autoGoRating fl">
# 												<i class="icon-reverse-go ico15 orange fl"></i>
# 												<small class="fl padL5 padT2"><b><%= item.right.rating%></b>
# 													<span class="font11Lt">/5</span>
# 												</small>
# 											</div>
# 											<% if(item.right.reviewCount){ %>
# 												<small class="autoReviewers  padT2 fl width100">
# 													<span><%=item.right.reviewCount%></span> <span>Reviews</span>
# 												</small>
# 											<% } %>
# 										</div>
# 									<% } %>
#
# 									<% if(item.right.span){%>
# 									<% } else if(item.right.group){%>
# 										<% if(item.right.group.span){%>
# 											<span class="statusTag auto txtLeft"><%=item.right.group.span%></span>
# 										<% } %>
# 										<i class="ht_bgAutoSuggest ht_<%= item.right.group.type %> fr"></i>
# 										<small class="margin5 dib pad3 fr"><%= item.right.group.type %></small>
# 									<% } %>
# 								</div>
# 							</div>
# 						<% } %>
# 					</li>
# 				<% }); %>
# 			</ul>
# 		</script><script id="go_suggestions_error" type="text/template">
# 			<ul class="autoSuggestBoxList dn">
# 				<li> No matching result found.</li>
# 			</ul>
# 		</script><script id="pax_select" type="text/template">
#     <div class="widgetUserBlock fl <%=val.containerClass%>">
#         <label class="ico13 db padB5"><span><%=val.label%></span><small class="font10Lt db padT3"> <%=val.subLabel%></small></label>
#         <div class="customSelect">
#             <select <%if(val.react){ %> class="hasChild" id="<%=val.id%>" <% } %> name="<%=val.label.replace(' ','')%>">
#             <% for(var i=val.min;i<=val.max;i++){ %>
#             <option value="<%=i%>" <%if(val.value==i){ %>selected<% } %>><%=i%></option>
#             <% } %>
#             </select>
#         </div>
#     </div>
# </script><script id="pax_li" type="text/template">
#     <li class="roomRow">
#         <% if(config.boxHeading.visible){ %>
#         <h4 class="padTB5"><%=config.boxHeading.label%>
#             <% if(config.boxHeading.useIndex){ %>
#             <%=++config.boxHeading.index%>
#             <% } %>
#         </h4>
#         <%}%>
#         <% _.each(entity, function(person,key){ %>
#         <% if(person.visible){ %>
#         <%=renderSelect({val:person})%>
#         <%if(person.childConfig){ %>
#         <%for(var z=1;z<=person.value;z++){ %>
#         <%=renderSelect({val:person.childConfig[z-1]})%>
#         <%};%>
#         <%}%>
#         <%}%>
#         <% }); %>
#     </li>
# </script><script id="pax_template" type="text/template">
#     <div class="paxMobile dn paxContainer">
#         <a class="icon-cancel-circle fr marginT10 marginR10 fr greyDr mobdn" id="pax_close" href="javascript:void(0);"></a>
#         <ul>
#             <% _.each(config.entities, function(entity,idx){ %>
#             <%=renderLi({config:config,entity:entity,renderSelect:renderSelect})%>
#             <% }); %>
#
#             <% if(config.actionLinks.visible){ %>
#             <li class="fl txtCenter">
#                 <a class="fl ico16 pad15" href="javascript:void(0)" id="add">Add <%=config.actionLinks.textToAppend%></a>
#                 <a class="fl ico16 pad15 dn" href="javascript:void(0)" id="remove">Remove <%=config.actionLinks.textToAppend%></a>
#             </li>
#             <% }%>
#         </ul>
#     </div>
# </script><script id="summaryTemplate" type="text/template">
#
# 	<%for(var i=0; i<roomObject.roomconfig.length; i++){%>
#
# 		<div class="width100 fl posRel borderBtm summary" data-serial="<%=i+1%>">
#
# 			<div class="rowIcons nClick">
# 				<a class="icon-edit fl greyLt ico16 pad5 nClick" href="javascript:void(0);"></a>
# 				<%if(roomObject.roomconfig.length != 1){%>
# 					<a class="icon-close1 fl pad5 red nClick" href="javascript:void(0);" data-close="true"></a>
# 				<% } %>
# 			</div>
# 			<div class="userselected fl width100 nClick">
# 				<span class="fl ico14 pad10 grey lh1-2 bg-greyLtest1 fb nClick">Room <%=i+1%></span>
# 				<span class="fl pad10 tipLeft nClick"><%=roomObject.roomconfig[i].adult%> <%=roomObject.roomconfig[i].adultTag%> / <%=roomObject.roomconfig[i].children%> <%=roomObject.roomconfig[i].childTag%></span>
# 			</div>
#
# 		</div>
#
# 	<% } %>
#
# </script><script id="editTemplate" type="text/template">
#
# 		<div class="width100 fl posRel borderBtm">
# 			<div class="rowIcons">
# 				<a class="icon-close1 fl pad5 red nClick" href="javascript:void(0);" id="editClose"></a>
# 			</div>
# 			<div class="useredit fl width100 pad10" id="edtHook" data-mode= "<%=mode%>" data-serial = "<%=rmnumber + 1%>">
# 				<h4 class="padTB5 ico14 grey lh1-2">Room <%=rmnumber + 1%></h4>
# 				<div class="widgetUserBlock fl " ele="adult">
# 			        <label class="ico13 db padB5"><span>Adult</span><small class="font10Lt db padT3"> (12+ yrs)</small></label>
# 			        <div class="customSelect">
# 			            <select name="Adult">
# 			            <%for(var x=1; x<5; x++ ){%>
# 			            	<option value="<%=x%>"
# 			            		<% if(x == adult) { %>
# 			            			selected="selected"
# 					            <% } %>
# 					         ><%=x%></option>
# 					     <% } %>
# 			            </select>
# 			        </div>
# 			    </div>
# 				<div class="widgetUserBlock fl " ele="children">
# 			        <label class="ico13 db padB5"><span>Children</span><small class="font10Lt db padT3"> (2-12 yrs)</small></label>
# 			        <div class="customSelect">
# 			            <select class="hasChild" id="children" name="children">
# 			            	<%for(var x=0; x<3; x++ ){%>
# 				            	<option value="<%=x%>"
# 				            		<% if(x == children) { %>
# 				            			selected="selected"
# 						            <% } %>
# 						         ><%=x%></option>
# 						     <% } %>
# 			            </select>
# 			        </div>
# 			    </div>
# 			    <div class="widgetUserBlock fl children <% if(!age1){ %> dn <% } %>" id="childBox1" ele="age1">
# 					<label class="ico13 db padB5"><span>Child 1</span><small class="font10Lt db padT3"> Select age</small></label>
# 			        <div class="customSelect">
# 			            <select name="Child1">
#
# 			            	<%for(var x=1; x<13; x++ ){%>
# 				            	<option value="<%=x%>"
# 				            		<% if(x == age1) { %>
# 				            			selected="selected"
# 						            <% } %>
# 						         ><%=x%></option>
# 						     <% } %>
#
# 			            </select>
# 			        </div>
# 			    </div>
# 			    <div class="widgetUserBlock fl children <% if(!age2){ %> dn <% } %>" id="childBox2" ele="age2">
# 					<label class="ico13 db padB5"><span>Child 2</span><small class="font10Lt db padT3"> Select age</small></label>
# 			        <div class="customSelect">
# 			            <select name="Child2">
#
# 				            <%for(var x=1; x<13; x++ ){%>
# 				            	<option value="<%=x%>"
# 				            		<% if(x == age2) { %>
# 				            			selected="selected"
# 						            <% } %>
# 						         ><%=x%></option>
# 						     <% } %>
#
# 			            </select>
# 			        </div>
# 			    </div>
# 		    </div>
# 	    </div>
#
# </script><script id="addTemplate" type="text/template">
#
# 	<%if(roomObject.roomconfig.length < 6){%>
# 		<a class="button outlineBlue fl margin5 txtTransUpper nClick" id="addRoom">+ Add Room</a>
# 	<% } else {%>
# 		<div class="width100 fl pad10 txtCenter borderBtm">
# 			<span class="width100 fl grey ico12 lh1-2">Need more rooms? Contact our travel expert on</span>
# 			<span class="width100 dib padT2 ico13">
# 				<span class="dib blue">1800 267 9999</span>
# 				<span class="dib grey padL4 padR4">or</span>
# 				<span class="dib blue">
# 					<a href="mailto:holidays@goibibo.com">holidays@goibibo.com</a>
# 				</span>
# 			</span>
# 		</div>
# 	<% } %>
# 	<button class="button blue fr margin5 xsmall nClick" id="editSubmit">Done</button>
#
# </script><script>
# 		proto = window.location.protocol;
# 	</script><script src="//goibibo.ibcdn.com/hotelsnew/static/js/widget_hotels-lib-min.1483561221.js" type="text/javascript"></script></div> <div class="clear"></div><div class="width100 fl greyBg"><div class="seoPageHtl marginAuto"><div class="breadcrumb marginTB5 lh1-5 col-md-9 col-sm-9 col-xs-12 padL15" style="margin-bottom: -5px;"><div class="fl" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><a href="/" itemprop="url" title="Home"><span itemprop="title">Goibibo</span></a>→ </div><div class="fl" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><a href="/hotels/" itemprop="url" title="Hotel Booking"><span itemprop="title">Hotel Booking</span></a>→ </div><div class="fl" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><a href="/hotels/india/" itemprop="url" title="Hotels in India"><span itemprop="title">India</span></a> → </div><div class="fl"><span>Shimla</span></div></div></div></div><div class="clear"></div><div class="width100 fl greyBg"><div class="seoPageHtl marginAuto"><div class="col-md-12 col-sm-12 col-xs-12 padLR10"><div class="width100 fl"><a class="posRel button showFiltr orange xsmall fr ipaddb mobdn dn" onclick="">Hide Filter</a><section class="col-md-9 col-sm-12 col-xs-12 fr wid80 pad0" style="width: 75% !important;"><div id="price-loader"><div class="price-loader-text">Fetching best deals for you<div class="typing_loader"></div></div></div><div style="clear: both;"></div><div class="col-md-12 col-sm-12 col-xs-12 marginB10 marginT10 dn" id="search-head1"><div class="fl font15">Current Search Filters</div><div id="current-search-btns"></div></div><div class="dn" id="add-more-loc-head"><div class="txt-cap fl marginL20" id="add-more-loc"><a class="filter-btn txt-cap" onclick="HotelCityApp.searchEvents.focusLocationFilter()" style="background-color: #f26722;" title="Add More Locations">+ Add More</a></div></div><div class="dn fl marginL5 width100 marginT5" id="sort-div"><div class="sort-tab sort-tab-active" id="popularity" onclick="HotelCityApp.searchEvents.processSort('popularity')" title="Sort by popularity">Popularity</div><div class="sort-tab" id="price-low" onclick="HotelCityApp.searchEvents.processSort('price-low')" title="Sort by price low to high">Price Low To High</div><div class="sort-tab" id="price-high" onclick="HotelCityApp.searchEvents.processSort('price-high')" title="Sort by price high to low">Price High To Low</div><div class="col-md-3 col-sm-3 col-xs-12"><select class="listdropdown locDropDown dn" id="sort-type" onchange="HotelCityApp.searchEvents.multiLocationSort()"></select></div></div><div style="clear:both;"></div><div class="width100 fl padB5" id="outerSrpLocContainer" style="margin-top:10px;padding-left:5px; padding-right:5px;"><div class="searchBlk posRel" id="srpLocContainer" style="background: rgb(255, 255, 255); border-width: 0px 1px 1px; border-top-style: initial; border-right-style: solid; border-bottom-style: solid; border-left-style: solid; border-top-color: initial; border-right-color: rgb(230, 230, 230); border-bottom-color: rgb(230, 230, 230); border-left-color: rgb(230, 230, 230); border-image: initial;"><span class="fl ico16 black padT4 marginTB5" style="width: 260px;"><i class="icon-area ico18 fl marginR5 borderBtm redDr padR4"></i>Find By Location or Address</span><div class="fl posRel" style="width:500px;"><div class="fl padL20 autoSuggestBox" style="width:100%;"><div class="fl marginTB5 posRel" id="location-search-div" style="width:100%;"></div></div></div><span class="offerTag"><span class="dib">New</span></span></div></div><div style="clear:both;"></div><div style="clear:both;"></div><div class="width100 fl pad5 padding-top-0" id="main-page-div" style="padding-top: 0px;margin-top:-18px;"><div style="width: 100%; float: left; margin-top: 10px; margin-bottom: 10px;"><div class="col-md-12 col-sm-12 col-xs-12 marginT10" id="all-hotels-container"><div class="col-md-9 col-sm-12 col-xs-12"><i class="fl icon-hotels blue ico28"></i><h1 class ...
# <div id="htl-<%= hotel_data.id %>" class="width100 fl htlListSeo hotel-tile-srp-container hotel-tile-srp-container-template"  onclick="window.open('<%= hotel_data.url %>'); event.stopPropagation();">
#     <div class="hotel-tile-srp-container-img-container">
#         <% if (hotel_data.bkfstOverlay && hotel_data.bkfstOverlay === 1) {%>
#             <div class="htl-tile-free-bkfst-overlay" style="display: block;">
#                 <div class="text-label">Free breakfast</div>
#                 <div class="label-decor"></div>
#             </div>
#         <% } %>
#         <div class="hotel-tile-srp-container-title-image">
#             <img class="lazy" src="<%= hotel_data.img %>" ori="<%= hotel_data.img %>" id="htl-tile-main-image-<%= hotel_data.id %>">
#         </div>
#         <% if (hotel_data.img_gallery.length > 1) {%>
#             <ul class="hotel-tile-srp-container-image-gallery">
#                 <% for (var idx in hotel_data.img_gallery) {%>
#                     <li>
#                         <% if ((hotel_data.img_gallery.length-idx) === 1) {%>
#                             <div style="cursor:pointer !important;">
#                                 VIEW ALL
#                             </div>
#                         <% } %>
#                         <img src="<%=hotel_data.img_gallery[idx].th%>" fsi="<%=hotel_data.img_gallery[idx].fs%>" class="lazy htl-tile-gallery-image" htl="<%= hotel_data.id %>" onmouseenter="onImageHover(this, 'in')" onmouseleave="onImageHover(this, 'out')">
#                     </li>
#                 <% } %>
#             </ul>
#         <% } %>
#     </div>
#     <div class="hotel-tile-srp-container-content-container">
# 		<ul class="hotel-content-container-top-hinged-list">
# 			<li>
# 				<div style="display: inline-block; float:left;">
#                     <% for (var i=0; i<hotel_data.star_rating; i++) {%>
# 					    <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i>
#                     <% } %>
# 					<span style="padding: 2px; border: 1px solid #e5edf6; border-radius: 2px; margin-left: 5px; color: #4f525a">HOTEL</span>
# 				</div>
#                 <div>
#                  <% if  (hotel_data.ugc_src == "ta" && hotel_data.ta_rating != "") { %>
#                          <div style="background-color: green; height: 20px; -webkit-border-radius:5px; float:right; margin-left:8px;">
#                              <span >
#                              <img src="https://gos3.ibcdn.com/trip_adviser-1557838494.png" alt="Trip Advisor Logo" style="max-width: 25.5px; max-height: 12px; margin: 5px 0px 5px 5px;">
#                              <span class="ico16" style="color:#ffffff;  margin: 4px 7px 3px 5px; font-size:12px; float:right;">
#                                  <strong> <%= hotel_data.ta_rating %> </strong> /5 </span>
#                              </span>
#                          </div>
#                     <% } %>
#                 </div>
# 				<div style="float: right; margin-top:3px;">
#                     <% if (hotel_data.review_count) {%>
#                         <span><%= hotel_data.review_count %> reviews</span>
#                     <% } %>
#                     <% if (hotel_data.ugc_src === "gir" && hotel_block_config.go_rating === true && hotel_data.go_rating != "" && hotel_data.go_rating > 0) {%>
#                         <span style="padding: 4px; background-color: <% if (hotel_data.go_rating >= 4.0){ %>#7ccf50<% } else if (hotel_data.go_rating >= 3.0 ){ %>#afd600<% } else { %>#fdaf15<% } %>; color: white; border-radius: 2px; margin-left: 5px;"><%= hotel_data.go_rating %>/5</span>
#                     <% } %>
#                     <% if (!(hotel_data.review_count || (hotel_data.ugc_src === "gir" && hotel_block_config.go_rating === true && hotel_data.go_rating != "" && hotel_data.go_rating > 0) || (hotel_data.ugc_src === "ta" && hotel_block_config.ta_rating === true && hotel_data.ta_rating != "" && hotel_data.ta_rating > 0))) {%>
#                     <span>New Listing</span>
#                     <span style="padding: 4px 6px;background-color: #1aabb8;color: white;border-radius: 2px;">NEW</span>
#                     <% } %>
#                 </div>
# 			</li>
# 			<li>
#                 <a href="<%= hotel_data.url %>" target="_blank" onclick="event.stopPropagation();"><p style="font-size: 18px; font-weight: bolder; color: #141823;font-family: 'Quicksand', sans-serif;  margin-top:17px;"><%= hotel_data.name %></p></a>
#             </li>
# 			<% if (hotel_data.location) {%>
#             <li style="color: #2276e3;">
#                 <p><%= hotel_data.location %></p>
#             </li>
#             <% } %>
# 		</ul>
# 		<ul class="hotel-content-container-bottom-hinged-list">
# 			<li>
# 				<i class="icon-ranking" style="font-size: 15px; margin-right: 3px; color: #fdba00"></i>
#                 <% if (hotel_data.topTag && hotel_data.topTag != '') {%>
#                     <span class="htl-tile-top-tag-text" style="color: #2276e3; cursor: pointer"><%= hotel_data.topTag %></span>
#                 <% } else if (hotel_data.reco_percent && hotel_data.reco_percent != '0') {%>
#                     <span class="htl-tile-top-tag-text" style="color: #2276e3; cursor: pointer"><%= hotel_data.reco_percent %>% Guests recommend this hotel</span>
#                 <% } else { %>
#                     <span class="htl-tile-top-tag-text" style="color: #2276e3; cursor: pointer"></span>
#                 <% } %>
# 			</li>
#             <% if (hotel_data.locPin && hotel_data.locPin != "") {%>
#                 <li class="hotel-content-container-li-loc-usp" style="display: block;">
#                     <i class="icon-persuation-generic" style="font-size: 15px; margin-right: 3px;"></i>
#                     <span class="htl-tile-loc-pin-text"><%= hotel_data.locPin %></span>
#                 </li>
#             <% } %>
#             <% if (hotel_data.htl_amen_list) {%>
#                 <li style="" class="htl-tile-amenities-list">
#                     <% if (hotel_data.htl_amen_list.room_service === true) {%>
#                         <div style="">
#                             <i class="icon-service2" style=""></i>
#                             <span>Room Service</span>
#                         </div>
#                     <% } %>
#                     <% if (hotel_data.htl_amen_list.internet === true) {%>
#                         <div style="">
#                             <i class="icon-wifi-free" style=""></i>
#                             <span>Free Internet</span>
#                         </div>
#                     <% } %>
#                     <% if (hotel_data.htl_amen_list.restaurant === true) {%>
#                         <div style="">
#                             <i class="icon-restaurant2" style=""></i>
#                             <span>Restaurant/Coffee Shop</span>
#                         </div>
#                     <% } %>
#                     <% if (hotel_data.htl_amen_list.swimming_pool === true) {%>
#                         <div style="">
#                             <i class="icon-swimming2" style=""></i>
#                             <span>Swimming Pool</span>
#                         </div>
#                     <% } %>
#                 <% if (hotel_data.htl_rem_amen_cnt > 0) {%>
#                     <span style="color: #2276e3; cursor: pointer">+ <%= hotel_data.htl_rem_amen_cnt %> More</span>
#                 <% } %>
#                 </li>
#             <% } %>
#
# 			<% if (hotel_data.couple_friendly && hotel_data.couple_friendly === 1) {%>
#                 <li style="color: #ff3a5c;">
#                     <i class="icon-couple-man-woman" style="font-size: 15px; margin-right: 3px;"></i>
#                     <span>Couple Friendly</span>
#                 </li>
#             <% } %>
#             <% if (hotel_data.stlDeal && hotel_data.stlDeal != "") {%>
# 			<li style="color: #861388;">
# 				<span>
# 					<i class="icon-steal-deal" style="font-size: 15px; margin-right: 3px;"></i>
# 					<!--<i class="icon-path" style="font-size: 15px; margin-right: 3px;"></i>-->
# 				</span>
# 				<span style="padding: 3px 8px; border-radius: 10px; background-color: #f2e7f3;">Steal Deal</span>
#                 <span style="margin-left: 5px; color: black;" class="htl-tile-steal-deal-text"><%= hotel_data.stlDeal %></span>
# 			</li>
#             <% } %>
# 			<!--<li style="border-radius: 4px; background-color: #eef4fd; margin-top: 4px;">
# 				 <span style="background-image: linear-gradient(285deg, #cf125d, #ff3478); color: white; padding: 2px 8px; border-radius: 2px; margin-right: 5px;">
#                     GIFT CARD
#                 </span>
#                 <span>1500 TAJ Experiences card for use at any Taj</span>
#                 <span style="display: inline-block; margin-left: 5px; color: #2276e3;">+More</span>
# 			</li>
# 			<li style="border-radius: 4px;background-color: #eef4fd;">
# 				<span style="background-image: linear-gradient(107deg, #1149f3, #00c3ff); color: white; padding: 2px 8px; border-radius: 2px; margin-right: 5px;">SPL DEAL</span>
#                 <span>Free 30min SPA session</span>
#                 <span style="display: inline-block; margin-left: 5px; color: #2276e3;">+More</span>
# 			</li>-->
# 		</ul>
# 	</div>
# 		<div style="width: 200px; margin: 12px 10px 0px 6px; display: inline-block; border-left: 1px solid #e5edf6; height: 256px; position: absolute; right: 0px; font-size: 12px; color: #4f525a;">
#             <% if (hotel_data.bannerText && hotel_data.bannerText != "") {%>
#                 <div style="font-size: 12px; font-weight: bold; position: absolute; top: -24px; right: 10px;">
#                     <div style="display: inline-block; width: 0px; height: 0px; border-right: 5px solid #898b91; border-left: 5px solid transparent; border-top: 5px solid transparent; border-bottom: 5px solid #898b91; margin: -9px 0px 0px 0px;"></div>
#                     <div class="htl-tile-banner-text-div" style="margin: 0px -4px; display: inline-block; padding: 1px 10px; background-image: linear-gradient(284deg, #adaeb2, #34393a); color: white; width: max-content; border-bottom-right-radius: 2px; border-bottom-left-radius: 2px; height: 17px;">
#                         <%= hotel_data.bannerText %>
#                     </div>
#                     <div style="display: inline-block; width: 0px; height: 0px; border-right: 5px solid transparent; border-left: 5px solid #898b91; border-top: 5px solid transparent; border-bottom: 5px solid #898b91; margin: -9px 0px 0px 0px;"></div>
#                 </div>
#             <% } %>
#             <% if (hotel_data.fcpText && hotel_data.fcpText != "") {%>
#                 <div style="background-color: aliceblue; width: 182px; text-align: center; border-radius: 10px; margin: 5px auto;">
#                     <span style="color: #2bac36;" class="htl-tile-fcp-text"><%= hotel_data.fcpText %></span>
#                 </div>
#             <% } %>
# 			<div style="text-align: right; position: absolute; top: 75px; right: 0px;">
#                 <ul>
#                     <li style="height: 27px; display: none" class="htl-tile-prc-loader">
#                         <div class="typing_loader" style="float: unset;"></div>
#                     </li>
#                     <% if (hotel_data.so) { %>
#                     <li style="font-size: 18px;color: black;font-weight: bold;" class="htl-tile-sold-out-label">SOLD OUT</li>
#                     <% } else { %>
#                         <% if (hotel_data.oprc) { %>
#                             <li style="text-decoration: line-through;" class="htl-tile-non-discount-prc">
#                                 <i class="icon-rupee rupee-icon" style="font-size: 12px;"></i><%= hotel_data.oprc %>
#                             </li>
#                         <% } %>
#                         <% if (hotel_block_config.price == true && hotel_data.booking_price != "" && hotel_data.booking_price > 0) {%>
#                         <li style="font-size: 22px; color: black; font-weight: bold;" class="htl-tile-discount-prc">
#                             <i class="icon-rupee rupee-icon" style="font-size: 16px;"></i><%= hotel_data.booking_price %>
#                         </li>
#                         <li>per room/night</li>
#                         <% } %>
#                     <% } %>
#                     <% if (hotel_data.offersCount && hotel_data.offersCount > 0) {%>
#                         <li style="background-color: #fef8e5; color: #8e5a14;">
#                             <i class="icon-gocash-plus" style="font-size: 15px; color: #fdba00;"></i>
#                             <span style="margin: 5px;" class="htl-tile-offers-count">+<%= hotel_data.offersCount %> offers</span>
#                         </li>
#                     <% } %>
#                 </ul>
#             </div>
# 			<div style="text-align: right; position: absolute; bottom: 0px; right: 0px;">
# 			<p>
#                 <button onclick="window.open('<%= hotel_data.url %>'); event.stopPropagation();" style="padding: 0px 15px; height: 35px; font-size: 16px; font-weight: bold; background-color: #ff6d38; color: white; border: none; border-radius: 4px;">BOOK NOW</button>
#             </p>
# 			<p style="color: #ff3a5c; margin: 5px 0px;" class="htl-tile-last-opt"><%= hotel_data.lastTag %></p>
# 		</div>
# 	</div>
# </div>
# </script><script type="text/javascript">
#     pageType = "main_city";
#     lat = 31.1048145;
#     lon = 77.1734033;
#     city_name = "Shimla";
#     city_id = "1449073512565742573";
#     currentHost = "voyager.goibibo.com";
#     allHotelsData = {};
#     allHermesData = {};
#     priortizedHotelIds = ["8833337098196373625", "5035039896502133936", "8871636629353578439", "7459202266562597344", "6133961403167948671", "9191986948655858497", "6919002552374671737", "3834503590779290545", "3429746845687339858", "4803818830674501773", "6042678147555200728", "8814950729764566617", "2668930289000053794", "4132340955783784970", "7393074725561129529", "4603401151261891684", "6219607130473533931", "2310909284817368176", "7764296370836633209", "3451763848511086302", "7899035935330867108", "1085766080464256343", "7233073256399800597", "3027796615243425553", "334113831833825406", "7926285534851583337", "5644494538551280914", "1367466367395691201", "7830725769081543809", "9132401001922838353", "5552266556689170547", "7638770112293463188", "7896309543687198170", "4508640287885363792", "1949489690883681366", "2722835239411954969", "5890844042233498779", "5226089337385666229", "1700844874317530146", "919875262476689975", "4093584789369691896", "7973943634519748681", "3572747602679325734", "2739295705892554451", "4930060251182269812", "5231879829398869129", "5582707235298205128", "4341947675367428838", "3162417438540254080", "4366881424198211944", "9047047789922507199", "8847676300359984525", "8833940789536256162", "4797386695497356013", "2805366558683576001", "643910851770662122", "1840384582126692352", "6676802961546271766", "8256559789798336309", "7908309035161623236", "887913683841027079", "8525939572628378557", "3972438790911577064", "2918584767187870299", "6354599858499974952", "5296367711267092596", "7814236958554289102", "4356622928106972422", "6467213783512500824", "171304619761356672", "5364825111301595548", "7481785841346701430", "8210235490388535758", "4180652637903669013", "7867442280735533839", "2928012005302227019", "4024291697560108892", "7325499651138989507", "8634570325548773980", "6961675676232961072", "6833650235336324497", "1684310128965648781", "2152028404001390089", "7543907359980632827", "1923769941457192394", "5190297589595166178", "1272848330064890914", "5688410952616404300", "3840120836663711930", "3122448041086811088", "1839450225092003455", "5761525067723984112", "6672745452248732216", "3555257284160429171", "7535386019037895893", "4382675063350128999", "6868601222461797927", "6992592702406338805", "1373067411416306668", "7696013012067250540", "4865285288407569798", "2923180421546263602", "289297441951257782", "8487828901284192936", "6997953323380690605", "3062377524074980636", "5989231034384112109", "1753840413039671320", "1770849336303147771", "8798437038915809316", "584566816388311754", "3241060935116797850", "8154688523451183823", "7309046686498622248", "6682502713314075020", "2724952418138578682", "7491354277971285191", "5917072032362829316", "6655733281806765216", "3763280662125809904", "2502293248040232672", "5339455598025612593", "7481695928021801525", "4430673730811884875", "5860465706634300818", "1447855037354376569", "3443781901865797711", "6617236183435430076", "8964443484484594838", "2264529271423614038", "1416809721456220441", "1602794851833368474", "7071577211857429914", "3394214965776349887", "6849717144312925906", "3382270246003252888", "6025344523708922203", "4713243126660706589", "323485704258300318", "8685198985434721970", "292549637383670558", "4086518870721023087", "5755630105667356881", "1805720073013259735", "8477564650772533145", "6077198038391316207", "3063282073816526781", "926642424978302912", "4098314048100585768", "360487241192802909", "1632511420934038011", "1874875264102932793", "8038818731568437947", "4719927100919199252", "518705267460558983", "3403463968076540848", "3882623631711451075", "5186180118951080266", "2930265219565893244", "4343073517424016921", "4558330758147613894", "4899085585014300339", "6365647411079466321", "7144406779096906702", "7330523828712648537", "2706073311959172046", "2209003268233911490", "3754327080378501221", "7275331496949195588", "736425363845889208", "7493940230123243060", "632154612455959267", "2000804894644230056", "29420724 ...
#     priortizedHotelIdsSlice = ["8833337098196373625", "5035039896502133936", "8871636629353578439", "7459202266562597344", "6133961403167948671", "9191986948655858497", "6919002552374671737", "3834503590779290545", "3429746845687339858", "4803818830674501773", "953909913787486485", "3451763848511086302", "9047047789922507199", "2865955665055037007", "3451763848511086302", "2599470256323068721", "8351599671021854493", "3839912992465323263", "8269876364174459846"];
#
#     recentlyReviewedHotelIds = ["8351599671021854493", "3839912992465323263", "8269876364174459846"];
#     recentlyBookedHotelIds = ["2865955665055037007", "3451763848511086302", "2599470256323068721"];
#     allHotelIds = priortizedHotelIds.concat(recentlyReviewedHotelIds)
#     allHotelIds = allHotelIds.concat(recentlyBookedHotelIds)
#     hotelAmenitiesNames = {"Free Internet": 112, "Outdoor Activities": 108, "CCTV surveillance": 119, "Dining": 120, "Internet": 105, "Conference Room": 125, "Travel Assistance": 109, "Power backup": 123, "Swimming Pool": 101, "Banquet hall": 124, "Clean Room": 115, "Indoor Entertainment": 111, "Front desk": 107, "Clean linen": 118, "Laundry Service": 110, "Business Services": 104, "Health-Spa": 106, "Parking Facility": 103, "Airport Transfer (on Demand)": 121, "Room Service": 113, "Restaurant/Coffee Shop": 102, "Pets allowed": 122, "Smoking Rooms Available": 116, "Spa": 114, "Clean Washroom": 117};
#     ugcAmenitiesMapping = {"vfm_rating": {"name": "Value for Money", "icon": "mnyIconMob"}, "fd_rating": {"name": "Food & Drinks", "icon": "fdIconMob"}, "loc_rating": {"name": "Location", "icon": "loctnIconMob"}, "sq_rating": {"name": "Service & Quality", "icon": "qltyIconMob"}, "cleanliness_rating": {"name": "Cleanliness", "icon": "clnIconMob"}, "amenities_rating": {"name": "Amenities", "icon": "amntyIconMob"}};
#     location_area_name = "";
#     hotel_city_name = "shimla";
#     chain_code = "";
#
#     star_rating = "";
#
#     property_type = "Hotels";
#     recommendedHotelIds = []
#     showLocationBox = true
#
#     location_id = ""
#     currentPage = 1;
#     loadLock = false;
#     locations = [];
#     landmarks = [];
#     contextTotalPages = 0;
#     distanceMapData = {};
#     collecName = "";
#     collecId = "";
#     segmentsRedirectSlugMap = {"763": {"url": "https://www.goibibo.com/hotels/hotels-for-couples-in-shimla-cl/", "collec_name": "dh_cf", "collec_id": "763"}, "766": {"url": "https://www.goibibo.com/hotels/business-hotels-in-shimla-cl/", "collec_name": "dh_business_friendly", "collec_id": "766"}, "5421": {"url": "https://www.goibibo.com/hotels/resorts-in-shimla-cl/", "collec_name": "resorts_landmark_location", "collec_id": "5421"}, "749": {"url": "https://www.goibibo.com/hotels/gostays-in-shimla-cl/", "collec_name": "dh_gostays", "collec_id": "749"}};
#
#     for (var id in segmentsRedirectSlugMap) {
#         url = segmentsRedirectSlugMap[id]["url"]
#         if (url == "https://www.goibibo.com/hotels/hotels-in-shimla-ct/") {
#             collecName = segmentsRedirectSlugMap[id]['collec_name'];
#             collecId = segmentsRedirectSlugMap[id]['collec_id'];
# ...
#
#
#         chains = [{"url": "/hotels/hotels-in-shimla/oyo-rooms-oyorms-chain/", "count": 200, "img": "https://gos3.ibcdn.com/OYO_Rooms-1424340877.jpg", "n": "OYO Rooms"}, {"url": "/hotels/hotels-in-shimla/hptdc-hptdc-chain/", "count": 4, "img": "", "n": "HPTDC"}, {"url": "/hotels/hotels-in-shimla/leisure-hotels-leisurehtl-chain/", "count": 3, "img": "https://gos3.ibcdn.com/LeisureHotels-1423739810.jpg", "n": "Leisure Hotels"}, {"url": "/hotels/hotels-in-shimla/club-mahindra-group-clubmhndrg-chain/", "count": 3, "img": "https://gos3.ibcdn.com/Club_Mahindra_Group-1424342342.png", "n": "Club Mahindra Group"}];
#
#
#     var enhancedEcommerceEvent = {};
#     var pos = 1;
#
#         var event_info = {}
#
#     var category = "hotels-domestic";
#     var end_page = 10;
#     var start_page = 1;
#     var subCategory = "domestic";
#
#     var hotelSoContext = {"hid": null};
#     var recommendedHotels = [];
#     enhancedEcommerceEvent['event'] = "enhanced-ecommerce-srp";
#     enhancedEcommerceEvent['path'] = window.location.href;
#     enhancedEcommerceEvent['client'] = "client";
#     enhancedEcommerceEvent['ecommerce'] = {"impressions":[]};
#     var roomString = "1-2_0";
#
#
#             enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"landmark shimla - With Elevator Access To Mall Road","id":"8351599671021854493","brand":"","category":category,"price":2880,"variant":4,"position":pos,"list":ecommerceListType });
#             pos++;
#
#             enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Summit Thistle Villa Resort &amp; Spa","id":"3839912992465323263","brand":"","category":category,"price":1650,"variant":4,"position":pos,"list":ecommerceListType });
#             pos++;
#
#             enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Hotel Dalziel","id":"8269876364174459846","brand":"","category":category,"price":1365,"variant":3,"position":pos,"list":ecommerceListType });
#             pos++;
#
#
#
#
#
#             enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Koti Resorts","id":"2865955665055037007","brand":"","category":category,"price":5500,"variant":4,"position":pos,"list":ecommerceListType });
#             pos++;
#
#             enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Hotel Chaman Palace","id":"3451763848511086302","brand":"","category":category,"price":1500,"variant":3,"position":pos,"list":ecommerceListType });
#             pos++;
#
#             enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Hotel Sidharath","id":"2599470256323068721","brand":"","category":category,"price":2800,"variant":3,"position":pos,"list":ecommerceListType });
#             pos++;
#
#
#
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Marina- Shimla First Designer Boutique Hotel","id":"8833337098196373625","brand":"","category":category,"price":8100,"variant":5,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Ashiana Clarks INN Shimla","id":"5035039896502133936","brand":"","category":category,"price":2880,"variant":3,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Hotel Sangeet","id":"8871636629353578439","brand":"","category":category,"price":1950,"variant":3,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Hotel Holiday Home(Govt. Hotel)","id":"7459202266562597344","brand":"","category":category,"price":3550,"variant":3,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Hotel Sansar","id":"6133961403167948671","brand":"","category":category,"price":650,"variant":0,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"OYO 1706 Hotel The Alpine Heritage Residency","id":"9191986948655858497","brand":"","category":category,"price":1958,"variant":3,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Clarkes Hotel, A grand heritage hotel since 1898","id":"6919002552374671737","brand":"","category":category,"price":6750,"variant":5,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"OYO Home 13421 Cozy Hill View 2BHK","id":"3834503590779290545","brand":"","category":category,"price":1710,"variant":3,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"Pine Cottage Estate by BOHO","id":"3429746845687339858","brand":"","category":category,"price":3000,"variant":0,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#                 enhancedEcommerceEvent['ecommerce']['impressions'].push({"name":"OYO Home 10839 Cozy Studio","id":"4803818830674501773","brand":"","category":category,"price":977,"variant":3,"position":pos,"list":ecommerceListType });
#                 pos++;
#
#
#
#
#
#
#     // get list of locations and landmark ids
#
#     locationIdsList = [];
#     landmarkIdsList = [];
#
#     for (var i = 0; i < locations.length; i++) {
#         locationIdsList.push(locations[i]['id'])
#     }
#     for (var i = 0; i < landmarks.length; i++) {
#         landmarkIdsList.push(landmarks[i]['id'])
#     }
# </script><script src="//voyager.goibibo.com/static/cache/js/7cf80432c671.js" type="text/javascript"></script><style type="text/css">.fotDPLink a { color: #b3b3b3; font-size: 12px; line-height: 1; float: left; margin-right: 5px; padding-bottom: 5px; } .greyLter { color: #b3b3b3; } .website-badge-Bottom{display:none!important;}</style><div class="footerBox mobdn posRel" style="z-index: 1;"><div class="website-badge-Bottom"></div><div class="marginAuto"><div class="col-md-12 col-sm-12 padB20"><ul class="col-md-2 col-sm-3 footerLinks"><li class="txtTransUpper font12 greyDr fb padB10">our products</li><li><a href="/flight-schedule/">Flight Schedule</a></li><li><a href="/flights/city-to-city-airlines/">City Airline Routes</a></li><li><a href="/international-flights/">International Flights</a></li><li><a href="/hotels-international/">International Hotels</a></li><li><a href="/bus/">Bus Booking</a></li><li><a href="/airlines/">Domestic Airlines</a></li><li><a href="/hotels/hotels-in-india/">Hotels in India</a></li><li><a href="/hotels/">Hotel Booking</a></li><li><a href="/flights/cheap-flights/">Cheap Flights</a></li><li class="txtTransUpper font12 greyDr fb padB10 marginT15">Company</li><li><a href="/aboutus/">About Us</a></li><li><a href="/faqs/">FAQs</a></li><li><a href="/terms-and-conditions/">Terms &amp; Conditions</a></li><li><a href="/common/privacy/">Privacy</a></li><li><a href="/contactus/">Contact Us</a></li><li><a href="http://www.ibibo.com/">ibibo Group</a></li></ul><ul class="col-md-2 col-sm-3 footerLinks"><li class="txtTransUpper font12 greyDr fb padB10">Trending Hotel Cities</li><li><a href="//www.goibibo.com/hotels/hotels-in-goa-ct/">Hotels in Goa</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-delhi-ct/">Hotels in Delhi</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-mumbai-ct/">Hotels in Mumbai</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-bangalore-ct/">Hotels in Bangalore</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-hyderabad-ct/">Hotels in Hyderabad</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-chennai-ct/">Hotels in Chennai</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-jaipur-ct/">Hotels in Jaipur</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-pondicherry-ct/">Hotels in Pondicherry</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-agra-ct/">Hotels in Agra</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-bhopal-ct/">Hotels in Bhopal</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-indore-ct/">Hotels in Indore</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-digha-ct/">Hotels in Digha</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-guwahati-ct/">Hotels in Guwahati</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-udaipur-ct/">Hotels in Udaipur</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-shimla-ct/">Hotels in Shimla</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-surat-ct/">Hotels in Surat</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-puri-ct/">Hotels in Puri</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-manali-ct/">Hotels in Manali</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-ahmedabad-ct/">Hotels in Ahmedabad</a></li><li><a href="//www.goibibo.com/hotels/hotels-in-coimbatore-ct/">Hotels in Coimbatore</a></li></ul><ul class="col-md-2 col-sm-3 footerLinks"><li class="txtTransUpper font12 greyDr fb padB10">Trending International Hotel Cities</li><li><a href="//www.goibibo.com/hotels/intl-hotels-in-dubai-ct/">Hotels in Dubai</a></li><li><a href="//www.goibibo.com/hotels/intl-hotels-in-bangkok-ct/">Hotels in Bangkok</a></li><li><a href="//www.goibibo.com/hotels/intl-hotels-in-bali-ct/">Hotels in Bali</a></li><li><a href="//www.goibibo.com/hotels/intl-hotels-in-phuket-ct/">Hotels in Phuket</a></li><li><a href="//www.goibibo.com/hotels/intl-hotels-in-pattaya-ct/">Hotels in Pattaya</a></li><li><a href="//www.goibibo.com/hotels/intl-hotels-in-singapore-ct/">Hotels in  ...
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer', 'GTM-NNFJ8WW' );</script><script type="text/javascript">
#     var _gaq = _gaq || {};
#     var dataLayer = dataLayer || {};
#     var gaDevice = "desktop";
#
# </script><script type="text/javascript">
#     function pushEventToGA(category,action,label){
#         if(_gaq && _gaq.push)
#         {
#             var eventData = (label && label!=null) ? ['_trackEvent', category, action, label] : ['_trackEvent', category, action];
#             _gaq.push(eventData);
#         }
#
#     }
# </script><script type="text/javascript">
#     function createCookie(name,value,time) {
#         if (time) {
#             var date = new Date();
#             date.setTime(date.getTime()+(time*1000));
#             var expires = "; expires="+date.toGMTString();
#         }
#         else var expires = "";
#         document.cookie = name+"="+value+expires+"; path=/";
#     }
#
#     function readCookie(name) {
#         var nameEQ = name + "=";
#         var ca = document.cookie.split(';');
#         for(var i=0;i < ca.length;i++) {
#             var c = ca[i];
#             while (c.charAt(0)==' ') c = c.substring(1,c.length);
#             if (c.indexOf(nameEQ) == 0) return c.substring(nameEQ.length,c.length);
#         }
#         return null;
#     }
#
#     function eraseCookie(name) {
#         createCookie(name,"",-1);
#     }
#
#
#     function setAppInstallWidget(){
#         $("#app-install-widget").html('<div class="mobileApp" style="background-color:#f7f7f7;padding:10px 5px;"><div class="fl crossTop" style="width:5%;margin-right:1%;"><a href="javascript:void(0);" onclick="$(\'#app-install-widget\').slideUp();"><img src="//goibibo.ibcdn.com/images/mobile/apparrow.png" style="width:14px;"></a></div><div class="fl" style="width:94%;margin-top:-5px;"><a href="https://go.onelink.me/2118851199?pid=SEO&c=SEO_Banners" id="appFlyer"><div class="fl" style="margin-right:12px; color:#737373;font-size:14px;line-height:22px;"><div style="font-size:22px; color:#000;"><div class="fl"><img src="//goibibo.ibcdn.com/images/mobile/go_icon.png"></div><div class="fl" style="margin-top:5px;margin-left:5px;">Goibibo <img src="//goibibo.ibcdn.com/images/mobile/android_stars.png"></div></div><div style="clear:both;"></div><p>For more discounts and better experience download goibibo app.<span style="border-radius:3px;float:none;background-color:#2e69b3;color:#fff;padding:5px 10px;margin-left:10px;">Install</span></p></div><div class="clearAll"></div></a></div><div class="clearAll"></div></div>');
#     }
#
#     $(window).load(function(){
#         var seobanner = true;
#         location.search.substr(1).split("&").forEach(function (item) {
#             tmp = item.split("=");
#             if (tmp[0] === "flavour" && (tmp[1] === "android" || tmp[1] === "ios") )
#                 seobanner = false;
#                 });
#
#
#         if($(window).width()<600 && !readCookie("app_install_widget_seo") && seobanner){
#
#             createCookie("app_install_widget_seo",1,15*60);
#
#         }
#     })
#
#     function pushDataLayerEvent(eventData){
#         if(dataLayer && dataLayer.push)
#         {
#             dataLayer.push(eventData);
#         }
#
#     }
#
#
# </script><input name="pgt" type="hidden" value="25-10-2019 00:41:46"/><a class="btn-scroll-top dn" id="scroll-top-btn"></a><div id="login-div" style="display: none;"><div class="popOverlay popShow"></div><div class="popModal zoom small popShow" id="authOverlay"><div class="popContent"><a class="fr icon-close font12Lt popClose" href="javascript:void(0)" onclick="$('#login-div').hide()"></a><div class="popBody"><iframe height="480px" id="authiframe" src="" width="100%"></iframe></div></div></div></div><div class="padT10 width10 dn" id="missing-review"><span>Be the first Reviewer</span> <br/> <a class="blue font13" id="write-review">Write Reviews</a> <a class="blue fr font13" id="ask-questions">Ask Questions</a></div></body></html>

# %%
url
# Out:
# 'https://www.goibibo.com/hotels/hotels-in-shimla-ct/'

# %%
# find all the sections with specifiedd class name
cards_data = data.find_all('div', attrs={'class', 'width100 fl htlListSeo hotel-tile-srp-container hotel-tile-srp-container-template new-htl-design-tile-main-block'})

# total number of cards
print('Total Number of Cards Found : ', len(cards_data))

# source code of hotel cards
for card in cards_data:
    print(card)
# Out:
# Total Number of Cards Found :  10
# <div class="width100 fl htlListSeo hotel-tile-srp-container hotel-tile-srp-container-template new-htl-design-tile-main-block" id="htl-1953288179585905793" onclick="window.open('https://www.goibibo.com/hotels/snow-valley-resorts-hotel-in-shimla-1953288179585905793/');event.stopPropagation();"><div class="hotel-tile-srp-container-img-container"><div class="htl-tile-free-bkfst-overlay"><div class="text-label">Free breakfast</div><div class="label-decor"></div></div><div class="hotel-tile-srp-container-title-image"><img class="lazy" id="htl-tile-main-image-1953288179585905793" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" ori="https://cdn1.goibibo.com/image/fetch/t_g/f_jpg/https://gos3.ibcdn.com/9b33e1ccf01f11e98c710242ac110007.jpg" pagespeed_url_hash="3361994855" src="https://cdn1.goibibo.com/image/fetch/t_g/f_jpg/https://gos3.ibcdn.com/9b33e1ccf01f11e98c710242ac110007.jpg"/></div><ul class="hotel-tile-srp-container-image-gallery"><li><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/image/fetch/t_g/f_jpg/https://gos3.ibcdn.com/57d343c2e83c11e98f910242ac110002.jpg" htl="1953288179585905793" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="3450412480" src="https://cdn1.goibibo.com/image/fetch/t_r/f_jpg/https://gos3.ibcdn.com/57d343c2e83c11e98f910242ac110002.jpg"/></li><li><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/image/fetch/t_g/f_jpg/https://gos3.ibcdn.com/e6804d38e83a11e9934a0242ac110002.jpg" htl="1953288179585905793" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="2171658030" src="https://cdn1.goibibo.com/image/fetch/t_r/f_jpg/https://gos3.ibcdn.com/e6804d38e83a11e9934a0242ac110002.jpg"/></li><li><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/image/fetch/t_g/f_jpg/https://gos3.ibcdn.com/9b33e1ccf01f11e98c710242ac110007.jpg" htl="1953288179585905793" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="87232714" src="https://cdn1.goibibo.com/image/fetch/t_r/f_jpg/https://gos3.ibcdn.com/9b33e1ccf01f11e98c710242ac110007.jpg"/></li><li><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/image/fetch/t_g/f_jpg/https://gos3.ibcdn.com/8e705590eff911e9a67e0242ac110002.jpg" htl="1953288179585905793" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="3221985984" src="https://cdn1.goibibo.com/image/fetch/t_r/f_jpg/https://gos3.ibcdn.com/8e705590eff911e9a67e0242ac110002.jpg"/></li><li><div style="cursor:pointer !important;">VIEW ALL</div><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/snow-valley-resorts-shimla-washroom-121885880613-jpeg-fs.jpg" htl="1953288179585905793" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="52046395" src="https://cdn1.goibibo.com/snow-valley-resorts-shimla-washroom-121885880613-jpeg-r.jpg"/></li></ul></div><div class="hotel-tile-srp-container-content-container"><ul class="hotel-content-container-top-hinged-list"><li><div style="display: inline-block;"><i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <span style="padding: 2px; border: 1px solid #e5edf6; border-radius: 2px; margin-left: 5px; color: #4f525a">HOTEL</span></div><div style="float: right; margin-right:8px; margin-top:3px;"><span>1933 reviews</span> <span style="padding: 4px; background-color: #7ccf50; color: white; border-radius: 2px; margin-left: 5px;">4.4/5</span></div></li><li><a href="https://www.goibibo.com/hotels/snow-valley-resorts-hotel-in-shimla-1953288179585905793/" onclick="event.stopPropagation();" target="_blank"><p style="font-size: 18px; font-weight: bolder; color: #141823;font-family: 'Quicksand', sans-serif ...
# <div class="width100 fl htlListSeo hotel-tile-srp-container hotel-tile-srp-container-template new-htl-design-tile-main-block" id="htl-8833337098196373625" onclick="window.open('https://www.goibibo.com/hotels/marina-shimla-first-designer-boutique-hotel-in-shimla-8833337098196373625/');event.stopPropagation();"><div class="hotel-tile-srp-container-img-container"><div class="htl-tile-free-bkfst-overlay"><div class="text-label">Free breakfast</div><div class="label-decor"></div></div><div class="hotel-tile-srp-container-title-image"><img class="lazy" id="htl-tile-main-image-8833337098196373625" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" ori="https://cdn1.goibibo.com/marina-shimla-first-designer-boutique-hotel-shimla-exterior-128415489726-jpeg-g.jpg" pagespeed_url_hash="116042952" src="https://cdn1.goibibo.com/marina-shimla-first-designer-boutique-hotel-shimla-exterior-128415489726-jpeg-g.jpg"/></div><ul class="hotel-tile-srp-container-image-gallery"><li><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/marina-shimla-first-designer-boutique-hotel-shimla-1468662608328jpg-111895410692-jpeg-fs.jpg" htl="8833337098196373625" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1905834826" src="https://cdn1.goibibo.com/marina-shimla-first-designer-boutique-hotel-shimla-1468662608328jpg-111895410692-jpeg-r.jpg"/></li><li><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/marina-shimla-first-designer-boutique-hotel-shimla-exterior-128415489726-jpeg-fs.jpg" htl="8833337098196373625" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="3355542083" src="https://cdn1.goibibo.com/marina-shimla-first-designer-boutique-hotel-shimla-exterior-128415489726-jpeg-r.jpg"/></li><li><img class="lazy htl-tile-gallery-image" fsi="https://gos3.ibcdn.com/marina-shimla-first-designer-boutique-hotel-shimla-executive-66155028197fs.jpg" htl="8833337098196373625" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="3954957623" src="https://gos3.ibcdn.com/marina-shimla-first-designer-boutique-hotel-shimla-executive-66155028197r.jpg"/></li><li><img class="lazy htl-tile-gallery-image" fsi="https://gos3.ibcdn.com/marina-shimla-first-designer-boutique-hotel-shimla-game-zone-66155011567fs.jpg" htl="8833337098196373625" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="73760911" src="https://gos3.ibcdn.com/marina-shimla-first-designer-boutique-hotel-shimla-game-zone-66155011567r.jpg"/></li><li><div style="cursor:pointer !important;">VIEW ALL</div><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/marina-shimla-first-designer-boutique-hotel-shimla-hotel-marina-executive-bathroom_jpg-shimla-111895459508-jpeg-fs.jpg" htl="8833337098196373625" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="2517020836" src="https://cdn1.goibibo.com/marina-shimla-first-designer-boutique-hotel-shimla-hotel-marina-executive-bathroom_jpg-shimla-111895459508-jpeg-r.jpg"/></li></ul></div><div class="hotel-tile-srp-container-content-container"><ul class="hotel-content-container-top-hinged-list"><li><div style="display: inline-block;"><i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <span style="padding: 2px; border: 1px solid #e5edf6; border-radius: 2px; margin-left: 5px; color: #4f525a">HOTEL</span></div><div style="float: right; margin-right:8px; margin-top:3px;"><span>742 reviews</span> <span style="padding: 4px; background-color: #7ccf50; color: white; border-radius: 2px; margin-left: 5px;">4.5/5</span></div></li><li><a href="https://www.goibibo.com/hotel ...
# <div class="width100 fl htlListSeo hotel-tile-srp-container hotel-tile-srp-container-template new-htl-design-tile-main-block" id="htl-8269876364174459846" onclick="window.open('https://www.goibibo.com/hotels/dalziel-hotel-in-shimla-8269876364174459846/');event.stopPropagation();"><div class="hotel-tile-srp-container-img-container"><div class="htl-tile-free-bkfst-overlay"><div class="text-label">Free breakfast</div><div class="label-decor"></div></div><div class="hotel-tile-srp-container-title-image"><img class="lazy" id="htl-tile-main-image-8269876364174459846" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" ori="https://cdn1.goibibo.com/hotel-dalziel-shimla-lobby-115068775954-jpeg-g.jpg" pagespeed_url_hash="2627776515" src="https://cdn1.goibibo.com/hotel-dalziel-shimla-lobby-115068775954-jpeg-g.jpg"/></div><ul class="hotel-tile-srp-container-image-gallery"><li><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/t_fs/hotel-dalziel-shimla-reception-area-167085996884-orijgp.jpg" htl="8269876364174459846" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="2474305510" src="https://cdn1.goibibo.com/t_r/hotel-dalziel-shimla-reception-area-167085996884-orijgp.jpg"/></li><li><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/t_fs/hotel-dalziel-shimla-deluxe-room-145027948398-orijgp.jpg" htl="8269876364174459846" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="3483472693" src="https://cdn1.goibibo.com/t_r/hotel-dalziel-shimla-deluxe-room-145027948398-orijgp.jpg"/></li><li><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/hotel-dalziel-shimla-201405271746231675_hotel-dalziel_super-deluxe-bathroom_image2jpg-112875277963-jpeg-fs.jpg" htl="8269876364174459846" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="3530172730" src="https://cdn1.goibibo.com/hotel-dalziel-shimla-201405271746231675_hotel-dalziel_super-deluxe-bathroom_image2jpg-112875277963-jpeg-r.jpg"/></li><li><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/hotel-dalziel-shimla-lobby-115068775954-jpeg-fs.jpg" htl="8269876364174459846" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1572308350" src="https://cdn1.goibibo.com/hotel-dalziel-shimla-lobby-115068775954-jpeg-r.jpg"/></li><li><div style="cursor:pointer !important;">VIEW ALL</div><img class="lazy htl-tile-gallery-image" fsi="https://gos3.ibcdn.com/hotel-dalziel-shimla-restaurant-29783334fs.jpg" htl="8269876364174459846" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="3922057287" src="https://gos3.ibcdn.com/hotel-dalziel-shimla-restaurant-29783334r.jpg"/></li></ul></div><div class="hotel-tile-srp-container-content-container"><ul class="hotel-content-container-top-hinged-list"><li><div style="display: inline-block;"><i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <span style="padding: 2px; border: 1px solid #e5edf6; border-radius: 2px; margin-left: 5px; color: #4f525a">HOTEL</span></div><div style="float: right; margin-right:8px; margin-top:3px;"><span>1145 reviews</span> <span style="padding: 4px; background-color: #7ccf50; color: white; border-radius: 2px; margin-left: 5px;">4.0/5</span></div></li><li><a href="https://www.goibibo.com/hotels/dalziel-hotel-in-shimla-8269876364174459846/" onclick="event.stopPropagation();" target="_blank"><p style="font-size: 18px; font-weight: bolder; color: #141823;font-family: 'Quicksand', sans-serif;">Hotel Dalziel</p></a></li><li style="color: #2276e3;"><p>The Mall, Shimla, Himachal Pradesh, India, Shimla</p></li></ul><ul class="hotel-content-container-bottom-hinged-list"><li><i class="icon-ranking" style="font-size: 15px; margin-right: 3px; color: #fdba0 ...
# <div class="width100 fl htlListSeo hotel-tile-srp-container hotel-tile-srp-container-template new-htl-design-tile-main-block" id="htl-3572747602679325734" onclick="window.open('https://www.goibibo.com/hotels/combermere-hotel-in-shimla-3572747602679325734/');event.stopPropagation();"><div class="hotel-tile-srp-container-img-container"><div class="htl-tile-free-bkfst-overlay"><div class="text-label">Free breakfast</div><div class="label-decor"></div></div><div class="hotel-tile-srp-container-title-image"><img class="lazy" id="htl-tile-main-image-3572747602679325734" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" ori="https://gos3.ibcdn.com/hotel-combermere-shimla-hotel-fecade-66170888922g.jpg" pagespeed_url_hash="2192931302" src="https://gos3.ibcdn.com/hotel-combermere-shimla-hotel-fecade-66170888922g.jpg"/></div><ul class="hotel-tile-srp-container-image-gallery"><li><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/t_fs/hotel-combermere-shimla-sitting-area-156602476632-orijgp.jpg" htl="3572747602679325734" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="4232516156" src="https://cdn1.goibibo.com/t_r/hotel-combermere-shimla-sitting-area-156602476632-orijgp.jpg"/></li><li><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/hotel-combermere-shimla-14-85839731094-jpeg-fs.jpg" htl="3572747602679325734" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="3886965118" src="https://cdn1.goibibo.com/hotel-combermere-shimla-14-85839731094-jpeg-r.jpg"/></li><li><img class="lazy htl-tile-gallery-image" fsi="https://gos3.ibcdn.com/hotel-combermere-shimla-hotel-fecade-66170888922fs.jpg" htl="3572747602679325734" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1137463137" src="https://gos3.ibcdn.com/hotel-combermere-shimla-hotel-fecade-66170888922r.jpg"/></li><li><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/hotel-combermere-shimla-12-85839694430-jpeg-fs.jpg" htl="3572747602679325734" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="2633439054" src="https://cdn1.goibibo.com/hotel-combermere-shimla-12-85839694430-jpeg-r.jpg"/></li><li><div style="cursor:pointer !important;">VIEW ALL</div><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/hotel-combermere-shimla-02-85839934482-jpeg-fs.jpg" htl="3572747602679325734" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1125225817" src="https://cdn1.goibibo.com/hotel-combermere-shimla-02-85839934482-jpeg-r.jpg"/></li></ul></div><div class="hotel-tile-srp-container-content-container"><ul class="hotel-content-container-top-hinged-list"><li><div style="display: inline-block;"><i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <span style="padding: 2px; border: 1px solid #e5edf6; border-radius: 2px; margin-left: 5px; color: #4f525a">HOTEL</span></div><div style="float: right; margin-right:8px; margin-top:3px;"><span>749 reviews</span> <span style="padding: 4px; background-color: #7ccf50; color: white; border-radius: 2px; margin-left: 5px;">4.1/5</span></div></li><li><a href="https://www.goibibo.com/hotels/combermere-hotel-in-shimla-3572747602679325734/" onclick="event.stopPropagation();" target="_blank"><p style="font-size: 18px; font-weight: bolder; color: #141823;font-family: 'Quicksand', sans-serif;">Hotel Combermere</p></a></li><li style="color: #2276e3;"><p>The Mall Road, Shimla</p></li></ul><ul class="hotel-content-container-bottom-hinged-list"><li><i class="icon-ranking" style="font-size: 15px; margin-right: 3px; color: #fdba00"></i> <span class="htl-tile-top-tag-text" style="color: #2276e3; cursor: p ...
# <div class="width100 fl htlListSeo hotel-tile-srp-container hotel-tile-srp-container-template new-htl-design-tile-main-block" id="htl-8689972586923762049" onclick="window.open('https://www.goibibo.com/hotels/shingar-hotel-in-shimla-8689972586923762049/');event.stopPropagation();"><div class="hotel-tile-srp-container-img-container"><div class="htl-tile-free-bkfst-overlay"><div class="text-label">Free breakfast</div><div class="label-decor"></div></div><div class="hotel-tile-srp-container-title-image"><img class="lazy" id="htl-tile-main-image-8689972586923762049" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" ori="https://gos3.ibcdn.com/hotel-shingar-shimla-night-view-58546963244g.jpg" pagespeed_url_hash="3446296193" src="https://gos3.ibcdn.com/hotel-shingar-shimla-night-view-58546963244g.jpg"/></div><ul class="hotel-tile-srp-container-image-gallery"><li><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/hotel-shingar-shimla-hotel-shingar-shimla-reception-111976924538-jpeg-fs.jpg" htl="8689972586923762049" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="2528028071" src="https://cdn1.goibibo.com/hotel-shingar-shimla-hotel-shingar-shimla-reception-111976924538-jpeg-r.jpg"/></li><li><img class="lazy htl-tile-gallery-image" fsi="https://gos3.ibcdn.com/hotel-shingar-shimla-facade2-28625498fs.jpg" htl="8689972586923762049" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="2329771419" src="https://gos3.ibcdn.com/hotel-shingar-shimla-facade2-28625507r.jpg"/></li><li><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/hotel-shingar-shimla-super-deluxe-room-1-81367393657-jpeg-fs.jpg" htl="8689972586923762049" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="3395436246" src="https://cdn1.goibibo.com/hotel-shingar-shimla-super-deluxe-room-1-81367393657-jpeg-r.jpg"/></li><li><img class="lazy htl-tile-gallery-image" fsi="https://gos3.ibcdn.com/hotel-shingar-shimla-bathroom-1-58546986219fs.jpg" htl="8689972586923762049" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="412391905" src="https://gos3.ibcdn.com/hotel-shingar-shimla-bathroom-1-58546986219r.jpg"/></li><li><div style="cursor:pointer !important;">VIEW ALL</div><img class="lazy htl-tile-gallery-image" fsi="https://gos3.ibcdn.com/hotel-shingar-shimla-reception-58546981981fs.jpg" htl="8689972586923762049" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="2528058243" src="https://gos3.ibcdn.com/hotel-shingar-shimla-reception-58546981981r.jpg"/></li></ul></div><div class="hotel-tile-srp-container-content-container"><ul class="hotel-content-container-top-hinged-list"><li><div style="display: inline-block;"><i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <span style="padding: 2px; border: 1px solid #e5edf6; border-radius: 2px; margin-left: 5px; color: #4f525a">HOTEL</span></div><div style="float: right; margin-right:8px; margin-top:3px;"><span>925 reviews</span> <span style="padding: 4px; background-color: #7ccf50; color: white; border-radius: 2px; margin-left: 5px;">4.0/5</span></div></li><li><a href="https://www.goibibo.com/hotels/shingar-hotel-in-shimla-8689972586923762049/" onclick="event.stopPropagation();" target="_blank"><p style="font-size: 18px; font-weight: bolder; color: #141823;font-family: 'Quicksand', sans-serif;">Hotel Shingar</p></a></li><li style="color: #2276e3;"><p>Main Town, Shimla</p></li></ul><ul class="hotel-content-container-bottom-hinged-list"><li><i class="icon-ranking" style="font-size: 15px; margin-right: 3px; color: #fdba00"></i> <span class="htl-tile-top-tag-text" style="color: #2276e3; cursor: pointer">89% Guests recommend this hotel</span></li><li class="hotel-content-co ...
# <div class="width100 fl htlListSeo hotel-tile-srp-container hotel-tile-srp-container-template new-htl-design-tile-main-block" id="htl-6672745452248732216" onclick="window.open('https://www.goibibo.com/hotels/shimla-havens-resort-hotel-in-shimla-6672745452248732216/');event.stopPropagation();"><div class="hotel-tile-srp-container-img-container"><div class="htl-tile-free-bkfst-overlay"><div class="text-label">Free breakfast</div><div class="label-decor"></div></div><div class="hotel-tile-srp-container-title-image"><img class="lazy" id="htl-tile-main-image-6672745452248732216" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" ori="https://cdn1.goibibo.com/shimla-havens-shimla-bird-eye-view-102162412002-jpeg-g.jpg" pagespeed_url_hash="2821982799" src="https://cdn1.goibibo.com/shimla-havens-shimla-bird-eye-view-102162412002-jpeg-g.jpg"/></div><ul class="hotel-tile-srp-container-image-gallery"><li><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/shimla-havens-shimla-bar-2-124127577173-jpeg-fs.jpg" htl="6672745452248732216" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1604931805" src="https://cdn1.goibibo.com/shimla-havens-shimla-bar-2-124127577173-jpeg-r.jpg"/></li><li><img class="lazy htl-tile-gallery-image" fsi="https://gos3.ibcdn.com/shimla-havens-shimla-corridor-62169861458fs.jpg" htl="6672745452248732216" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="938215849" src="https://gos3.ibcdn.com/shimla-havens-shimla-corridor-62169861458r.jpg"/></li><li><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/shimla-havens-shimla-shimla-havens-shimla-img_-127007042031-jpeg-fs.jpg" htl="6672745452248732216" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1607824673" src="https://cdn1.goibibo.com/shimla-havens-shimla-shimla-havens-shimla-img_-127007042031-jpeg-r.jpg"/></li><li><img class="lazy htl-tile-gallery-image" fsi="https://gos3.ibcdn.com/shimla-havens-shimla-deluxe-suite-75735424806fs.jpg" htl="6672745452248732216" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="426090378" src="https://gos3.ibcdn.com/shimla-havens-shimla-deluxe-suite-75735424806r.jpg"/></li><li><div style="cursor:pointer !important;">VIEW ALL</div><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/shimla-havens-shimla-shimla-havens-resort-exterior_view_jpg-shimla-112897057002-jpeg-fs.jpg" htl="6672745452248732216" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="2533988166" src="https://cdn1.goibibo.com/shimla-havens-shimla-shimla-havens-resort-exterior_view_jpg-shimla-112897057002-jpeg-r.jpg"/></li></ul></div><div class="hotel-tile-srp-container-content-container"><ul class="hotel-content-container-top-hinged-list"><li><div style="display: inline-block;"><i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <span style="padding: 2px; border: 1px solid #e5edf6; border-radius: 2px; margin-left: 5px; color: #4f525a">RESORT</span></div><div style="float: right; margin-right:8px; margin-top:3px;"><span>328 reviews</span> <span style="padding: 4px; background-color: #7ccf50; color: white; border-radius: 2px; margin-left: 5px;">4.3/5</span></div></li><li><a href="https://www.goibibo.com/hotels/shimla-havens-resort-hotel-in-shimla-6672745452248732216/" onclick="event.stopPropagation();" target="_blank"><p style="font-size: 18px; font-weight: bolder; color: #141823;font-family: 'Quicksand', sans-serif;">Shimla Havens Resort</p></a></li><li style="color: #2276e3;"><p>Kachi Ghatti, Shimla</p></li></ul><ul class="hotel-content-container-bottom-hinged-list"><li><i class="icon-ranking" style="font-size ...
# <div class="width100 fl htlListSeo hotel-tile-srp-container hotel-tile-srp-container-template new-htl-design-tile-main-block" id="htl-6025344523708922203" onclick="window.open('https://www.goibibo.com/hotels/rocky-knob-hotel-in-shimla-6025344523708922203/');event.stopPropagation();"><div class="hotel-tile-srp-container-img-container"><div class="htl-tile-free-bkfst-overlay"><div class="text-label">Free breakfast</div><div class="label-decor"></div></div><div class="hotel-tile-srp-container-title-image"><img class="lazy" id="htl-tile-main-image-6025344523708922203" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" ori="https://cdn1.goibibo.com/t_g/rocky-knob-shimla-room-159882773979-orijgp.jpg" pagespeed_url_hash="237562232" src="https://cdn1.goibibo.com/t_g/rocky-knob-shimla-room-159882773979-orijgp.jpg"/></div></div><div class="hotel-tile-srp-container-content-container"><ul class="hotel-content-container-top-hinged-list"><li><div style="display: inline-block;"><i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <span style="padding: 2px; border: 1px solid #e5edf6; border-radius: 2px; margin-left: 5px; color: #4f525a">HOTEL</span></div><div style="float: right; margin-right:8px; margin-top:3px;"><span>42 reviews</span> <span style="padding: 4px; background-color: #7ccf50; color: white; border-radius: 2px; margin-left: 5px;">4.4/5</span></div></li><li><a href="https://www.goibibo.com/hotels/rocky-knob-hotel-in-shimla-6025344523708922203/" onclick="event.stopPropagation();" target="_blank"><p style="font-size: 18px; font-weight: bolder; color: #141823;font-family: 'Quicksand', sans-serif;">Rocky Knob</p></a></li><li style="color: #2276e3;"><p>Main Town, Shimla</p></li></ul><ul class="hotel-content-container-bottom-hinged-list"><li><i class="icon-ranking" style="font-size: 15px; margin-right: 3px; color: #fdba00"></i> <span class="htl-tile-top-tag-text" style="color: #2276e3; cursor: pointer">97% Guests recommend this hotel</span></li><li class="hotel-content-container-li-loc-usp" style=""><i class="icon-persuation-generic" style="font-size: 15px; margin-right: 3px;"></i> <span class="htl-tile-loc-pin-text"></span></li><li class="htl-tile-amenities-list" style=""><div style=""><i class="icon-service2" style=""></i> <span>Room Service</span></div><div style=""><i class="icon-restaurant2" style=""></i> <span>Restaurant/Coffee Shop</span></div><span style="color: #2276e3; cursor: pointer">+ 10 More</span></li><li style="color: #ff3a5c;"><i class="icon-couple-man-woman" style="font-size: 15px; margin-right: 3px;"></i> <span>Couple Friendly</span></li><li style="color: #861388; display: none"><span><i class="icon-steal-deal" style="font-size: 15px; margin-right: 3px;"></i></span> <span style="padding: 3px 8px; border-radius: 10px; background-color: #f2e7f3;">Steal Deal</span> <span class="htl-tile-steal-deal-text" style="margin-left: 5px; color: black;"></span></li></ul></div><div style="width: 200px; margin: 12px 10px 0px 6px; display: inline-block; border-left: 1px solid #e5edf6; height: 256px; position: absolute; right: 0px; font-size: 12px; color: #4f525a;"><div style="display: none; font-size: 12px; font-weight: bold; position: absolute; top: -24px; right: 10px;"><div style="display: inline-block; width: 0px; height: 0px; border-right: 5px solid #898b91; border-left: 5px solid transparent; border-top: 5px solid transparent; border-bottom: 5px solid #898b91; margin: -9px 0px 0px 0px;"></div><div class="htl-tile-banner-text-div" style="display: inline-block; padding: 1px 10px; background-image: linear-gradient(284deg, #adaeb2, #34393a); color: white; width: max-content; border-bottom-right-radius: 2px; border-bottom-left-radius: 2px; height: 17px;">HOT DEAL</div><div style="display: inline-block; width: 0px; height: 0px; border-right: 5px solid transparent; border-l ...
# <div class="width100 fl htlListSeo hotel-tile-srp-container hotel-tile-srp-container-template new-htl-design-tile-main-block" id="htl-7393074725561129529" onclick="window.open('https://www.goibibo.com/hotels/baljees-regency-hotel-in-shimla-7393074725561129529/');event.stopPropagation();"><div class="hotel-tile-srp-container-img-container"><div class="htl-tile-free-bkfst-overlay"><div class="text-label">Free breakfast</div><div class="label-decor"></div></div><div class="hotel-tile-srp-container-title-image"><img class="lazy" id="htl-tile-main-image-7393074725561129529" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" ori="https://cdn1.goibibo.com/hotel-baljees-regency-shimla-203_1-137265717069-jpeg-g.jpg" pagespeed_url_hash="940532987" src="https://cdn1.goibibo.com/hotel-baljees-regency-shimla-203_1-137265717069-jpeg-g.jpg"/></div><ul class="hotel-tile-srp-container-image-gallery"><li><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/hotel-baljees-regency-shimla-hotel-baljees-regency-shimla-reception-124648042319-jpeg-fs.jpg" htl="7393074725561129529" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="896728205" src="https://cdn1.goibibo.com/hotel-baljees-regency-shimla-hotel-baljees-regency-shimla-reception-124648042319-jpeg-r.jpg"/></li><li><img class="lazy htl-tile-gallery-image" fsi="https://gos3.ibcdn.com/hotel-baljees-regency-shimla-enterance-50183045539fs.jpg" htl="7393074725561129529" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="4236413226" src="https://gos3.ibcdn.com/hotel-baljees-regency-shimla-enterance-50183045539r.jpg"/></li><li><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/hotel-baljees-regency-shimla-202_1-137163338173-jpeg-fs.jpg" htl="7393074725561129529" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1164139609" src="https://cdn1.goibibo.com/hotel-baljees-regency-shimla-202_1-137163338173-jpeg-r.jpg"/></li><li><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/hotel-baljees-regency-shimla-216_2-137163395066-jpeg-fs.jpg" htl="7393074725561129529" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="208797789" src="https://cdn1.goibibo.com/hotel-baljees-regency-shimla-216_2-137163395066-jpeg-r.jpg"/></li><li><div style="cursor:pointer !important;">VIEW ALL</div><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/hotel-baljees-regency-shimla-206_5-135705117577-jpeg-fs.jpg" htl="7393074725561129529" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="2844993464" src="https://cdn1.goibibo.com/hotel-baljees-regency-shimla-206_5-135705117577-jpeg-r.jpg"/></li></ul></div><div class="hotel-tile-srp-container-content-container"><ul class="hotel-content-container-top-hinged-list"><li><div style="display: inline-block;"><i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <span style="padding: 2px; border: 1px solid #e5edf6; border-radius: 2px; margin-left: 5px; color: #4f525a">HOTEL</span></div><div style="float: right; margin-right:8px; margin-top:3px;"><span>1192 reviews</span> <span style="padding: 4px; background-color: #7ccf50; color: white; border-radius: 2px; margin-left: 5px;">4.2/5</span></div></li><li><a href="https://www.goibibo.com/hotels/baljees-regency-hotel-in-shimla-7393074725561129529/" onclick="event.stopPropagation();" target="_blank"><p style="font-size: 18px; font-weight: bolder; color: #141823;font-family: 'Quicksand', sans-serif;">Hotel Baljees Regency</p></a></li><li style="color: #2276e3;"><p>Main Town, Shimla</p></li></ul><ul class="hotel-content-container-bottom-hinged-list"><li><i class="icon-ranking" style="font-size: 15px; margin-right: 3px; color: #fdba00"></i> < ...
# <div class="width100 fl htlListSeo hotel-tile-srp-container hotel-tile-srp-container-template new-htl-design-tile-main-block" id="htl-3839912992465323263" onclick="window.open('https://www.goibibo.com/hotels/summit-thistle-villa-resort-spa-hotel-in-shimla-3839912992465323263/');event.stopPropagation();"><div class="hotel-tile-srp-container-img-container"><div class="htl-tile-free-bkfst-overlay"><div class="text-label">Free breakfast</div><div class="label-decor"></div></div><div class="hotel-tile-srp-container-title-image"><img class="lazy" id="htl-tile-main-image-3839912992465323263" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" ori="https://cdn1.goibibo.com/image/fetch/t_g/f_jpg/https://gos3.ibcdn.com/9341052ccf2611e99cdc0242ac110004.jpg" pagespeed_url_hash="1309812580" src="https://cdn1.goibibo.com/image/fetch/t_g/f_jpg/https://gos3.ibcdn.com/9341052ccf2611e99cdc0242ac110004.jpg"/></div><ul class="hotel-tile-srp-container-image-gallery"><li><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/image/fetch/t_g/f_jpg/https://gos3.ibcdn.com/a01b2a72ef5911e9a2b90242ac110002.jpg" htl="3839912992465323263" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1064806427" src="https://cdn1.goibibo.com/image/fetch/t_r/f_jpg/https://gos3.ibcdn.com/a01b2a72ef5911e9a2b90242ac110002.jpg"/></li><li><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/image/fetch/t_g/f_jpg/https://gos3.ibcdn.com/2f54b084ef5811e986f00242ac110006.jpg" htl="3839912992465323263" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="3734193085" src="https://cdn1.goibibo.com/image/fetch/t_r/f_jpg/https://gos3.ibcdn.com/2f54b084ef5811e986f00242ac110006.jpg"/></li><li><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/image/fetch/t_g/f_jpg/https://gos3.ibcdn.com/affbdc66ef5911e9b6780242ac110002.jpg" htl="3839912992465323263" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="2262600998" src="https://cdn1.goibibo.com/image/fetch/t_r/f_jpg/https://gos3.ibcdn.com/affbdc66ef5911e9b6780242ac110002.jpg"/></li><li><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/image/fetch/t_g/f_jpg/https://gos3.ibcdn.com/f83102d6d18611e9bc4d0242ac110003.jpg" htl="3839912992465323263" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1707766753" src="https://cdn1.goibibo.com/image/fetch/t_r/f_jpg/https://gos3.ibcdn.com/f83102d6d18611e9bc4d0242ac110003.jpg"/></li><li><div style="cursor:pointer !important;">VIEW ALL</div><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/image/fetch/t_g/f_jpg/https://gos3.ibcdn.com/09d7673cef5a11e99e0e0242ac110002.jpg" htl="3839912992465323263" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="2252137127" src="https://cdn1.goibibo.com/image/fetch/t_r/f_jpg/https://gos3.ibcdn.com/09d7673cef5a11e99e0e0242ac110002.jpg"/></li></ul></div><div class="hotel-tile-srp-container-content-container"><ul class="hotel-content-container-top-hinged-list"><li><div style="display: inline-block;"><i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <span style="padding: 2px; border: 1px solid #e5edf6; border-radius: 2px; margin-left: 5px; color: #4f525a">RESORT</span></div><div style="float: right; margin-right:8px; margin-top:3px;"><span>50 reviews</span> <span style="padding: 4px; background-color: #7ccf50; color: white; border-radius: 2px; margin-left: 5px;">4.6/5</span></div></li><li><a href="https://www.goibibo.com/hotels/summit-thistle-villa-resort-spa-hotel-in-shimla-3839912992465323263/" onclick="event.stopPropagation();" target="_blank"><p style="font-size: 18px; fo ...
# <div class="width100 fl htlListSeo hotel-tile-srp-container hotel-tile-srp-container-template new-htl-design-tile-main-block" id="htl-3972438790911577064" onclick="window.open('https://www.goibibo.com/hotels/surya-hotel-in-shimla-3972438790911577064/');event.stopPropagation();"><div class="hotel-tile-srp-container-img-container"><div class="htl-tile-free-bkfst-overlay"><div class="text-label">Free breakfast</div><div class="label-decor"></div></div><div class="hotel-tile-srp-container-title-image"><img class="lazy" id="htl-tile-main-image-3972438790911577064" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" ori="https://cdn1.goibibo.com/t_g/hotel-surya-shimla-hotel-surya-shimla-luxury-room-144765062278-orijgp.jpg" pagespeed_url_hash="4001991222" src="https://cdn1.goibibo.com/t_g/hotel-surya-shimla-hotel-surya-shimla-luxury-room-144765062278-orijgp.jpg"/></div><ul class="hotel-tile-srp-container-image-gallery"><li><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/t_fs/hotel-surya-shimla-hotel-surya-shimla-lobby-144765073049-orijgp.jpg" htl="3972438790911577064" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="4019471510" src="https://cdn1.goibibo.com/t_r/hotel-surya-shimla-hotel-surya-shimla-lobby-144765073049-orijgp.jpg"/></li><li><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/t_fs/hotel-surya-shimla-hotel-surya-shimla-roof-top-restaurant-144765078234-orijgp.jpg" htl="3972438790911577064" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1428799849" src="https://cdn1.goibibo.com/t_r/hotel-surya-shimla-hotel-surya-shimla-roof-top-restaurant-144765078234-orijgp.jpg"/></li><li><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/t_fs/hotel-surya-shimla-hotel-151331717018-orijgp.jpg" htl="3972438790911577064" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="3672954243" src="https://cdn1.goibibo.com/t_r/hotel-surya-shimla-hotel-151331717018-orijgp.jpg"/></li><li><img class="lazy htl-tile-gallery-image" fsi="https://cdn1.goibibo.com/t_fs/hotel-surya-shimla-hotel-surya-shimla-luxury-room-144765062278-orijgp.jpg" htl="3972438790911577064" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="1206751097" src="https://cdn1.goibibo.com/t_r/hotel-surya-shimla-hotel-surya-shimla-luxury-room-144765062278-orijgp.jpg"/></li><li><div style="cursor:pointer !important;">VIEW ALL</div><img class="lazy htl-tile-gallery-image" fsi="https://gos3.ibcdn.com/hotel-surya-shimla-lobby-28656506fs.jpg" htl="3972438790911577064" onload="pagespeed.CriticalImages.checkImageForCriticality(this);" pagespeed_url_hash="3441041995" src="https://gos3.ibcdn.com/hotel-surya-shimla-lobby-28656509r.jpg"/></li></ul></div><div class="hotel-tile-srp-container-content-container"><ul class="hotel-content-container-top-hinged-list"><li><div style="display: inline-block;"><i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <i class="icon-star3" style="font-size: 15px; color: #fdba00;"></i> <span style="padding: 2px; border: 1px solid #e5edf6; border-radius: 2px; margin-left: 5px; color: #4f525a">HOTEL</span></div><div style="float: right; margin-right:8px; margin-top:3px;"><span>1838 reviews</span> <span style="padding: 4px; background-color: #afd600; color: white; border-radius: 2px; margin-left: 5px;">3.8/5</span></div></li><li><a href="https://www.goibibo.com/hotels/surya-hotel-in-shimla-3972438790911577064/" onclick="event.stopPropagation();" target="_blank"><p style="font-size: 18px; font-weight: bolder; color: #141823;font-family: 'Quicksand', sans-serif;">Hotel Surya</p></a></li><li style="color: #2276e3;"><p>Main Town, Shimla</p></li></ul><ul class="hotel-content-container-bottom-hinged-list"><li><i class="icon-ranking" style="font-size: 15px; margin-right: 3px; color ...

# %%
# extract the hotel name and price per room
for card in cards_data:

    # get the hotel name
    hotel_name = card.find('p')

    # get the room price
    room_price = card.find('li', attrs={'class': 'htl-tile-discount-prc'})
    print(hotel_name.text, room_price.text)
# Out:
# Snow Valley Resorts 3000
# Marina- Shimla First Designer Boutique Hotel 7020
# Hotel Dalziel 1470
# Hotel Combermere 6150
# Hotel Shingar 2850
# Shimla Havens Resort 3025
# Rocky Knob 2700
# Hotel Baljees Regency 2310
# Summit Thistle Villa Resort & Spa 1650
# Hotel Surya 2376

# %%
# create a list to store the data
scraped_data = []

for card in cards_data:

    # initialize the dictionary
    card_details = {}

    # get the hotel name
    hotel_name = card.find('p')

    # get the room price
    room_price = card.find('li', attrs={'class': 'htl-tile-discount-prc'})

    # add data to the dictionary
    card_details['hotel_name'] = hotel_name.text
    card_details['room_price'] = room_price.text

    # append the scraped data to the list
    scraped_data.append(card_details)

# create a data frame from the list of dictionaries
dataFrame = pd.DataFrame.from_dict(scraped_data)

# save the scraped data as CSV file
dataFrame.to_csv('hotels_data.csv', index=False)
